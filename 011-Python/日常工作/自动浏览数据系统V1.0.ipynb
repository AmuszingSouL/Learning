# %%
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Downloads\chromedriver_win32\chromedriver.exe')

# %%
# 设置最大等待时长为 10秒
driver.implicitly_wait(10)

# %%
driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/")

# %%
user1 = driver.find_element_by_id('dynamic-table').text
print(user)
# Out:
# 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间
# imcall renwei1 3350 imkfdb1 imkf_chat_message_guazi 查看DDL 49100823 34112 2020-03-26 会话消息表 -2570533 2020-04-28
# imcall renwei1 3350 imkfdb3 imkf_chat_message_guazi 查看DDL 50222761 33527 2020-03-31 会话消息表 -1382796 2020-04-28
# new wangfeng5 3324 xinche work_order_operation_log 查看DDL 57226477 33191 2019-08-06 工单操作记录表 -3087448 2020-04-28
# medusa zhanghe8 3394 saber pod_info_log 查看DDL 90347759 32797 2020-02-27 -2919261 2020-04-28
# sem panxiaohuai 3314 guazi_sem semadmin_callin_record_channel_relation 查看DDL 87069260 32148 2018-09-05 400通话记录和渠道 3763037 2020-04-28
# clue sunweili 3317 clues vehicle_c2c_car_clues 查看DDL 16357926 31806 2019-08-02 线索表 17831 2020-04-28
# clue sunweili 3317 clues vehicle_c2c_car_clues_expand 查看DDL 90531067 30640 2020-04-11 线索信息扩展表 -451573 2020-04-28
# cwf guolingyu 3381 activiti_workflow ACT_HI_TASKINST 查看DDL 80277636 30433 2019-07-04 历史任务实例表 -10187804 2020-04-28
# ...

# %%
print(driver.current_url)
# Out:
# http://db-service.guazi-corp.com/dataQuery/allTables/

# %%
driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=3&keywords=")

# %%
user1 = driver.find_element_by_id('dynamic-table').text
print(user1)
# Out:
# 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间
# imcall renwei1 3350 imkfdb1 imkf_chat_message_guazi 查看DDL 49100823 34112 2020-03-26 会话消息表 -2570533 2020-04-28
# imcall renwei1 3350 imkfdb3 imkf_chat_message_guazi 查看DDL 50222761 33527 2020-03-31 会话消息表 -1382796 2020-04-28
# new wangfeng5 3324 xinche work_order_operation_log 查看DDL 57226477 33191 2019-08-06 工单操作记录表 -3087448 2020-04-28
# medusa zhanghe8 3394 saber pod_info_log 查看DDL 90347759 32797 2020-02-27 -2919261 2020-04-28
# sem panxiaohuai 3314 guazi_sem semadmin_callin_record_channel_relation 查看DDL 87069260 32148 2018-09-05 400通话记录和渠道 3763037 2020-04-28
# clue sunweili 3317 clues vehicle_c2c_car_clues 查看DDL 16357926 31806 2019-08-02 线索表 17831 2020-04-28
# clue sunweili 3317 clues vehicle_c2c_car_clues_expand 查看DDL 90531067 30640 2020-04-11 线索信息扩展表 -451573 2020-04-28
# cwf guolingyu 3381 activiti_workflow ACT_HI_TASKINST 查看DDL 80277636 30433 2019-07-04 历史任务实例表 -10187804 2020-04-28
# ...

# %%
print(driver.current_url)
# Out:
# http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=3&keywords=

# %%
print(user1,user2)
# Out:
# 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间
# medusa zhanghe8 3394 pod_informer task_execution_pod_record 查看DDL 17814850 159577 2020-04-22 任务执行POD记录表 432291 2020-04-28
# dbsys liuqiang44 3401 tulong mysql_status_history 查看DDL 254365959 149800 2019-04-21 mysql服务器状态 2119657 2020-04-28
# ncdata zhouquan5 3357 xinche_chain_surveillance tracking_event 查看DDL 60011454 119714 2019-09-05 埋点动作表 -5488852 2020-04-28
# cli donglei 3318 guazi_client client_personalized_url 查看DDL 629172424 97020 2018-08-15 个性URL存储表 586003 2020-04-28
# cra maolinwei 3307 newspider rrcb_links 查看DDL 494447947 80680 2018-04-02 人人车b端url 3218300 2020-04-28
# of huangfei6 3330 graph endpoint_counter 查看DDL 188823869 78859 2017-11-07 1370922 2020-04-28
# pay chenjun18 3340 paym_api_gw call_api_flow_detail 查看DDL 38524820 76927 2019-01-26 网关API调用明细表 3826995 2020-04-28
# xt linyuqiang 3404 confluence EVENTS 查看DDL 84055892 76229 2019-10-11 7243567 2020-04-28
# ...

# %%
d1=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1&keywords=")
d2=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=2&keywords=")

# %%
user1 = driver.find_element_by_id('dynamic-table').text
user2 = driver.find_element_by_id('dynamic-table').text

print(user1,user2)
# Out:
# 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间
# jr zhengdong 3312 finance vehicle_finance_loan_order_action 查看DDL 70184391 40441 2019-08-08 金融订单行为记录表 -7180602 2020-04-28
# inno songdaojun 3342 iip_iov base_daily_union_stat_gps 查看DDL 117723624 39962 2019-12-23 终端每日详情表 1387238 2020-04-28
# ai zhoujiashuai 3323 profile_log clue_sale_score_log 查看DDL 4287156 39884 2019-10-19 智能售卖评分日志表 10225 2020-04-28
# dbsys liuqiang44 3401 tulong redis_status_history 查看DDL 82316976 39632 2020-04-20 redis状态历史记 1445168 2020-04-28
# cat huhongjia 3331 call_task tasks 查看DDL 95294823 38830 2018-01-15 全部任务表 -1167417 2020-04-28
# new wangfeng5 3324 xinche_call_record call_record 查看DDL 111578207 37885 2019-12-07 新车工作手机通话录音 -359071 2020-04-28
# dbsys liuqiang44 3401 tulong mysql_users_history 查看DDL 338329 37004 2019-04-21 mysql用户记录历 761 2020-04-28
# audi zhoujiashuai 3316 open_platform maintenance_order 查看DDL 13887412 36918 2019-12-31 维修保养订单表 9601 2020-04-28
# ...

# %%
print(user1,user2,user3)
# Out:
# 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间

# %%
f = open(r'd:\result.txt', "a")

# %%
d1=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1&keywords=")
user1 = driver.find_element_by_id('dynamic-table').text
d2=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=2&keywords=")
user2 = driver.find_element_by_id('dynamic-table').text
d3=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=3&keywords=")
user3 = driver.find_element_by_id('dynamic-table').text
d4=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=4&keywords=")
user4 = driver.find_element_by_id('dynamic-table').text
d5=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=5&keywords=")
user5 = driver.find_element_by_id('dynamic-table').text
d6=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=6&keywords=")
user6 = driver.find_element_by_id('dynamic-table').text
d7=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=7&keywords=")
user7 = driver.find_element_by_id('dynamic-table').text
d8=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=8&keywords=")
user8 = driver.find_element_by_id('dynamic-table').text
d9=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=9&keywords=")
user9 = driver.find_element_by_id('dynamic-table').text
d10=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=10&keywords=")
user10 = driver.find_element_by_id('dynamic-table').text
d11=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=11&keywords=")
user11 = driver.find_element_by_id('dynamic-table').text
d12=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=12&keywords=")
user12 = driver.find_element_by_id('dynamic-table').text
d13=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=13&keywords=")
user13 = driver.find_element_by_id('dynamic-table').text
d14=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=14&keywords=")
user14 = driver.find_element_by_id('dynamic-table').text
d15=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=15&keywords=")
user15 = driver.find_element_by_id('dynamic-table').text
d16=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=16&keywords=")
user16 = driver.find_element_by_id('dynamic-table').text
d17=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=17&keywords=")
user17 = driver.find_element_by_id('dynamic-table').text
d18=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=18&keywords=")
user18 = driver.find_element_by_id('dynamic-table').text
d19=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=19&keywords=")
user19 = driver.find_element_by_id('dynamic-table').text
d20=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=20&keywords=")
user20 = driver.find_element_by_id('dynamic-table').text
d21=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=21&keywords=")
user21 = driver.find_element_by_id('dynamic-table').text
d22=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=22&keywords=")
user22 = driver.find_element_by_id('dynamic-table').text
d23=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=23&keywords=")
user23 = driver.find_element_by_id('dynamic-table').text
d24=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=24&keywords=")
user24 = driver.find_element_by_id('dynamic-table').text
d25=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=25&keywords=")
user25 = driver.find_element_by_id('dynamic-table').text
d26=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=26&keywords=")
user26 = driver.find_element_by_id('dynamic-table').text
d27=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=27&keywords=")
user27 = driver.find_element_by_id('dynamic-table').text
d28=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=28&keywords=")
user28 = driver.find_element_by_id('dynamic-table').text
d29=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=29&keywords=")
user29 = driver.find_element_by_id('dynamic-table').text
d30=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=30&keywords=")
user30 = driver.find_element_by_id('dynamic-table').text
d31=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=31&keywords=")
user31 = driver.find_element_by_id('dynamic-table').text
d32=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=32&keywords=")
user32 = driver.find_element_by_id('dynamic-table').text
d33=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=33&keywords=")
user33 = driver.find_element_by_id('dynamic-table').text
d34=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=34&keywords=")
user34 = driver.find_element_by_id('dynamic-table').text
d35=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=35&keywords=")
user35 = driver.find_element_by_id('dynamic-table').text
d36=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=36&keywords=")
user36 = driver.find_element_by_id('dynamic-table').text
d37=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=37&keywords=")
user37 = driver.find_element_by_id('dynamic-table').text
d38=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=38&keywords=")
user38 = driver.find_element_by_id('dynamic-table').text
d39=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=39&keywords=")
user39 = driver.find_element_by_id('dynamic-table').text
d40=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=40&keywords=")
user40 = driver.find_element_by_id('dynamic-table').text
d41=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=41&keywords=")
user41 = driver.find_element_by_id('dynamic-table').text
d42=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=42&keywords=")
user42 = driver.find_element_by_id('dynamic-table').text
d43=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=43&keywords=")
user43 = driver.find_element_by_id('dynamic-table').text
d44=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=44&keywords=")
user44 = driver.find_element_by_id('dynamic-table').text
d45=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=45&keywords=")
user45 = driver.find_element_by_id('dynamic-table').text
d46=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=46&keywords=")
user46 = driver.find_element_by_id('dynamic-table').text
d47=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=47&keywords=")
user47 = driver.find_element_by_id('dynamic-table').text
d48=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=48&keywords=")
user48 = driver.find_element_by_id('dynamic-table').text
d49=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=49&keywords=")
user49 = driver.find_element_by_id('dynamic-table').text
d50=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=50&keywords=")
user50 = driver.find_element_by_id('dynamic-table').text
d51=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=51&keywords=")
user51 = driver.find_element_by_id('dynamic-table').text
d52=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=52&keywords=")
user52 = driver.find_element_by_id('dynamic-table').text
d53=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=53&keywords=")
user53 = driver.find_element_by_id('dynamic-table').text
d54=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=54&keywords=")
user54 = driver.find_element_by_id('dynamic-table').text
d55=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=55&keywords=")
user55 = driver.find_element_by_id('dynamic-table').text
d56=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=56&keywords=")
user56 = driver.find_element_by_id('dynamic-table').text
d57=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=57&keywords=")
user57 = driver.find_element_by_id('dynamic-table').text
d58=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=58&keywords=")
user58 = driver.find_element_by_id('dynamic-table').text
d59=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=59&keywords=")
user59 = driver.find_element_by_id('dynamic-table').text
d60=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=60&keywords=")
user60 = driver.find_element_by_id('dynamic-table').text
d61=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=61&keywords=")
user61 = driver.find_element_by_id('dynamic-table').text
d62=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=62&keywords=")
user62 = driver.find_element_by_id('dynamic-table').text
d63=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=63&keywords=")
user63 = driver.find_element_by_id('dynamic-table').text
d64=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=64&keywords=")
user64 = driver.find_element_by_id('dynamic-table').text
d65=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=65&keywords=")
user65 = driver.find_element_by_id('dynamic-table').text
d66=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=66&keywords=")
user66 = driver.find_element_by_id('dynamic-table').text
d67=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=67&keywords=")
user67 = driver.find_element_by_id('dynamic-table').text
d68=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=68&keywords=")
user68 = driver.find_element_by_id('dynamic-table').text
d69=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=69&keywords=")
user69 = driver.find_element_by_id('dynamic-table').text
d70=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=70&keywords=")
user70 = driver.find_element_by_id('dynamic-table').text
d71=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=71&keywords=")
user71 = driver.find_element_by_id('dynamic-table').text
d72=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=72&keywords=")
user72 = driver.find_element_by_id('dynamic-table').text
d73=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=73&keywords=")
user73 = driver.find_element_by_id('dynamic-table').text
d74=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=74&keywords=")
user74 = driver.find_element_by_id('dynamic-table').text
d75=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=75&keywords=")
user75 = driver.find_element_by_id('dynamic-table').text
d76=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=76&keywords=")
user76 = driver.find_element_by_id('dynamic-table').text
d77=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=77&keywords=")
user77 = driver.find_element_by_id('dynamic-table').text
d78=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=78&keywords=")
user78 = driver.find_element_by_id('dynamic-table').text
d79=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=79&keywords=")
user79 = driver.find_element_by_id('dynamic-table').text
d80=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=80&keywords=")
user80 = driver.find_element_by_id('dynamic-table').text
d81=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=81&keywords=")
user81 = driver.find_element_by_id('dynamic-table').text
d82=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=82&keywords=")
user82 = driver.find_element_by_id('dynamic-table').text
d83=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=83&keywords=")
user83 = driver.find_element_by_id('dynamic-table').text
d84=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=84&keywords=")
user84 = driver.find_element_by_id('dynamic-table').text
d85=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=85&keywords=")
user85 = driver.find_element_by_id('dynamic-table').text
d86=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=86&keywords=")
user86 = driver.find_element_by_id('dynamic-table').text
d87=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=87&keywords=")
user87 = driver.find_element_by_id('dynamic-table').text
d88=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=88&keywords=")
user88 = driver.find_element_by_id('dynamic-table').text
d89=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=89&keywords=")
user89 = driver.find_element_by_id('dynamic-table').text
d90=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=90&keywords=")
user90 = driver.find_element_by_id('dynamic-table').text
d91=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=91&keywords=")
user91 = driver.find_element_by_id('dynamic-table').text
d92=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=92&keywords=")
user92 = driver.find_element_by_id('dynamic-table').text
d93=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=93&keywords=")
user93 = driver.find_element_by_id('dynamic-table').text
d94=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=94&keywords=")
user94 = driver.find_element_by_id('dynamic-table').text
d95=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=95&keywords=")
user95 = driver.find_element_by_id('dynamic-table').text
d96=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=96&keywords=")
user96 = driver.find_element_by_id('dynamic-table').text
d97=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=97&keywords=")
user97 = driver.find_element_by_id('dynamic-table').text
d98=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=98&keywords=")
user98 = driver.find_element_by_id('dynamic-table').text
d99=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=99&keywords=")
user99 = driver.find_element_by_id('dynamic-table').text
d100=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=100&keywords=")
user100 = driver.find_element_by_id('dynamic-table').text
d101=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=101&keywords=")
user101 = driver.find_element_by_id('dynamic-table').text
d102=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=102&keywords=")
user102 = driver.find_element_by_id('dynamic-table').text
d103=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=103&keywords=")
user103 = driver.find_element_by_id('dynamic-table').text
d104=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=104&keywords=")
user104 = driver.find_element_by_id('dynamic-table').text
d105=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=105&keywords=")
user105 = driver.find_element_by_id('dynamic-table').text
d106=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=106&keywords=")
user106 = driver.find_element_by_id('dynamic-table').text
d107=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=107&keywords=")
user107 = driver.find_element_by_id('dynamic-table').text
d108=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=108&keywords=")
user108 = driver.find_element_by_id('dynamic-table').text
d109=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=109&keywords=")
user109 = driver.find_element_by_id('dynamic-table').text
d110=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=110&keywords=")
user110 = driver.find_element_by_id('dynamic-table').text
d111=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=111&keywords=")
user111 = driver.find_element_by_id('dynamic-table').text
d112=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=112&keywords=")
user112 = driver.find_element_by_id('dynamic-table').text
d113=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=113&keywords=")
user113 = driver.find_element_by_id('dynamic-table').text
d114=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=114&keywords=")
user114 = driver.find_element_by_id('dynamic-table').text
d115=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=115&keywords=")
user115 = driver.find_element_by_id('dynamic-table').text
d116=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=116&keywords=")
user116 = driver.find_element_by_id('dynamic-table').text
d117=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=117&keywords=")
user117 = driver.find_element_by_id('dynamic-table').text
d118=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=118&keywords=")
user118 = driver.find_element_by_id('dynamic-table').text
d119=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=119&keywords=")
user119 = driver.find_element_by_id('dynamic-table').text
d120=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=120&keywords=")
user120 = driver.find_element_by_id('dynamic-table').text
d121=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=121&keywords=")
user121 = driver.find_element_by_id('dynamic-table').text
d122=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=122&keywords=")
user122 = driver.find_element_by_id('dynamic-table').text
d123=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=123&keywords=")
user123 = driver.find_element_by_id('dynamic-table').text
d124=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=124&keywords=")
user124 = driver.find_element_by_id('dynamic-table').text
d125=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=125&keywords=")
user125 = driver.find_element_by_id('dynamic-table').text
d126=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=126&keywords=")
user126 = driver.find_element_by_id('dynamic-table').text
d127=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=127&keywords=")
user127 = driver.find_element_by_id('dynamic-table').text
d128=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=128&keywords=")
user128 = driver.find_element_by_id('dynamic-table').text
d129=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=129&keywords=")
user129 = driver.find_element_by_id('dynamic-table').text
d130=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=130&keywords=")
user130 = driver.find_element_by_id('dynamic-table').text
d131=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=131&keywords=")
user131 = driver.find_element_by_id('dynamic-table').text
d132=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=132&keywords=")
user132 = driver.find_element_by_id('dynamic-table').text
d133=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=133&keywords=")
user133 = driver.find_element_by_id('dynamic-table').text
d134=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=134&keywords=")
user134 = driver.find_element_by_id('dynamic-table').text
d135=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=135&keywords=")
user135 = driver.find_element_by_id('dynamic-table').text
d136=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=136&keywords=")
user136 = driver.find_element_by_id('dynamic-table').text
d137=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=137&keywords=")
user137 = driver.find_element_by_id('dynamic-table').text
d138=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=138&keywords=")
user138 = driver.find_element_by_id('dynamic-table').text
d139=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=139&keywords=")
user139 = driver.find_element_by_id('dynamic-table').text
d140=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=140&keywords=")
user140 = driver.find_element_by_id('dynamic-table').text
d141=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=141&keywords=")
user141 = driver.find_element_by_id('dynamic-table').text
d142=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=142&keywords=")
user142 = driver.find_element_by_id('dynamic-table').text
d143=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=143&keywords=")
user143 = driver.find_element_by_id('dynamic-table').text
d144=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=144&keywords=")
user144 = driver.find_element_by_id('dynamic-table').text
d145=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=145&keywords=")
user145 = driver.find_element_by_id('dynamic-table').text
d146=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=146&keywords=")
user146 = driver.find_element_by_id('dynamic-table').text
d147=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=147&keywords=")
user147 = driver.find_element_by_id('dynamic-table').text
d148=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=148&keywords=")
user148 = driver.find_element_by_id('dynamic-table').text
d149=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=149&keywords=")
user149 = driver.find_element_by_id('dynamic-table').text
d150=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=150&keywords=")
user150 = driver.find_element_by_id('dynamic-table').text
d151=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=151&keywords=")
user151 = driver.find_element_by_id('dynamic-table').text
d152=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=152&keywords=")
user152 = driver.find_element_by_id('dynamic-table').text
d153=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=153&keywords=")
user153 = driver.find_element_by_id('dynamic-table').text
d154=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=154&keywords=")
user154 = driver.find_element_by_id('dynamic-table').text
d155=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=155&keywords=")
user155 = driver.find_element_by_id('dynamic-table').text
d156=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=156&keywords=")
user156 = driver.find_element_by_id('dynamic-table').text
d157=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=157&keywords=")
user157 = driver.find_element_by_id('dynamic-table').text
d158=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=158&keywords=")
user158 = driver.find_element_by_id('dynamic-table').text
d159=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=159&keywords=")
user159 = driver.find_element_by_id('dynamic-table').text
d160=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=160&keywords=")
user160 = driver.find_element_by_id('dynamic-table').text
d161=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=161&keywords=")
user161 = driver.find_element_by_id('dynamic-table').text
d162=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=162&keywords=")
user162 = driver.find_element_by_id('dynamic-table').text
d163=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=163&keywords=")
user163 = driver.find_element_by_id('dynamic-table').text
d164=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=164&keywords=")
user164 = driver.find_element_by_id('dynamic-table').text
d165=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=165&keywords=")
user165 = driver.find_element_by_id('dynamic-table').text
d166=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=166&keywords=")
user166 = driver.find_element_by_id('dynamic-table').text
d167=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=167&keywords=")
user167 = driver.find_element_by_id('dynamic-table').text
d168=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=168&keywords=")
user168 = driver.find_element_by_id('dynamic-table').text
d169=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=169&keywords=")
user169 = driver.find_element_by_id('dynamic-table').text
d170=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=170&keywords=")
user170 = driver.find_element_by_id('dynamic-table').text
d171=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=171&keywords=")
user171 = driver.find_element_by_id('dynamic-table').text
d172=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=172&keywords=")
user172 = driver.find_element_by_id('dynamic-table').text
d173=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=173&keywords=")
user173 = driver.find_element_by_id('dynamic-table').text
d174=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=174&keywords=")
user174 = driver.find_element_by_id('dynamic-table').text
d175=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=175&keywords=")
user175 = driver.find_element_by_id('dynamic-table').text
d176=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=176&keywords=")
user176 = driver.find_element_by_id('dynamic-table').text
d177=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=177&keywords=")
user177 = driver.find_element_by_id('dynamic-table').text
d178=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=178&keywords=")
user178 = driver.find_element_by_id('dynamic-table').text
d179=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=179&keywords=")
user179 = driver.find_element_by_id('dynamic-table').text
d180=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=180&keywords=")
user180 = driver.find_element_by_id('dynamic-table').text
d181=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=181&keywords=")
user181 = driver.find_element_by_id('dynamic-table').text
d182=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=182&keywords=")
user182 = driver.find_element_by_id('dynamic-table').text
d183=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=183&keywords=")
user183 = driver.find_element_by_id('dynamic-table').text
d184=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=184&keywords=")
user184 = driver.find_element_by_id('dynamic-table').text
d185=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=185&keywords=")
user185 = driver.find_element_by_id('dynamic-table').text
d186=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=186&keywords=")
user186 = driver.find_element_by_id('dynamic-table').text
d187=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=187&keywords=")
user187 = driver.find_element_by_id('dynamic-table').text
d188=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=188&keywords=")
user188 = driver.find_element_by_id('dynamic-table').text
d189=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=189&keywords=")
user189 = driver.find_element_by_id('dynamic-table').text
d190=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=190&keywords=")
user190 = driver.find_element_by_id('dynamic-table').text
d191=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=191&keywords=")
user191 = driver.find_element_by_id('dynamic-table').text
d192=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=192&keywords=")
user192 = driver.find_element_by_id('dynamic-table').text
d193=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=193&keywords=")
user193 = driver.find_element_by_id('dynamic-table').text
d194=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=194&keywords=")
user194 = driver.find_element_by_id('dynamic-table').text
d195=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=195&keywords=")
user195 = driver.find_element_by_id('dynamic-table').text
d196=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=196&keywords=")
user196 = driver.find_element_by_id('dynamic-table').text
d197=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=197&keywords=")
user197 = driver.find_element_by_id('dynamic-table').text
d198=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=198&keywords=")
user198 = driver.find_element_by_id('dynamic-table').text
d199=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=199&keywords=")
user199 = driver.find_element_by_id('dynamic-table').text
d200=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=200&keywords=")
user200 = driver.find_element_by_id('dynamic-table').text
d201=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=201&keywords=")
user201 = driver.find_element_by_id('dynamic-table').text
d202=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=202&keywords=")
user202 = driver.find_element_by_id('dynamic-table').text
d203=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=203&keywords=")
user203 = driver.find_element_by_id('dynamic-table').text
d204=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=204&keywords=")
user204 = driver.find_element_by_id('dynamic-table').text
d205=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=205&keywords=")
user205 = driver.find_element_by_id('dynamic-table').text
d206=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=206&keywords=")
user206 = driver.find_element_by_id('dynamic-table').text
d207=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=207&keywords=")
user207 = driver.find_element_by_id('dynamic-table').text
d208=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=208&keywords=")
user208 = driver.find_element_by_id('dynamic-table').text
d209=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=209&keywords=")
user209 = driver.find_element_by_id('dynamic-table').text
d210=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=210&keywords=")
user210 = driver.find_element_by_id('dynamic-table').text
d211=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=211&keywords=")
user211 = driver.find_element_by_id('dynamic-table').text
d212=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=212&keywords=")
user212 = driver.find_element_by_id('dynamic-table').text
d213=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=213&keywords=")
user213 = driver.find_element_by_id('dynamic-table').text
d214=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=214&keywords=")
user214 = driver.find_element_by_id('dynamic-table').text
d215=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=215&keywords=")
user215 = driver.find_element_by_id('dynamic-table').text
d216=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=216&keywords=")
user216 = driver.find_element_by_id('dynamic-table').text
d217=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=217&keywords=")
user217 = driver.find_element_by_id('dynamic-table').text
d218=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=218&keywords=")
user218 = driver.find_element_by_id('dynamic-table').text
d219=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=219&keywords=")
user219 = driver.find_element_by_id('dynamic-table').text
d220=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=220&keywords=")
user220 = driver.find_element_by_id('dynamic-table').text
d221=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=221&keywords=")
user221 = driver.find_element_by_id('dynamic-table').text
d222=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=222&keywords=")
user222 = driver.find_element_by_id('dynamic-table').text
d223=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=223&keywords=")
user223 = driver.find_element_by_id('dynamic-table').text
d224=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=224&keywords=")
user224 = driver.find_element_by_id('dynamic-table').text
d225=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=225&keywords=")
user225 = driver.find_element_by_id('dynamic-table').text
d226=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=226&keywords=")
user226 = driver.find_element_by_id('dynamic-table').text
d227=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=227&keywords=")
user227 = driver.find_element_by_id('dynamic-table').text
d228=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=228&keywords=")
user228 = driver.find_element_by_id('dynamic-table').text
d229=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=229&keywords=")
user229 = driver.find_element_by_id('dynamic-table').text
d230=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=230&keywords=")
user230 = driver.find_element_by_id('dynamic-table').text
d231=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=231&keywords=")
user231 = driver.find_element_by_id('dynamic-table').text
d232=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=232&keywords=")
user232 = driver.find_element_by_id('dynamic-table').text
d233=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=233&keywords=")
user233 = driver.find_element_by_id('dynamic-table').text
d234=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=234&keywords=")
user234 = driver.find_element_by_id('dynamic-table').text
d235=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=235&keywords=")
user235 = driver.find_element_by_id('dynamic-table').text
d236=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=236&keywords=")
user236 = driver.find_element_by_id('dynamic-table').text
d237=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=237&keywords=")
user237 = driver.find_element_by_id('dynamic-table').text
d238=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=238&keywords=")
user238 = driver.find_element_by_id('dynamic-table').text
d239=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=239&keywords=")
user239 = driver.find_element_by_id('dynamic-table').text
d240=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=240&keywords=")
user240 = driver.find_element_by_id('dynamic-table').text
d241=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=241&keywords=")
user241 = driver.find_element_by_id('dynamic-table').text
d242=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=242&keywords=")
user242 = driver.find_element_by_id('dynamic-table').text
d243=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=243&keywords=")
user243 = driver.find_element_by_id('dynamic-table').text
d244=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=244&keywords=")
user244 = driver.find_element_by_id('dynamic-table').text
d245=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=245&keywords=")
user245 = driver.find_element_by_id('dynamic-table').text
d246=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=246&keywords=")
user246 = driver.find_element_by_id('dynamic-table').text
d247=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=247&keywords=")
user247 = driver.find_element_by_id('dynamic-table').text
d248=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=248&keywords=")
user248 = driver.find_element_by_id('dynamic-table').text
d249=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=249&keywords=")
user249 = driver.find_element_by_id('dynamic-table').text
d250=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=250&keywords=")
user250 = driver.find_element_by_id('dynamic-table').text
d251=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=251&keywords=")
user251 = driver.find_element_by_id('dynamic-table').text
d252=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=252&keywords=")
user252 = driver.find_element_by_id('dynamic-table').text
d253=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=253&keywords=")
user253 = driver.find_element_by_id('dynamic-table').text
d254=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=254&keywords=")
user254 = driver.find_element_by_id('dynamic-table').text
d255=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=255&keywords=")
user255 = driver.find_element_by_id('dynamic-table').text
d256=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=256&keywords=")
user256 = driver.find_element_by_id('dynamic-table').text
d257=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=257&keywords=")
user257 = driver.find_element_by_id('dynamic-table').text
d258=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=258&keywords=")
user258 = driver.find_element_by_id('dynamic-table').text
d259=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=259&keywords=")
user259 = driver.find_element_by_id('dynamic-table').text
d260=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=260&keywords=")
user260 = driver.find_element_by_id('dynamic-table').text
d261=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=261&keywords=")
user261 = driver.find_element_by_id('dynamic-table').text
d262=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=262&keywords=")
user262 = driver.find_element_by_id('dynamic-table').text
d263=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=263&keywords=")
user263 = driver.find_element_by_id('dynamic-table').text
d264=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=264&keywords=")
user264 = driver.find_element_by_id('dynamic-table').text
d265=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=265&keywords=")
user265 = driver.find_element_by_id('dynamic-table').text
d266=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=266&keywords=")
user266 = driver.find_element_by_id('dynamic-table').text
d267=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=267&keywords=")
user267 = driver.find_element_by_id('dynamic-table').text
d268=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=268&keywords=")
user268 = driver.find_element_by_id('dynamic-table').text
d269=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=269&keywords=")
user269 = driver.find_element_by_id('dynamic-table').text
d270=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=270&keywords=")
user270 = driver.find_element_by_id('dynamic-table').text
d271=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=271&keywords=")
user271 = driver.find_element_by_id('dynamic-table').text
d272=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=272&keywords=")
user272 = driver.find_element_by_id('dynamic-table').text
d273=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=273&keywords=")
user273 = driver.find_element_by_id('dynamic-table').text
d274=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=274&keywords=")
user274 = driver.find_element_by_id('dynamic-table').text
d275=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=275&keywords=")
user275 = driver.find_element_by_id('dynamic-table').text
d276=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=276&keywords=")
user276 = driver.find_element_by_id('dynamic-table').text
d277=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=277&keywords=")
user277 = driver.find_element_by_id('dynamic-table').text
d278=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=278&keywords=")
user278 = driver.find_element_by_id('dynamic-table').text
d279=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=279&keywords=")
user279 = driver.find_element_by_id('dynamic-table').text
d280=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=280&keywords=")
user280 = driver.find_element_by_id('dynamic-table').text
d281=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=281&keywords=")
user281 = driver.find_element_by_id('dynamic-table').text
d282=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=282&keywords=")
user282 = driver.find_element_by_id('dynamic-table').text
d283=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=283&keywords=")
user283 = driver.find_element_by_id('dynamic-table').text
d284=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=284&keywords=")
user284 = driver.find_element_by_id('dynamic-table').text
d285=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=285&keywords=")
user285 = driver.find_element_by_id('dynamic-table').text
d286=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=286&keywords=")
user286 = driver.find_element_by_id('dynamic-table').text
d287=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=287&keywords=")
user287 = driver.find_element_by_id('dynamic-table').text
d288=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=288&keywords=")
user288 = driver.find_element_by_id('dynamic-table').text
d289=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=289&keywords=")
user289 = driver.find_element_by_id('dynamic-table').text
d290=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=290&keywords=")
user290 = driver.find_element_by_id('dynamic-table').text
d291=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=291&keywords=")
user291 = driver.find_element_by_id('dynamic-table').text
d292=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=292&keywords=")
user292 = driver.find_element_by_id('dynamic-table').text
d293=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=293&keywords=")
user293 = driver.find_element_by_id('dynamic-table').text
d294=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=294&keywords=")
user294 = driver.find_element_by_id('dynamic-table').text
d295=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=295&keywords=")
user295 = driver.find_element_by_id('dynamic-table').text
d296=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=296&keywords=")
user296 = driver.find_element_by_id('dynamic-table').text
d297=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=297&keywords=")
user297 = driver.find_element_by_id('dynamic-table').text
d298=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=298&keywords=")
user298 = driver.find_element_by_id('dynamic-table').text
d299=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=299&keywords=")
user299 = driver.find_element_by_id('dynamic-table').text
d300=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=300&keywords=")
user300 = driver.find_element_by_id('dynamic-table').text
d301=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=301&keywords=")
user301 = driver.find_element_by_id('dynamic-table').text
d302=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=302&keywords=")
user302 = driver.find_element_by_id('dynamic-table').text
d303=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=303&keywords=")
user303 = driver.find_element_by_id('dynamic-table').text
d304=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=304&keywords=")
user304 = driver.find_element_by_id('dynamic-table').text
d305=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=305&keywords=")
user305 = driver.find_element_by_id('dynamic-table').text
d306=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=306&keywords=")
user306 = driver.find_element_by_id('dynamic-table').text
d307=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=307&keywords=")
user307 = driver.find_element_by_id('dynamic-table').text
d308=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=308&keywords=")
user308 = driver.find_element_by_id('dynamic-table').text
d309=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=309&keywords=")
user309 = driver.find_element_by_id('dynamic-table').text
d310=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=310&keywords=")
user310 = driver.find_element_by_id('dynamic-table').text
d311=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=311&keywords=")
user311 = driver.find_element_by_id('dynamic-table').text
d312=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=312&keywords=")
user312 = driver.find_element_by_id('dynamic-table').text
d313=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=313&keywords=")
user313 = driver.find_element_by_id('dynamic-table').text
d314=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=314&keywords=")
user314 = driver.find_element_by_id('dynamic-table').text
d315=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=315&keywords=")
user315 = driver.find_element_by_id('dynamic-table').text
d316=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=316&keywords=")
user316 = driver.find_element_by_id('dynamic-table').text
d317=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=317&keywords=")
user317 = driver.find_element_by_id('dynamic-table').text
d318=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=318&keywords=")
user318 = driver.find_element_by_id('dynamic-table').text
d319=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=319&keywords=")
user319 = driver.find_element_by_id('dynamic-table').text
d320=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=320&keywords=")
user320 = driver.find_element_by_id('dynamic-table').text
d321=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=321&keywords=")
user321 = driver.find_element_by_id('dynamic-table').text
d322=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=322&keywords=")
user322 = driver.find_element_by_id('dynamic-table').text
d323=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=323&keywords=")
user323 = driver.find_element_by_id('dynamic-table').text
d324=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=324&keywords=")
user324 = driver.find_element_by_id('dynamic-table').text
d325=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=325&keywords=")
user325 = driver.find_element_by_id('dynamic-table').text
d326=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=326&keywords=")
user326 = driver.find_element_by_id('dynamic-table').text
d327=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=327&keywords=")
user327 = driver.find_element_by_id('dynamic-table').text
d328=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=328&keywords=")
user328 = driver.find_element_by_id('dynamic-table').text
d329=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=329&keywords=")
user329 = driver.find_element_by_id('dynamic-table').text
d330=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=330&keywords=")
user330 = driver.find_element_by_id('dynamic-table').text
d331=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=331&keywords=")
user331 = driver.find_element_by_id('dynamic-table').text
d332=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=332&keywords=")
user332 = driver.find_element_by_id('dynamic-table').text
d333=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=333&keywords=")
user333 = driver.find_element_by_id('dynamic-table').text
d334=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=334&keywords=")
user334 = driver.find_element_by_id('dynamic-table').text
d335=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=335&keywords=")
user335 = driver.find_element_by_id('dynamic-table').text
d336=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=336&keywords=")
user336 = driver.find_element_by_id('dynamic-table').text
d337=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=337&keywords=")
user337 = driver.find_element_by_id('dynamic-table').text
d338=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=338&keywords=")
user338 = driver.find_element_by_id('dynamic-table').text
d339=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=339&keywords=")
user339 = driver.find_element_by_id('dynamic-table').text
d340=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=340&keywords=")
user340 = driver.find_element_by_id('dynamic-table').text
d341=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=341&keywords=")
user341 = driver.find_element_by_id('dynamic-table').text
d342=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=342&keywords=")
user342 = driver.find_element_by_id('dynamic-table').text
d343=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=343&keywords=")
user343 = driver.find_element_by_id('dynamic-table').text
d344=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=344&keywords=")
user344 = driver.find_element_by_id('dynamic-table').text
d345=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=345&keywords=")
user345 = driver.find_element_by_id('dynamic-table').text
d346=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=346&keywords=")
user346 = driver.find_element_by_id('dynamic-table').text
d347=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=347&keywords=")
user347 = driver.find_element_by_id('dynamic-table').text
d348=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=348&keywords=")
user348 = driver.find_element_by_id('dynamic-table').text
d349=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=349&keywords=")
user349 = driver.find_element_by_id('dynamic-table').text
d350=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=350&keywords=")
user350 = driver.find_element_by_id('dynamic-table').text
d351=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=351&keywords=")
user351 = driver.find_element_by_id('dynamic-table').text
d352=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=352&keywords=")
user352 = driver.find_element_by_id('dynamic-table').text
d353=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=353&keywords=")
user353 = driver.find_element_by_id('dynamic-table').text
d354=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=354&keywords=")
user354 = driver.find_element_by_id('dynamic-table').text
d355=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=355&keywords=")
user355 = driver.find_element_by_id('dynamic-table').text
d356=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=356&keywords=")
user356 = driver.find_element_by_id('dynamic-table').text
d357=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=357&keywords=")
user357 = driver.find_element_by_id('dynamic-table').text
d358=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=358&keywords=")
user358 = driver.find_element_by_id('dynamic-table').text
d359=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=359&keywords=")
user359 = driver.find_element_by_id('dynamic-table').text
d360=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=360&keywords=")
user360 = driver.find_element_by_id('dynamic-table').text
d361=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=361&keywords=")
user361 = driver.find_element_by_id('dynamic-table').text
d362=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=362&keywords=")
user362 = driver.find_element_by_id('dynamic-table').text
d363=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=363&keywords=")
user363 = driver.find_element_by_id('dynamic-table').text
d364=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=364&keywords=")
user364 = driver.find_element_by_id('dynamic-table').text
d365=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=365&keywords=")
user365 = driver.find_element_by_id('dynamic-table').text
d366=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=366&keywords=")
user366 = driver.find_element_by_id('dynamic-table').text
d367=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=367&keywords=")
user367 = driver.find_element_by_id('dynamic-table').text
d368=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=368&keywords=")
user368 = driver.find_element_by_id('dynamic-table').text
d369=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=369&keywords=")
user369 = driver.find_element_by_id('dynamic-table').text
d370=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=370&keywords=")
user370 = driver.find_element_by_id('dynamic-table').text
d371=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=371&keywords=")
user371 = driver.find_element_by_id('dynamic-table').text
d372=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=372&keywords=")
user372 = driver.find_element_by_id('dynamic-table').text
d373=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=373&keywords=")
user373 = driver.find_element_by_id('dynamic-table').text
d374=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=374&keywords=")
user374 = driver.find_element_by_id('dynamic-table').text
d375=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=375&keywords=")
user375 = driver.find_element_by_id('dynamic-table').text
d376=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=376&keywords=")
user376 = driver.find_element_by_id('dynamic-table').text
d377=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=377&keywords=")
user377 = driver.find_element_by_id('dynamic-table').text
d378=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=378&keywords=")
user378 = driver.find_element_by_id('dynamic-table').text
d379=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=379&keywords=")
user379 = driver.find_element_by_id('dynamic-table').text
d380=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=380&keywords=")
user380 = driver.find_element_by_id('dynamic-table').text
d381=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=381&keywords=")
user381 = driver.find_element_by_id('dynamic-table').text
d382=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=382&keywords=")
user382 = driver.find_element_by_id('dynamic-table').text
d383=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=383&keywords=")
user383 = driver.find_element_by_id('dynamic-table').text
d384=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=384&keywords=")
user384 = driver.find_element_by_id('dynamic-table').text
d385=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=385&keywords=")
user385 = driver.find_element_by_id('dynamic-table').text
d386=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=386&keywords=")
user386 = driver.find_element_by_id('dynamic-table').text
d387=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=387&keywords=")
user387 = driver.find_element_by_id('dynamic-table').text
d388=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=388&keywords=")
user388 = driver.find_element_by_id('dynamic-table').text
d389=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=389&keywords=")
user389 = driver.find_element_by_id('dynamic-table').text
d390=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=390&keywords=")
user390 = driver.find_element_by_id('dynamic-table').text
d391=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=391&keywords=")
user391 = driver.find_element_by_id('dynamic-table').text
d392=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=392&keywords=")
user392 = driver.find_element_by_id('dynamic-table').text
d393=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=393&keywords=")
user393 = driver.find_element_by_id('dynamic-table').text
d394=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=394&keywords=")
user394 = driver.find_element_by_id('dynamic-table').text
d395=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=395&keywords=")
user395 = driver.find_element_by_id('dynamic-table').text
d396=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=396&keywords=")
user396 = driver.find_element_by_id('dynamic-table').text
d397=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=397&keywords=")
user397 = driver.find_element_by_id('dynamic-table').text
d398=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=398&keywords=")
user398 = driver.find_element_by_id('dynamic-table').text
d399=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=399&keywords=")
user399 = driver.find_element_by_id('dynamic-table').text
d400=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=400&keywords=")
user400 = driver.find_element_by_id('dynamic-table').text
d401=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=401&keywords=")
user401 = driver.find_element_by_id('dynamic-table').text
d402=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=402&keywords=")
user402 = driver.find_element_by_id('dynamic-table').text
d403=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=403&keywords=")
user403 = driver.find_element_by_id('dynamic-table').text
d404=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=404&keywords=")
user404 = driver.find_element_by_id('dynamic-table').text
d405=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=405&keywords=")
user405 = driver.find_element_by_id('dynamic-table').text
d406=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=406&keywords=")
user406 = driver.find_element_by_id('dynamic-table').text
d407=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=407&keywords=")
user407 = driver.find_element_by_id('dynamic-table').text
d408=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=408&keywords=")
user408 = driver.find_element_by_id('dynamic-table').text
d409=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=409&keywords=")
user409 = driver.find_element_by_id('dynamic-table').text
d410=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=410&keywords=")
user410 = driver.find_element_by_id('dynamic-table').text
d411=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=411&keywords=")
user411 = driver.find_element_by_id('dynamic-table').text
d412=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=412&keywords=")
user412 = driver.find_element_by_id('dynamic-table').text
d413=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=413&keywords=")
user413 = driver.find_element_by_id('dynamic-table').text
d414=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=414&keywords=")
user414 = driver.find_element_by_id('dynamic-table').text
d415=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=415&keywords=")
user415 = driver.find_element_by_id('dynamic-table').text
d416=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=416&keywords=")
user416 = driver.find_element_by_id('dynamic-table').text
d417=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=417&keywords=")
user417 = driver.find_element_by_id('dynamic-table').text
d418=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=418&keywords=")
user418 = driver.find_element_by_id('dynamic-table').text
d419=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=419&keywords=")
user419 = driver.find_element_by_id('dynamic-table').text
d420=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=420&keywords=")
user420 = driver.find_element_by_id('dynamic-table').text
d421=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=421&keywords=")
user421 = driver.find_element_by_id('dynamic-table').text
d422=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=422&keywords=")
user422 = driver.find_element_by_id('dynamic-table').text
d423=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=423&keywords=")
user423 = driver.find_element_by_id('dynamic-table').text
d424=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=424&keywords=")
user424 = driver.find_element_by_id('dynamic-table').text
d425=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=425&keywords=")
user425 = driver.find_element_by_id('dynamic-table').text
d426=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=426&keywords=")
user426 = driver.find_element_by_id('dynamic-table').text
d427=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=427&keywords=")
user427 = driver.find_element_by_id('dynamic-table').text
d428=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=428&keywords=")
user428 = driver.find_element_by_id('dynamic-table').text
d429=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=429&keywords=")
user429 = driver.find_element_by_id('dynamic-table').text
d430=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=430&keywords=")
user430 = driver.find_element_by_id('dynamic-table').text
d431=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=431&keywords=")
user431 = driver.find_element_by_id('dynamic-table').text
d432=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=432&keywords=")
user432 = driver.find_element_by_id('dynamic-table').text
d433=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=433&keywords=")
user433 = driver.find_element_by_id('dynamic-table').text
d434=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=434&keywords=")
user434 = driver.find_element_by_id('dynamic-table').text
d435=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=435&keywords=")
user435 = driver.find_element_by_id('dynamic-table').text
d436=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=436&keywords=")
user436 = driver.find_element_by_id('dynamic-table').text
d437=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=437&keywords=")
user437 = driver.find_element_by_id('dynamic-table').text
d438=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=438&keywords=")
user438 = driver.find_element_by_id('dynamic-table').text
d439=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=439&keywords=")
user439 = driver.find_element_by_id('dynamic-table').text
d440=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=440&keywords=")
user440 = driver.find_element_by_id('dynamic-table').text
d441=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=441&keywords=")
user441 = driver.find_element_by_id('dynamic-table').text
d442=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=442&keywords=")
user442 = driver.find_element_by_id('dynamic-table').text
d443=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=443&keywords=")
user443 = driver.find_element_by_id('dynamic-table').text
d444=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=444&keywords=")
user444 = driver.find_element_by_id('dynamic-table').text
d445=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=445&keywords=")
user445 = driver.find_element_by_id('dynamic-table').text
d446=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=446&keywords=")
user446 = driver.find_element_by_id('dynamic-table').text
d447=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=447&keywords=")
user447 = driver.find_element_by_id('dynamic-table').text
d448=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=448&keywords=")
user448 = driver.find_element_by_id('dynamic-table').text
d449=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=449&keywords=")
user449 = driver.find_element_by_id('dynamic-table').text
d450=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=450&keywords=")
user450 = driver.find_element_by_id('dynamic-table').text
d451=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=451&keywords=")
user451 = driver.find_element_by_id('dynamic-table').text
d452=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=452&keywords=")
user452 = driver.find_element_by_id('dynamic-table').text
d453=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=453&keywords=")
user453 = driver.find_element_by_id('dynamic-table').text
d454=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=454&keywords=")
user454 = driver.find_element_by_id('dynamic-table').text
d455=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=455&keywords=")
user455 = driver.find_element_by_id('dynamic-table').text
d456=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=456&keywords=")
user456 = driver.find_element_by_id('dynamic-table').text
d457=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=457&keywords=")
user457 = driver.find_element_by_id('dynamic-table').text
d458=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=458&keywords=")
user458 = driver.find_element_by_id('dynamic-table').text
d459=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=459&keywords=")
user459 = driver.find_element_by_id('dynamic-table').text
d460=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=460&keywords=")
user460 = driver.find_element_by_id('dynamic-table').text
d461=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=461&keywords=")
user461 = driver.find_element_by_id('dynamic-table').text
d462=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=462&keywords=")
user462 = driver.find_element_by_id('dynamic-table').text
d463=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=463&keywords=")
user463 = driver.find_element_by_id('dynamic-table').text
d464=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=464&keywords=")
user464 = driver.find_element_by_id('dynamic-table').text
d465=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=465&keywords=")
user465 = driver.find_element_by_id('dynamic-table').text
d466=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=466&keywords=")
user466 = driver.find_element_by_id('dynamic-table').text
d467=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=467&keywords=")
user467 = driver.find_element_by_id('dynamic-table').text
d468=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=468&keywords=")
user468 = driver.find_element_by_id('dynamic-table').text
d469=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=469&keywords=")
user469 = driver.find_element_by_id('dynamic-table').text
d470=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=470&keywords=")
user470 = driver.find_element_by_id('dynamic-table').text
d471=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=471&keywords=")
user471 = driver.find_element_by_id('dynamic-table').text
d472=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=472&keywords=")
user472 = driver.find_element_by_id('dynamic-table').text
d473=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=473&keywords=")
user473 = driver.find_element_by_id('dynamic-table').text
d474=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=474&keywords=")
user474 = driver.find_element_by_id('dynamic-table').text
d475=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=475&keywords=")
user475 = driver.find_element_by_id('dynamic-table').text
d476=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=476&keywords=")
user476 = driver.find_element_by_id('dynamic-table').text
d477=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=477&keywords=")
user477 = driver.find_element_by_id('dynamic-table').text
d478=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=478&keywords=")
user478 = driver.find_element_by_id('dynamic-table').text
d479=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=479&keywords=")
user479 = driver.find_element_by_id('dynamic-table').text
d480=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=480&keywords=")
user480 = driver.find_element_by_id('dynamic-table').text
d481=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=481&keywords=")
user481 = driver.find_element_by_id('dynamic-table').text
d482=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=482&keywords=")
user482 = driver.find_element_by_id('dynamic-table').text
d483=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=483&keywords=")
user483 = driver.find_element_by_id('dynamic-table').text
d484=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=484&keywords=")
user484 = driver.find_element_by_id('dynamic-table').text
d485=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=485&keywords=")
user485 = driver.find_element_by_id('dynamic-table').text
d486=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=486&keywords=")
user486 = driver.find_element_by_id('dynamic-table').text
d487=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=487&keywords=")
user487 = driver.find_element_by_id('dynamic-table').text
d488=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=488&keywords=")
user488 = driver.find_element_by_id('dynamic-table').text
d489=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=489&keywords=")
user489 = driver.find_element_by_id('dynamic-table').text
d490=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=490&keywords=")
user490 = driver.find_element_by_id('dynamic-table').text
d491=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=491&keywords=")
user491 = driver.find_element_by_id('dynamic-table').text
d492=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=492&keywords=")
user492 = driver.find_element_by_id('dynamic-table').text
d493=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=493&keywords=")
user493 = driver.find_element_by_id('dynamic-table').text
d494=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=494&keywords=")
user494 = driver.find_element_by_id('dynamic-table').text
d495=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=495&keywords=")
user495 = driver.find_element_by_id('dynamic-table').text
d496=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=496&keywords=")
user496 = driver.find_element_by_id('dynamic-table').text
d497=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=497&keywords=")
user497 = driver.find_element_by_id('dynamic-table').text
d498=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=498&keywords=")
user498 = driver.find_element_by_id('dynamic-table').text
d499=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=499&keywords=")
user499 = driver.find_element_by_id('dynamic-table').text
d500=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=500&keywords=")
user500 = driver.find_element_by_id('dynamic-table').text
d501=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=501&keywords=")
user501 = driver.find_element_by_id('dynamic-table').text
d502=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=502&keywords=")
user502 = driver.find_element_by_id('dynamic-table').text
d503=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=503&keywords=")
user503 = driver.find_element_by_id('dynamic-table').text
d504=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=504&keywords=")
user504 = driver.find_element_by_id('dynamic-table').text
d505=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=505&keywords=")
user505 = driver.find_element_by_id('dynamic-table').text
d506=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=506&keywords=")
user506 = driver.find_element_by_id('dynamic-table').text
d507=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=507&keywords=")
user507 = driver.find_element_by_id('dynamic-table').text
d508=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=508&keywords=")
user508 = driver.find_element_by_id('dynamic-table').text
d509=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=509&keywords=")
user509 = driver.find_element_by_id('dynamic-table').text
d510=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=510&keywords=")
user510 = driver.find_element_by_id('dynamic-table').text
d511=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=511&keywords=")
user511 = driver.find_element_by_id('dynamic-table').text
d512=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=512&keywords=")
user512 = driver.find_element_by_id('dynamic-table').text
d513=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=513&keywords=")
user513 = driver.find_element_by_id('dynamic-table').text
d514=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=514&keywords=")
user514 = driver.find_element_by_id('dynamic-table').text
d515=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=515&keywords=")
user515 = driver.find_element_by_id('dynamic-table').text
d516=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=516&keywords=")
user516 = driver.find_element_by_id('dynamic-table').text
d517=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=517&keywords=")
user517 = driver.find_element_by_id('dynamic-table').text
d518=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=518&keywords=")
user518 = driver.find_element_by_id('dynamic-table').text
d519=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=519&keywords=")
user519 = driver.find_element_by_id('dynamic-table').text
d520=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=520&keywords=")
user520 = driver.find_element_by_id('dynamic-table').text
d521=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=521&keywords=")
user521 = driver.find_element_by_id('dynamic-table').text
d522=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=522&keywords=")
user522 = driver.find_element_by_id('dynamic-table').text
d523=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=523&keywords=")
user523 = driver.find_element_by_id('dynamic-table').text
d524=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=524&keywords=")
user524 = driver.find_element_by_id('dynamic-table').text
d525=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=525&keywords=")
user525 = driver.find_element_by_id('dynamic-table').text
d526=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=526&keywords=")
user526 = driver.find_element_by_id('dynamic-table').text
d527=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=527&keywords=")
user527 = driver.find_element_by_id('dynamic-table').text
d528=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=528&keywords=")
user528 = driver.find_element_by_id('dynamic-table').text
d529=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=529&keywords=")
user529 = driver.find_element_by_id('dynamic-table').text
d530=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=530&keywords=")
user530 = driver.find_element_by_id('dynamic-table').text
d531=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=531&keywords=")
user531 = driver.find_element_by_id('dynamic-table').text
d532=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=532&keywords=")
user532 = driver.find_element_by_id('dynamic-table').text
d533=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=533&keywords=")
user533 = driver.find_element_by_id('dynamic-table').text
d534=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=534&keywords=")
user534 = driver.find_element_by_id('dynamic-table').text
d535=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=535&keywords=")
user535 = driver.find_element_by_id('dynamic-table').text
d536=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=536&keywords=")
user536 = driver.find_element_by_id('dynamic-table').text
d537=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=537&keywords=")
user537 = driver.find_element_by_id('dynamic-table').text
d538=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=538&keywords=")
user538 = driver.find_element_by_id('dynamic-table').text
d539=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=539&keywords=")
user539 = driver.find_element_by_id('dynamic-table').text
d540=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=540&keywords=")
user540 = driver.find_element_by_id('dynamic-table').text
d541=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=541&keywords=")
user541 = driver.find_element_by_id('dynamic-table').text
d542=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=542&keywords=")
user542 = driver.find_element_by_id('dynamic-table').text
d543=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=543&keywords=")
user543 = driver.find_element_by_id('dynamic-table').text
d544=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=544&keywords=")
user544 = driver.find_element_by_id('dynamic-table').text
d545=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=545&keywords=")
user545 = driver.find_element_by_id('dynamic-table').text
d546=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=546&keywords=")
user546 = driver.find_element_by_id('dynamic-table').text
d547=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=547&keywords=")
user547 = driver.find_element_by_id('dynamic-table').text
d548=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=548&keywords=")
user548 = driver.find_element_by_id('dynamic-table').text
d549=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=549&keywords=")
user549 = driver.find_element_by_id('dynamic-table').text
d550=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=550&keywords=")
user550 = driver.find_element_by_id('dynamic-table').text
d551=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=551&keywords=")
user551 = driver.find_element_by_id('dynamic-table').text
d552=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=552&keywords=")
user552 = driver.find_element_by_id('dynamic-table').text
d553=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=553&keywords=")
user553 = driver.find_element_by_id('dynamic-table').text
d554=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=554&keywords=")
user554 = driver.find_element_by_id('dynamic-table').text
d555=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=555&keywords=")
user555 = driver.find_element_by_id('dynamic-table').text
d556=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=556&keywords=")
user556 = driver.find_element_by_id('dynamic-table').text
d557=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=557&keywords=")
user557 = driver.find_element_by_id('dynamic-table').text
d558=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=558&keywords=")
user558 = driver.find_element_by_id('dynamic-table').text
d559=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=559&keywords=")
user559 = driver.find_element_by_id('dynamic-table').text
d560=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=560&keywords=")
user560 = driver.find_element_by_id('dynamic-table').text
d561=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=561&keywords=")
user561 = driver.find_element_by_id('dynamic-table').text
d562=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=562&keywords=")
user562 = driver.find_element_by_id('dynamic-table').text
d563=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=563&keywords=")
user563 = driver.find_element_by_id('dynamic-table').text
d564=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=564&keywords=")
user564 = driver.find_element_by_id('dynamic-table').text
d565=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=565&keywords=")
user565 = driver.find_element_by_id('dynamic-table').text
d566=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=566&keywords=")
user566 = driver.find_element_by_id('dynamic-table').text
d567=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=567&keywords=")
user567 = driver.find_element_by_id('dynamic-table').text
d568=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=568&keywords=")
user568 = driver.find_element_by_id('dynamic-table').text
d569=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=569&keywords=")
user569 = driver.find_element_by_id('dynamic-table').text
d570=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=570&keywords=")
user570 = driver.find_element_by_id('dynamic-table').text
d571=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=571&keywords=")
user571 = driver.find_element_by_id('dynamic-table').text
d572=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=572&keywords=")
user572 = driver.find_element_by_id('dynamic-table').text
d573=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=573&keywords=")
user573 = driver.find_element_by_id('dynamic-table').text
d574=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=574&keywords=")
user574 = driver.find_element_by_id('dynamic-table').text
d575=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=575&keywords=")
user575 = driver.find_element_by_id('dynamic-table').text
d576=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=576&keywords=")
user576 = driver.find_element_by_id('dynamic-table').text
d577=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=577&keywords=")
user577 = driver.find_element_by_id('dynamic-table').text
d578=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=578&keywords=")
user578 = driver.find_element_by_id('dynamic-table').text
d579=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=579&keywords=")
user579 = driver.find_element_by_id('dynamic-table').text
d580=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=580&keywords=")
user580 = driver.find_element_by_id('dynamic-table').text
d581=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=581&keywords=")
user581 = driver.find_element_by_id('dynamic-table').text
d582=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=582&keywords=")
user582 = driver.find_element_by_id('dynamic-table').text
d583=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=583&keywords=")
user583 = driver.find_element_by_id('dynamic-table').text
d584=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=584&keywords=")
user584 = driver.find_element_by_id('dynamic-table').text
d585=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=585&keywords=")
user585 = driver.find_element_by_id('dynamic-table').text
d586=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=586&keywords=")
user586 = driver.find_element_by_id('dynamic-table').text
d587=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=587&keywords=")
user587 = driver.find_element_by_id('dynamic-table').text
d588=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=588&keywords=")
user588 = driver.find_element_by_id('dynamic-table').text
d589=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=589&keywords=")
user589 = driver.find_element_by_id('dynamic-table').text
d590=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=590&keywords=")
user590 = driver.find_element_by_id('dynamic-table').text
d591=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=591&keywords=")
user591 = driver.find_element_by_id('dynamic-table').text
d592=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=592&keywords=")
user592 = driver.find_element_by_id('dynamic-table').text
d593=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=593&keywords=")
user593 = driver.find_element_by_id('dynamic-table').text
d594=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=594&keywords=")
user594 = driver.find_element_by_id('dynamic-table').text
d595=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=595&keywords=")
user595 = driver.find_element_by_id('dynamic-table').text
d596=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=596&keywords=")
user596 = driver.find_element_by_id('dynamic-table').text
d597=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=597&keywords=")
user597 = driver.find_element_by_id('dynamic-table').text
d598=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=598&keywords=")
user598 = driver.find_element_by_id('dynamic-table').text
d599=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=599&keywords=")
user599 = driver.find_element_by_id('dynamic-table').text
d600=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=600&keywords=")
user600 = driver.find_element_by_id('dynamic-table').text
d601=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=601&keywords=")
user601 = driver.find_element_by_id('dynamic-table').text
d602=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=602&keywords=")
user602 = driver.find_element_by_id('dynamic-table').text
d603=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=603&keywords=")
user603 = driver.find_element_by_id('dynamic-table').text
d604=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=604&keywords=")
user604 = driver.find_element_by_id('dynamic-table').text
d605=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=605&keywords=")
user605 = driver.find_element_by_id('dynamic-table').text
d606=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=606&keywords=")
user606 = driver.find_element_by_id('dynamic-table').text
d607=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=607&keywords=")
user607 = driver.find_element_by_id('dynamic-table').text
d608=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=608&keywords=")
user608 = driver.find_element_by_id('dynamic-table').text
d609=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=609&keywords=")
user609 = driver.find_element_by_id('dynamic-table').text
d610=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=610&keywords=")
user610 = driver.find_element_by_id('dynamic-table').text
d611=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=611&keywords=")
user611 = driver.find_element_by_id('dynamic-table').text
d612=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=612&keywords=")
user612 = driver.find_element_by_id('dynamic-table').text
d613=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=613&keywords=")
user613 = driver.find_element_by_id('dynamic-table').text
d614=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=614&keywords=")
user614 = driver.find_element_by_id('dynamic-table').text
d615=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=615&keywords=")
user615 = driver.find_element_by_id('dynamic-table').text
d616=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=616&keywords=")
user616 = driver.find_element_by_id('dynamic-table').text
d617=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=617&keywords=")
user617 = driver.find_element_by_id('dynamic-table').text
d618=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=618&keywords=")
user618 = driver.find_element_by_id('dynamic-table').text
d619=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=619&keywords=")
user619 = driver.find_element_by_id('dynamic-table').text
d620=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=620&keywords=")
user620 = driver.find_element_by_id('dynamic-table').text
d621=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=621&keywords=")
user621 = driver.find_element_by_id('dynamic-table').text
d622=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=622&keywords=")
user622 = driver.find_element_by_id('dynamic-table').text
d623=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=623&keywords=")
user623 = driver.find_element_by_id('dynamic-table').text
d624=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=624&keywords=")
user624 = driver.find_element_by_id('dynamic-table').text
d625=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=625&keywords=")
user625 = driver.find_element_by_id('dynamic-table').text
d626=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=626&keywords=")
user626 = driver.find_element_by_id('dynamic-table').text
d627=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=627&keywords=")
user627 = driver.find_element_by_id('dynamic-table').text
d628=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=628&keywords=")
user628 = driver.find_element_by_id('dynamic-table').text
d629=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=629&keywords=")
user629 = driver.find_element_by_id('dynamic-table').text
d630=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=630&keywords=")
user630 = driver.find_element_by_id('dynamic-table').text
d631=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=631&keywords=")
user631 = driver.find_element_by_id('dynamic-table').text
d632=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=632&keywords=")
user632 = driver.find_element_by_id('dynamic-table').text
d633=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=633&keywords=")
user633 = driver.find_element_by_id('dynamic-table').text
d634=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=634&keywords=")
user634 = driver.find_element_by_id('dynamic-table').text
d635=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=635&keywords=")
user635 = driver.find_element_by_id('dynamic-table').text
d636=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=636&keywords=")
user636 = driver.find_element_by_id('dynamic-table').text
d637=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=637&keywords=")
user637 = driver.find_element_by_id('dynamic-table').text
d638=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=638&keywords=")
user638 = driver.find_element_by_id('dynamic-table').text
d639=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=639&keywords=")
user639 = driver.find_element_by_id('dynamic-table').text
d640=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=640&keywords=")
user640 = driver.find_element_by_id('dynamic-table').text
d641=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=641&keywords=")
user641 = driver.find_element_by_id('dynamic-table').text
d642=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=642&keywords=")
user642 = driver.find_element_by_id('dynamic-table').text
d643=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=643&keywords=")
user643 = driver.find_element_by_id('dynamic-table').text
d644=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=644&keywords=")
user644 = driver.find_element_by_id('dynamic-table').text
d645=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=645&keywords=")
user645 = driver.find_element_by_id('dynamic-table').text
d646=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=646&keywords=")
user646 = driver.find_element_by_id('dynamic-table').text
d647=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=647&keywords=")
user647 = driver.find_element_by_id('dynamic-table').text
d648=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=648&keywords=")
user648 = driver.find_element_by_id('dynamic-table').text
d649=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=649&keywords=")
user649 = driver.find_element_by_id('dynamic-table').text
d650=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=650&keywords=")
user650 = driver.find_element_by_id('dynamic-table').text
d651=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=651&keywords=")
user651 = driver.find_element_by_id('dynamic-table').text
d652=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=652&keywords=")
user652 = driver.find_element_by_id('dynamic-table').text
d653=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=653&keywords=")
user653 = driver.find_element_by_id('dynamic-table').text
d654=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=654&keywords=")
user654 = driver.find_element_by_id('dynamic-table').text
d655=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=655&keywords=")
user655 = driver.find_element_by_id('dynamic-table').text
d656=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=656&keywords=")
user656 = driver.find_element_by_id('dynamic-table').text
d657=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=657&keywords=")
user657 = driver.find_element_by_id('dynamic-table').text
d658=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=658&keywords=")
user658 = driver.find_element_by_id('dynamic-table').text
d659=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=659&keywords=")
user659 = driver.find_element_by_id('dynamic-table').text
d660=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=660&keywords=")
user660 = driver.find_element_by_id('dynamic-table').text
d661=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=661&keywords=")
user661 = driver.find_element_by_id('dynamic-table').text
d662=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=662&keywords=")
user662 = driver.find_element_by_id('dynamic-table').text
d663=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=663&keywords=")
user663 = driver.find_element_by_id('dynamic-table').text
d664=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=664&keywords=")
user664 = driver.find_element_by_id('dynamic-table').text
d665=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=665&keywords=")
user665 = driver.find_element_by_id('dynamic-table').text
d666=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=666&keywords=")
user666 = driver.find_element_by_id('dynamic-table').text
d667=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=667&keywords=")
user667 = driver.find_element_by_id('dynamic-table').text
d668=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=668&keywords=")
user668 = driver.find_element_by_id('dynamic-table').text
d669=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=669&keywords=")
user669 = driver.find_element_by_id('dynamic-table').text
d670=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=670&keywords=")
user670 = driver.find_element_by_id('dynamic-table').text
d671=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=671&keywords=")
user671 = driver.find_element_by_id('dynamic-table').text
d672=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=672&keywords=")
user672 = driver.find_element_by_id('dynamic-table').text
d673=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=673&keywords=")
user673 = driver.find_element_by_id('dynamic-table').text
d674=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=674&keywords=")
user674 = driver.find_element_by_id('dynamic-table').text
d675=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=675&keywords=")
user675 = driver.find_element_by_id('dynamic-table').text
d676=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=676&keywords=")
user676 = driver.find_element_by_id('dynamic-table').text
d677=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=677&keywords=")
user677 = driver.find_element_by_id('dynamic-table').text
d678=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=678&keywords=")
user678 = driver.find_element_by_id('dynamic-table').text
d679=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=679&keywords=")
user679 = driver.find_element_by_id('dynamic-table').text
d680=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=680&keywords=")
user680 = driver.find_element_by_id('dynamic-table').text
d681=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=681&keywords=")
user681 = driver.find_element_by_id('dynamic-table').text
d682=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=682&keywords=")
user682 = driver.find_element_by_id('dynamic-table').text
d683=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=683&keywords=")
user683 = driver.find_element_by_id('dynamic-table').text
d684=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=684&keywords=")
user684 = driver.find_element_by_id('dynamic-table').text
d685=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=685&keywords=")
user685 = driver.find_element_by_id('dynamic-table').text
d686=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=686&keywords=")
user686 = driver.find_element_by_id('dynamic-table').text
d687=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=687&keywords=")
user687 = driver.find_element_by_id('dynamic-table').text
d688=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=688&keywords=")
user688 = driver.find_element_by_id('dynamic-table').text
d689=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=689&keywords=")
user689 = driver.find_element_by_id('dynamic-table').text
d690=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=690&keywords=")
user690 = driver.find_element_by_id('dynamic-table').text
d691=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=691&keywords=")
user691 = driver.find_element_by_id('dynamic-table').text
d692=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=692&keywords=")
user692 = driver.find_element_by_id('dynamic-table').text
d693=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=693&keywords=")
user693 = driver.find_element_by_id('dynamic-table').text
d694=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=694&keywords=")
user694 = driver.find_element_by_id('dynamic-table').text
d695=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=695&keywords=")
user695 = driver.find_element_by_id('dynamic-table').text
d696=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=696&keywords=")
user696 = driver.find_element_by_id('dynamic-table').text
d697=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=697&keywords=")
user697 = driver.find_element_by_id('dynamic-table').text
d698=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=698&keywords=")
user698 = driver.find_element_by_id('dynamic-table').text
d699=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=699&keywords=")
user699 = driver.find_element_by_id('dynamic-table').text
d700=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=700&keywords=")
user700 = driver.find_element_by_id('dynamic-table').text
d701=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=701&keywords=")
user701 = driver.find_element_by_id('dynamic-table').text
d702=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=702&keywords=")
user702 = driver.find_element_by_id('dynamic-table').text
d703=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=703&keywords=")
user703 = driver.find_element_by_id('dynamic-table').text
d704=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=704&keywords=")
user704 = driver.find_element_by_id('dynamic-table').text
d705=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=705&keywords=")
user705 = driver.find_element_by_id('dynamic-table').text
d706=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=706&keywords=")
user706 = driver.find_element_by_id('dynamic-table').text
d707=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=707&keywords=")
user707 = driver.find_element_by_id('dynamic-table').text
d708=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=708&keywords=")
user708 = driver.find_element_by_id('dynamic-table').text
d709=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=709&keywords=")
user709 = driver.find_element_by_id('dynamic-table').text
d710=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=710&keywords=")
user710 = driver.find_element_by_id('dynamic-table').text
d711=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=711&keywords=")
user711 = driver.find_element_by_id('dynamic-table').text
d712=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=712&keywords=")
user712 = driver.find_element_by_id('dynamic-table').text
d713=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=713&keywords=")
user713 = driver.find_element_by_id('dynamic-table').text
d714=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=714&keywords=")
user714 = driver.find_element_by_id('dynamic-table').text
d715=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=715&keywords=")
user715 = driver.find_element_by_id('dynamic-table').text
d716=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=716&keywords=")
user716 = driver.find_element_by_id('dynamic-table').text
d717=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=717&keywords=")
user717 = driver.find_element_by_id('dynamic-table').text
d718=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=718&keywords=")
user718 = driver.find_element_by_id('dynamic-table').text
d719=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=719&keywords=")
user719 = driver.find_element_by_id('dynamic-table').text
d720=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=720&keywords=")
user720 = driver.find_element_by_id('dynamic-table').text
d721=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=721&keywords=")
user721 = driver.find_element_by_id('dynamic-table').text
d722=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=722&keywords=")
user722 = driver.find_element_by_id('dynamic-table').text
d723=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=723&keywords=")
user723 = driver.find_element_by_id('dynamic-table').text
d724=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=724&keywords=")
user724 = driver.find_element_by_id('dynamic-table').text
d725=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=725&keywords=")
user725 = driver.find_element_by_id('dynamic-table').text
d726=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=726&keywords=")
user726 = driver.find_element_by_id('dynamic-table').text
d727=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=727&keywords=")
user727 = driver.find_element_by_id('dynamic-table').text
d728=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=728&keywords=")
user728 = driver.find_element_by_id('dynamic-table').text
d729=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=729&keywords=")
user729 = driver.find_element_by_id('dynamic-table').text
d730=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=730&keywords=")
user730 = driver.find_element_by_id('dynamic-table').text
d731=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=731&keywords=")
user731 = driver.find_element_by_id('dynamic-table').text
d732=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=732&keywords=")
user732 = driver.find_element_by_id('dynamic-table').text
d733=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=733&keywords=")
user733 = driver.find_element_by_id('dynamic-table').text
d734=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=734&keywords=")
user734 = driver.find_element_by_id('dynamic-table').text
d735=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=735&keywords=")
user735 = driver.find_element_by_id('dynamic-table').text
d736=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=736&keywords=")
user736 = driver.find_element_by_id('dynamic-table').text
d737=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=737&keywords=")
user737 = driver.find_element_by_id('dynamic-table').text
d738=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=738&keywords=")
user738 = driver.find_element_by_id('dynamic-table').text
d739=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=739&keywords=")
user739 = driver.find_element_by_id('dynamic-table').text
d740=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=740&keywords=")
user740 = driver.find_element_by_id('dynamic-table').text
d741=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=741&keywords=")
user741 = driver.find_element_by_id('dynamic-table').text
d742=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=742&keywords=")
user742 = driver.find_element_by_id('dynamic-table').text
d743=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=743&keywords=")
user743 = driver.find_element_by_id('dynamic-table').text
d744=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=744&keywords=")
user744 = driver.find_element_by_id('dynamic-table').text
d745=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=745&keywords=")
user745 = driver.find_element_by_id('dynamic-table').text
d746=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=746&keywords=")
user746 = driver.find_element_by_id('dynamic-table').text
d747=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=747&keywords=")
user747 = driver.find_element_by_id('dynamic-table').text
d748=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=748&keywords=")
user748 = driver.find_element_by_id('dynamic-table').text
d749=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=749&keywords=")
user749 = driver.find_element_by_id('dynamic-table').text
d750=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=750&keywords=")
user750 = driver.find_element_by_id('dynamic-table').text
d751=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=751&keywords=")
user751 = driver.find_element_by_id('dynamic-table').text
d752=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=752&keywords=")
user752 = driver.find_element_by_id('dynamic-table').text
d753=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=753&keywords=")
user753 = driver.find_element_by_id('dynamic-table').text
d754=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=754&keywords=")
user754 = driver.find_element_by_id('dynamic-table').text
d755=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=755&keywords=")
user755 = driver.find_element_by_id('dynamic-table').text
d756=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=756&keywords=")
user756 = driver.find_element_by_id('dynamic-table').text
d757=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=757&keywords=")
user757 = driver.find_element_by_id('dynamic-table').text
d758=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=758&keywords=")
user758 = driver.find_element_by_id('dynamic-table').text
d759=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=759&keywords=")
user759 = driver.find_element_by_id('dynamic-table').text
d760=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=760&keywords=")
user760 = driver.find_element_by_id('dynamic-table').text
d761=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=761&keywords=")
user761 = driver.find_element_by_id('dynamic-table').text
d762=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=762&keywords=")
user762 = driver.find_element_by_id('dynamic-table').text
d763=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=763&keywords=")
user763 = driver.find_element_by_id('dynamic-table').text
d764=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=764&keywords=")
user764 = driver.find_element_by_id('dynamic-table').text
d765=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=765&keywords=")
user765 = driver.find_element_by_id('dynamic-table').text
d766=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=766&keywords=")
user766 = driver.find_element_by_id('dynamic-table').text
d767=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=767&keywords=")
user767 = driver.find_element_by_id('dynamic-table').text
d768=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=768&keywords=")
user768 = driver.find_element_by_id('dynamic-table').text
d769=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=769&keywords=")
user769 = driver.find_element_by_id('dynamic-table').text
d770=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=770&keywords=")
user770 = driver.find_element_by_id('dynamic-table').text
d771=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=771&keywords=")
user771 = driver.find_element_by_id('dynamic-table').text
d772=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=772&keywords=")
user772 = driver.find_element_by_id('dynamic-table').text
d773=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=773&keywords=")
user773 = driver.find_element_by_id('dynamic-table').text
d774=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=774&keywords=")
user774 = driver.find_element_by_id('dynamic-table').text
d775=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=775&keywords=")
user775 = driver.find_element_by_id('dynamic-table').text
d776=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=776&keywords=")
user776 = driver.find_element_by_id('dynamic-table').text
d777=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=777&keywords=")
user777 = driver.find_element_by_id('dynamic-table').text
d778=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=778&keywords=")
user778 = driver.find_element_by_id('dynamic-table').text
d779=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=779&keywords=")
user779 = driver.find_element_by_id('dynamic-table').text
d780=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=780&keywords=")
user780 = driver.find_element_by_id('dynamic-table').text
d781=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=781&keywords=")
user781 = driver.find_element_by_id('dynamic-table').text
d782=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=782&keywords=")
user782 = driver.find_element_by_id('dynamic-table').text
d783=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=783&keywords=")
user783 = driver.find_element_by_id('dynamic-table').text
d784=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=784&keywords=")
user784 = driver.find_element_by_id('dynamic-table').text
d785=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=785&keywords=")
user785 = driver.find_element_by_id('dynamic-table').text
d786=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=786&keywords=")
user786 = driver.find_element_by_id('dynamic-table').text
d787=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=787&keywords=")
user787 = driver.find_element_by_id('dynamic-table').text
d788=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=788&keywords=")
user788 = driver.find_element_by_id('dynamic-table').text
d789=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=789&keywords=")
user789 = driver.find_element_by_id('dynamic-table').text
d790=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=790&keywords=")
user790 = driver.find_element_by_id('dynamic-table').text
d791=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=791&keywords=")
user791 = driver.find_element_by_id('dynamic-table').text
d792=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=792&keywords=")
user792 = driver.find_element_by_id('dynamic-table').text
d793=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=793&keywords=")
user793 = driver.find_element_by_id('dynamic-table').text
d794=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=794&keywords=")
user794 = driver.find_element_by_id('dynamic-table').text
d795=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=795&keywords=")
user795 = driver.find_element_by_id('dynamic-table').text
d796=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=796&keywords=")
user796 = driver.find_element_by_id('dynamic-table').text
d797=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=797&keywords=")
user797 = driver.find_element_by_id('dynamic-table').text
d798=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=798&keywords=")
user798 = driver.find_element_by_id('dynamic-table').text
d799=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=799&keywords=")
user799 = driver.find_element_by_id('dynamic-table').text
d800=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=800&keywords=")
user800 = driver.find_element_by_id('dynamic-table').text
d801=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=801&keywords=")
user801 = driver.find_element_by_id('dynamic-table').text
d802=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=802&keywords=")
user802 = driver.find_element_by_id('dynamic-table').text
d803=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=803&keywords=")
user803 = driver.find_element_by_id('dynamic-table').text
d804=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=804&keywords=")
user804 = driver.find_element_by_id('dynamic-table').text
d805=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=805&keywords=")
user805 = driver.find_element_by_id('dynamic-table').text
d806=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=806&keywords=")
user806 = driver.find_element_by_id('dynamic-table').text
d807=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=807&keywords=")
user807 = driver.find_element_by_id('dynamic-table').text
d808=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=808&keywords=")
user808 = driver.find_element_by_id('dynamic-table').text
d809=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=809&keywords=")
user809 = driver.find_element_by_id('dynamic-table').text
d810=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=810&keywords=")
user810 = driver.find_element_by_id('dynamic-table').text
d811=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=811&keywords=")
user811 = driver.find_element_by_id('dynamic-table').text
d812=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=812&keywords=")
user812 = driver.find_element_by_id('dynamic-table').text
d813=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=813&keywords=")
user813 = driver.find_element_by_id('dynamic-table').text
d814=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=814&keywords=")
user814 = driver.find_element_by_id('dynamic-table').text
d815=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=815&keywords=")
user815 = driver.find_element_by_id('dynamic-table').text
d816=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=816&keywords=")
user816 = driver.find_element_by_id('dynamic-table').text
d817=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=817&keywords=")
user817 = driver.find_element_by_id('dynamic-table').text
d818=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=818&keywords=")
user818 = driver.find_element_by_id('dynamic-table').text
d819=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=819&keywords=")
user819 = driver.find_element_by_id('dynamic-table').text
d820=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=820&keywords=")
user820 = driver.find_element_by_id('dynamic-table').text
d821=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=821&keywords=")
user821 = driver.find_element_by_id('dynamic-table').text
d822=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=822&keywords=")
user822 = driver.find_element_by_id('dynamic-table').text
d823=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=823&keywords=")
user823 = driver.find_element_by_id('dynamic-table').text
d824=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=824&keywords=")
user824 = driver.find_element_by_id('dynamic-table').text
d825=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=825&keywords=")
user825 = driver.find_element_by_id('dynamic-table').text
d826=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=826&keywords=")
user826 = driver.find_element_by_id('dynamic-table').text
d827=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=827&keywords=")
user827 = driver.find_element_by_id('dynamic-table').text
d828=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=828&keywords=")
user828 = driver.find_element_by_id('dynamic-table').text
d829=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=829&keywords=")
user829 = driver.find_element_by_id('dynamic-table').text
d830=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=830&keywords=")
user830 = driver.find_element_by_id('dynamic-table').text
d831=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=831&keywords=")
user831 = driver.find_element_by_id('dynamic-table').text
d832=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=832&keywords=")
user832 = driver.find_element_by_id('dynamic-table').text
d833=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=833&keywords=")
user833 = driver.find_element_by_id('dynamic-table').text
d834=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=834&keywords=")
user834 = driver.find_element_by_id('dynamic-table').text
d835=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=835&keywords=")
user835 = driver.find_element_by_id('dynamic-table').text
d836=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=836&keywords=")
user836 = driver.find_element_by_id('dynamic-table').text
d837=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=837&keywords=")
user837 = driver.find_element_by_id('dynamic-table').text
d838=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=838&keywords=")
user838 = driver.find_element_by_id('dynamic-table').text
d839=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=839&keywords=")
user839 = driver.find_element_by_id('dynamic-table').text
d840=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=840&keywords=")
user840 = driver.find_element_by_id('dynamic-table').text
d841=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=841&keywords=")
user841 = driver.find_element_by_id('dynamic-table').text
d842=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=842&keywords=")
user842 = driver.find_element_by_id('dynamic-table').text
d843=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=843&keywords=")
user843 = driver.find_element_by_id('dynamic-table').text
d844=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=844&keywords=")
user844 = driver.find_element_by_id('dynamic-table').text
d845=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=845&keywords=")
user845 = driver.find_element_by_id('dynamic-table').text
d846=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=846&keywords=")
user846 = driver.find_element_by_id('dynamic-table').text
d847=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=847&keywords=")
user847 = driver.find_element_by_id('dynamic-table').text
d848=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=848&keywords=")
user848 = driver.find_element_by_id('dynamic-table').text
d849=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=849&keywords=")
user849 = driver.find_element_by_id('dynamic-table').text
d850=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=850&keywords=")
user850 = driver.find_element_by_id('dynamic-table').text
d851=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=851&keywords=")
user851 = driver.find_element_by_id('dynamic-table').text
d852=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=852&keywords=")
user852 = driver.find_element_by_id('dynamic-table').text
d853=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=853&keywords=")
user853 = driver.find_element_by_id('dynamic-table').text
d854=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=854&keywords=")
user854 = driver.find_element_by_id('dynamic-table').text
d855=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=855&keywords=")
user855 = driver.find_element_by_id('dynamic-table').text
d856=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=856&keywords=")
user856 = driver.find_element_by_id('dynamic-table').text
d857=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=857&keywords=")
user857 = driver.find_element_by_id('dynamic-table').text
d858=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=858&keywords=")
user858 = driver.find_element_by_id('dynamic-table').text
d859=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=859&keywords=")
user859 = driver.find_element_by_id('dynamic-table').text
d860=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=860&keywords=")
user860 = driver.find_element_by_id('dynamic-table').text
d861=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=861&keywords=")
user861 = driver.find_element_by_id('dynamic-table').text
d862=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=862&keywords=")
user862 = driver.find_element_by_id('dynamic-table').text
d863=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=863&keywords=")
user863 = driver.find_element_by_id('dynamic-table').text
d864=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=864&keywords=")
user864 = driver.find_element_by_id('dynamic-table').text
d865=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=865&keywords=")
user865 = driver.find_element_by_id('dynamic-table').text
d866=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=866&keywords=")
user866 = driver.find_element_by_id('dynamic-table').text
d867=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=867&keywords=")
user867 = driver.find_element_by_id('dynamic-table').text
d868=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=868&keywords=")
user868 = driver.find_element_by_id('dynamic-table').text
d869=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=869&keywords=")
user869 = driver.find_element_by_id('dynamic-table').text
d870=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=870&keywords=")
user870 = driver.find_element_by_id('dynamic-table').text
d871=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=871&keywords=")
user871 = driver.find_element_by_id('dynamic-table').text
d872=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=872&keywords=")
user872 = driver.find_element_by_id('dynamic-table').text
d873=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=873&keywords=")
user873 = driver.find_element_by_id('dynamic-table').text
d874=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=874&keywords=")
user874 = driver.find_element_by_id('dynamic-table').text
d875=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=875&keywords=")
user875 = driver.find_element_by_id('dynamic-table').text
d876=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=876&keywords=")
user876 = driver.find_element_by_id('dynamic-table').text
d877=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=877&keywords=")
user877 = driver.find_element_by_id('dynamic-table').text
d878=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=878&keywords=")
user878 = driver.find_element_by_id('dynamic-table').text
d879=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=879&keywords=")
user879 = driver.find_element_by_id('dynamic-table').text
d880=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=880&keywords=")
user880 = driver.find_element_by_id('dynamic-table').text
d881=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=881&keywords=")
user881 = driver.find_element_by_id('dynamic-table').text
d882=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=882&keywords=")
user882 = driver.find_element_by_id('dynamic-table').text
d883=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=883&keywords=")
user883 = driver.find_element_by_id('dynamic-table').text
d884=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=884&keywords=")
user884 = driver.find_element_by_id('dynamic-table').text
d885=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=885&keywords=")
user885 = driver.find_element_by_id('dynamic-table').text
d886=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=886&keywords=")
user886 = driver.find_element_by_id('dynamic-table').text
d887=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=887&keywords=")
user887 = driver.find_element_by_id('dynamic-table').text
d888=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=888&keywords=")
user888 = driver.find_element_by_id('dynamic-table').text
d889=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=889&keywords=")
user889 = driver.find_element_by_id('dynamic-table').text
d890=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=890&keywords=")
user890 = driver.find_element_by_id('dynamic-table').text
d891=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=891&keywords=")
user891 = driver.find_element_by_id('dynamic-table').text
d892=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=892&keywords=")
user892 = driver.find_element_by_id('dynamic-table').text
d893=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=893&keywords=")
user893 = driver.find_element_by_id('dynamic-table').text
d894=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=894&keywords=")
user894 = driver.find_element_by_id('dynamic-table').text
d895=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=895&keywords=")
user895 = driver.find_element_by_id('dynamic-table').text
d896=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=896&keywords=")
user896 = driver.find_element_by_id('dynamic-table').text
d897=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=897&keywords=")
user897 = driver.find_element_by_id('dynamic-table').text
d898=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=898&keywords=")
user898 = driver.find_element_by_id('dynamic-table').text
d899=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=899&keywords=")
user899 = driver.find_element_by_id('dynamic-table').text
d900=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=900&keywords=")
user900 = driver.find_element_by_id('dynamic-table').text
d901=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=901&keywords=")
user901 = driver.find_element_by_id('dynamic-table').text
d902=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=902&keywords=")
user902 = driver.find_element_by_id('dynamic-table').text
d903=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=903&keywords=")
user903 = driver.find_element_by_id('dynamic-table').text
d904=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=904&keywords=")
user904 = driver.find_element_by_id('dynamic-table').text
d905=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=905&keywords=")
user905 = driver.find_element_by_id('dynamic-table').text
d906=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=906&keywords=")
user906 = driver.find_element_by_id('dynamic-table').text
d907=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=907&keywords=")
user907 = driver.find_element_by_id('dynamic-table').text
d908=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=908&keywords=")
user908 = driver.find_element_by_id('dynamic-table').text
d909=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=909&keywords=")
user909 = driver.find_element_by_id('dynamic-table').text
d910=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=910&keywords=")
user910 = driver.find_element_by_id('dynamic-table').text
d911=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=911&keywords=")
user911 = driver.find_element_by_id('dynamic-table').text
d912=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=912&keywords=")
user912 = driver.find_element_by_id('dynamic-table').text
d913=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=913&keywords=")
user913 = driver.find_element_by_id('dynamic-table').text
d914=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=914&keywords=")
user914 = driver.find_element_by_id('dynamic-table').text
d915=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=915&keywords=")
user915 = driver.find_element_by_id('dynamic-table').text
d916=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=916&keywords=")
user916 = driver.find_element_by_id('dynamic-table').text
d917=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=917&keywords=")
user917 = driver.find_element_by_id('dynamic-table').text
d918=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=918&keywords=")
user918 = driver.find_element_by_id('dynamic-table').text
d919=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=919&keywords=")
user919 = driver.find_element_by_id('dynamic-table').text
d920=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=920&keywords=")
user920 = driver.find_element_by_id('dynamic-table').text
d921=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=921&keywords=")
user921 = driver.find_element_by_id('dynamic-table').text
d922=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=922&keywords=")
user922 = driver.find_element_by_id('dynamic-table').text
d923=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=923&keywords=")
user923 = driver.find_element_by_id('dynamic-table').text
d924=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=924&keywords=")
user924 = driver.find_element_by_id('dynamic-table').text
d925=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=925&keywords=")
user925 = driver.find_element_by_id('dynamic-table').text
d926=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=926&keywords=")
user926 = driver.find_element_by_id('dynamic-table').text
d927=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=927&keywords=")
user927 = driver.find_element_by_id('dynamic-table').text
d928=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=928&keywords=")
user928 = driver.find_element_by_id('dynamic-table').text
d929=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=929&keywords=")
user929 = driver.find_element_by_id('dynamic-table').text
d930=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=930&keywords=")
user930 = driver.find_element_by_id('dynamic-table').text
d931=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=931&keywords=")
user931 = driver.find_element_by_id('dynamic-table').text
d932=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=932&keywords=")
user932 = driver.find_element_by_id('dynamic-table').text
d933=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=933&keywords=")
user933 = driver.find_element_by_id('dynamic-table').text
d934=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=934&keywords=")
user934 = driver.find_element_by_id('dynamic-table').text
d935=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=935&keywords=")
user935 = driver.find_element_by_id('dynamic-table').text
d936=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=936&keywords=")
user936 = driver.find_element_by_id('dynamic-table').text
d937=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=937&keywords=")
user937 = driver.find_element_by_id('dynamic-table').text
d938=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=938&keywords=")
user938 = driver.find_element_by_id('dynamic-table').text
d939=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=939&keywords=")
user939 = driver.find_element_by_id('dynamic-table').text
d940=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=940&keywords=")
user940 = driver.find_element_by_id('dynamic-table').text
d941=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=941&keywords=")
user941 = driver.find_element_by_id('dynamic-table').text
d942=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=942&keywords=")
user942 = driver.find_element_by_id('dynamic-table').text
d943=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=943&keywords=")
user943 = driver.find_element_by_id('dynamic-table').text
d944=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=944&keywords=")
user944 = driver.find_element_by_id('dynamic-table').text
d945=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=945&keywords=")
user945 = driver.find_element_by_id('dynamic-table').text
d946=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=946&keywords=")
user946 = driver.find_element_by_id('dynamic-table').text
d947=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=947&keywords=")
user947 = driver.find_element_by_id('dynamic-table').text
d948=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=948&keywords=")
user948 = driver.find_element_by_id('dynamic-table').text
d949=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=949&keywords=")
user949 = driver.find_element_by_id('dynamic-table').text
d950=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=950&keywords=")
user950 = driver.find_element_by_id('dynamic-table').text
d951=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=951&keywords=")
user951 = driver.find_element_by_id('dynamic-table').text
d952=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=952&keywords=")
user952 = driver.find_element_by_id('dynamic-table').text
d953=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=953&keywords=")
user953 = driver.find_element_by_id('dynamic-table').text
d954=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=954&keywords=")
user954 = driver.find_element_by_id('dynamic-table').text
d955=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=955&keywords=")
user955 = driver.find_element_by_id('dynamic-table').text
d956=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=956&keywords=")
user956 = driver.find_element_by_id('dynamic-table').text
d957=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=957&keywords=")
user957 = driver.find_element_by_id('dynamic-table').text
d958=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=958&keywords=")
user958 = driver.find_element_by_id('dynamic-table').text
d959=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=959&keywords=")
user959 = driver.find_element_by_id('dynamic-table').text
d960=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=960&keywords=")
user960 = driver.find_element_by_id('dynamic-table').text
d961=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=961&keywords=")
user961 = driver.find_element_by_id('dynamic-table').text
d962=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=962&keywords=")
user962 = driver.find_element_by_id('dynamic-table').text
d963=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=963&keywords=")
user963 = driver.find_element_by_id('dynamic-table').text
d964=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=964&keywords=")
user964 = driver.find_element_by_id('dynamic-table').text
d965=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=965&keywords=")
user965 = driver.find_element_by_id('dynamic-table').text
d966=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=966&keywords=")
user966 = driver.find_element_by_id('dynamic-table').text
d967=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=967&keywords=")
user967 = driver.find_element_by_id('dynamic-table').text
d968=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=968&keywords=")
user968 = driver.find_element_by_id('dynamic-table').text
d969=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=969&keywords=")
user969 = driver.find_element_by_id('dynamic-table').text
d970=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=970&keywords=")
user970 = driver.find_element_by_id('dynamic-table').text
d971=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=971&keywords=")
user971 = driver.find_element_by_id('dynamic-table').text
d972=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=972&keywords=")
user972 = driver.find_element_by_id('dynamic-table').text
d973=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=973&keywords=")
user973 = driver.find_element_by_id('dynamic-table').text
d974=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=974&keywords=")
user974 = driver.find_element_by_id('dynamic-table').text
d975=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=975&keywords=")
user975 = driver.find_element_by_id('dynamic-table').text
d976=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=976&keywords=")
user976 = driver.find_element_by_id('dynamic-table').text
d977=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=977&keywords=")
user977 = driver.find_element_by_id('dynamic-table').text
d978=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=978&keywords=")
user978 = driver.find_element_by_id('dynamic-table').text
d979=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=979&keywords=")
user979 = driver.find_element_by_id('dynamic-table').text
d980=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=980&keywords=")
user980 = driver.find_element_by_id('dynamic-table').text
d981=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=981&keywords=")
user981 = driver.find_element_by_id('dynamic-table').text
d982=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=982&keywords=")
user982 = driver.find_element_by_id('dynamic-table').text
d983=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=983&keywords=")
user983 = driver.find_element_by_id('dynamic-table').text
d984=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=984&keywords=")
user984 = driver.find_element_by_id('dynamic-table').text
d985=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=985&keywords=")
user985 = driver.find_element_by_id('dynamic-table').text
d986=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=986&keywords=")
user986 = driver.find_element_by_id('dynamic-table').text
d987=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=987&keywords=")
user987 = driver.find_element_by_id('dynamic-table').text
d988=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=988&keywords=")
user988 = driver.find_element_by_id('dynamic-table').text
d989=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=989&keywords=")
user989 = driver.find_element_by_id('dynamic-table').text
d990=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=990&keywords=")
user990 = driver.find_element_by_id('dynamic-table').text
d991=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=991&keywords=")
user991 = driver.find_element_by_id('dynamic-table').text
d992=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=992&keywords=")
user992 = driver.find_element_by_id('dynamic-table').text
d993=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=993&keywords=")
user993 = driver.find_element_by_id('dynamic-table').text
d994=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=994&keywords=")
user994 = driver.find_element_by_id('dynamic-table').text
d995=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=995&keywords=")
user995 = driver.find_element_by_id('dynamic-table').text
d996=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=996&keywords=")
user996 = driver.find_element_by_id('dynamic-table').text
d997=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=997&keywords=")
user997 = driver.find_element_by_id('dynamic-table').text
d998=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=998&keywords=")
user998 = driver.find_element_by_id('dynamic-table').text
d999=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=999&keywords=")
user999 = driver.find_element_by_id('dynamic-table').text
d1000=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1000&keywords=")
user1000 = driver.find_element_by_id('dynamic-table').text
d1001=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1001&keywords=")
user1001 = driver.find_element_by_id('dynamic-table').text
d1002=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1002&keywords=")
user1002 = driver.find_element_by_id('dynamic-table').text
d1003=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1003&keywords=")
user1003 = driver.find_element_by_id('dynamic-table').text
d1004=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1004&keywords=")
user1004 = driver.find_element_by_id('dynamic-table').text
d1005=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1005&keywords=")
user1005 = driver.find_element_by_id('dynamic-table').text
d1006=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1006&keywords=")
user1006 = driver.find_element_by_id('dynamic-table').text
d1007=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1007&keywords=")
user1007 = driver.find_element_by_id('dynamic-table').text
d1008=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1008&keywords=")
user1008 = driver.find_element_by_id('dynamic-table').text
d1009=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1009&keywords=")
user1009 = driver.find_element_by_id('dynamic-table').text
d1010=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1010&keywords=")
user1010 = driver.find_element_by_id('dynamic-table').text
d1011=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1011&keywords=")
user1011 = driver.find_element_by_id('dynamic-table').text
d1012=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1012&keywords=")
user1012 = driver.find_element_by_id('dynamic-table').text
d1013=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1013&keywords=")
user1013 = driver.find_element_by_id('dynamic-table').text
d1014=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1014&keywords=")
user1014 = driver.find_element_by_id('dynamic-table').text
d1015=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1015&keywords=")
user1015 = driver.find_element_by_id('dynamic-table').text
d1016=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1016&keywords=")
user1016 = driver.find_element_by_id('dynamic-table').text
d1017=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1017&keywords=")
user1017 = driver.find_element_by_id('dynamic-table').text
d1018=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1018&keywords=")
user1018 = driver.find_element_by_id('dynamic-table').text
d1019=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1019&keywords=")
user1019 = driver.find_element_by_id('dynamic-table').text
d1020=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1020&keywords=")
user1020 = driver.find_element_by_id('dynamic-table').text
d1021=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1021&keywords=")
user1021 = driver.find_element_by_id('dynamic-table').text
d1022=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1022&keywords=")
user1022 = driver.find_element_by_id('dynamic-table').text
d1023=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1023&keywords=")
user1023 = driver.find_element_by_id('dynamic-table').text
d1024=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1024&keywords=")
user1024 = driver.find_element_by_id('dynamic-table').text
d1025=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1025&keywords=")
user1025 = driver.find_element_by_id('dynamic-table').text
d1026=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1026&keywords=")
user1026 = driver.find_element_by_id('dynamic-table').text
d1027=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1027&keywords=")
user1027 = driver.find_element_by_id('dynamic-table').text
d1028=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1028&keywords=")
user1028 = driver.find_element_by_id('dynamic-table').text
d1029=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1029&keywords=")
user1029 = driver.find_element_by_id('dynamic-table').text
d1030=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1030&keywords=")
user1030 = driver.find_element_by_id('dynamic-table').text
d1031=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1031&keywords=")
user1031 = driver.find_element_by_id('dynamic-table').text
d1032=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1032&keywords=")
user1032 = driver.find_element_by_id('dynamic-table').text
d1033=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1033&keywords=")
user1033 = driver.find_element_by_id('dynamic-table').text
d1034=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1034&keywords=")
user1034 = driver.find_element_by_id('dynamic-table').text
d1035=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1035&keywords=")
user1035 = driver.find_element_by_id('dynamic-table').text
d1036=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1036&keywords=")
user1036 = driver.find_element_by_id('dynamic-table').text
d1037=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1037&keywords=")
user1037 = driver.find_element_by_id('dynamic-table').text
d1038=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1038&keywords=")
user1038 = driver.find_element_by_id('dynamic-table').text
d1039=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1039&keywords=")
user1039 = driver.find_element_by_id('dynamic-table').text
d1040=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1040&keywords=")
user1040 = driver.find_element_by_id('dynamic-table').text
d1041=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1041&keywords=")
user1041 = driver.find_element_by_id('dynamic-table').text
d1042=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1042&keywords=")
user1042 = driver.find_element_by_id('dynamic-table').text
d1043=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1043&keywords=")
user1043 = driver.find_element_by_id('dynamic-table').text
d1044=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1044&keywords=")
user1044 = driver.find_element_by_id('dynamic-table').text
d1045=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1045&keywords=")
user1045 = driver.find_element_by_id('dynamic-table').text
d1046=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1046&keywords=")
user1046 = driver.find_element_by_id('dynamic-table').text
d1047=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1047&keywords=")
user1047 = driver.find_element_by_id('dynamic-table').text
d1048=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1048&keywords=")
user1048 = driver.find_element_by_id('dynamic-table').text
d1049=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1049&keywords=")
user1049 = driver.find_element_by_id('dynamic-table').text
d1050=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1050&keywords=")
user1050 = driver.find_element_by_id('dynamic-table').text
d1051=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1051&keywords=")
user1051 = driver.find_element_by_id('dynamic-table').text
d1052=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1052&keywords=")
user1052 = driver.find_element_by_id('dynamic-table').text
d1053=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1053&keywords=")
user1053 = driver.find_element_by_id('dynamic-table').text
d1054=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1054&keywords=")
user1054 = driver.find_element_by_id('dynamic-table').text
d1055=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1055&keywords=")
user1055 = driver.find_element_by_id('dynamic-table').text
d1056=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1056&keywords=")
user1056 = driver.find_element_by_id('dynamic-table').text
d1057=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1057&keywords=")
user1057 = driver.find_element_by_id('dynamic-table').text
d1058=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1058&keywords=")
user1058 = driver.find_element_by_id('dynamic-table').text
d1059=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1059&keywords=")
user1059 = driver.find_element_by_id('dynamic-table').text
d1060=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1060&keywords=")
user1060 = driver.find_element_by_id('dynamic-table').text
d1061=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1061&keywords=")
user1061 = driver.find_element_by_id('dynamic-table').text
d1062=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1062&keywords=")
user1062 = driver.find_element_by_id('dynamic-table').text
d1063=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1063&keywords=")
user1063 = driver.find_element_by_id('dynamic-table').text
d1064=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1064&keywords=")
user1064 = driver.find_element_by_id('dynamic-table').text
d1065=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1065&keywords=")
user1065 = driver.find_element_by_id('dynamic-table').text
d1066=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1066&keywords=")
user1066 = driver.find_element_by_id('dynamic-table').text
d1067=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1067&keywords=")
user1067 = driver.find_element_by_id('dynamic-table').text
d1068=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1068&keywords=")
user1068 = driver.find_element_by_id('dynamic-table').text
d1069=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1069&keywords=")
user1069 = driver.find_element_by_id('dynamic-table').text
d1070=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1070&keywords=")
user1070 = driver.find_element_by_id('dynamic-table').text
d1071=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1071&keywords=")
user1071 = driver.find_element_by_id('dynamic-table').text
d1072=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1072&keywords=")
user1072 = driver.find_element_by_id('dynamic-table').text
d1073=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1073&keywords=")
user1073 = driver.find_element_by_id('dynamic-table').text
d1074=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1074&keywords=")
user1074 = driver.find_element_by_id('dynamic-table').text
d1075=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1075&keywords=")
user1075 = driver.find_element_by_id('dynamic-table').text
d1076=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1076&keywords=")
user1076 = driver.find_element_by_id('dynamic-table').text
d1077=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1077&keywords=")
user1077 = driver.find_element_by_id('dynamic-table').text
d1078=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1078&keywords=")
user1078 = driver.find_element_by_id('dynamic-table').text
d1079=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1079&keywords=")
user1079 = driver.find_element_by_id('dynamic-table').text
d1080=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1080&keywords=")
user1080 = driver.find_element_by_id('dynamic-table').text
d1081=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1081&keywords=")
user1081 = driver.find_element_by_id('dynamic-table').text
d1082=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1082&keywords=")
user1082 = driver.find_element_by_id('dynamic-table').text
d1083=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1083&keywords=")
user1083 = driver.find_element_by_id('dynamic-table').text
d1084=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1084&keywords=")
user1084 = driver.find_element_by_id('dynamic-table').text
d1085=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1085&keywords=")
user1085 = driver.find_element_by_id('dynamic-table').text
d1086=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1086&keywords=")
user1086 = driver.find_element_by_id('dynamic-table').text
d1087=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1087&keywords=")
user1087 = driver.find_element_by_id('dynamic-table').text
d1088=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1088&keywords=")
user1088 = driver.find_element_by_id('dynamic-table').text
d1089=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1089&keywords=")
user1089 = driver.find_element_by_id('dynamic-table').text
d1090=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1090&keywords=")
user1090 = driver.find_element_by_id('dynamic-table').text
d1091=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1091&keywords=")
user1091 = driver.find_element_by_id('dynamic-table').text
d1092=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1092&keywords=")
user1092 = driver.find_element_by_id('dynamic-table').text
d1093=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1093&keywords=")
user1093 = driver.find_element_by_id('dynamic-table').text
d1094=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1094&keywords=")
user1094 = driver.find_element_by_id('dynamic-table').text
d1095=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1095&keywords=")
user1095 = driver.find_element_by_id('dynamic-table').text
d1096=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1096&keywords=")
user1096 = driver.find_element_by_id('dynamic-table').text
d1097=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1097&keywords=")
user1097 = driver.find_element_by_id('dynamic-table').text
d1098=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1098&keywords=")
user1098 = driver.find_element_by_id('dynamic-table').text
d1099=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1099&keywords=")
user1099 = driver.find_element_by_id('dynamic-table').text
d1100=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1100&keywords=")
user1100 = driver.find_element_by_id('dynamic-table').text
d1101=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1101&keywords=")
user1101 = driver.find_element_by_id('dynamic-table').text
d1102=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1102&keywords=")
user1102 = driver.find_element_by_id('dynamic-table').text
d1103=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1103&keywords=")
user1103 = driver.find_element_by_id('dynamic-table').text
d1104=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1104&keywords=")
user1104 = driver.find_element_by_id('dynamic-table').text
d1105=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1105&keywords=")
user1105 = driver.find_element_by_id('dynamic-table').text
d1106=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1106&keywords=")
user1106 = driver.find_element_by_id('dynamic-table').text
d1107=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1107&keywords=")
user1107 = driver.find_element_by_id('dynamic-table').text
d1108=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1108&keywords=")
user1108 = driver.find_element_by_id('dynamic-table').text
d1109=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1109&keywords=")
user1109 = driver.find_element_by_id('dynamic-table').text
d1110=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1110&keywords=")
user1110 = driver.find_element_by_id('dynamic-table').text
d1111=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1111&keywords=")
user1111 = driver.find_element_by_id('dynamic-table').text
d1112=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1112&keywords=")
user1112 = driver.find_element_by_id('dynamic-table').text
d1113=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1113&keywords=")
user1113 = driver.find_element_by_id('dynamic-table').text
d1114=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1114&keywords=")
user1114 = driver.find_element_by_id('dynamic-table').text
d1115=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1115&keywords=")
user1115 = driver.find_element_by_id('dynamic-table').text
d1116=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1116&keywords=")
user1116 = driver.find_element_by_id('dynamic-table').text
d1117=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1117&keywords=")
user1117 = driver.find_element_by_id('dynamic-table').text
d1118=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1118&keywords=")
user1118 = driver.find_element_by_id('dynamic-table').text
d1119=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1119&keywords=")
user1119 = driver.find_element_by_id('dynamic-table').text
d1120=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1120&keywords=")
user1120 = driver.find_element_by_id('dynamic-table').text
d1121=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1121&keywords=")
user1121 = driver.find_element_by_id('dynamic-table').text
d1122=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1122&keywords=")
user1122 = driver.find_element_by_id('dynamic-table').text
d1123=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1123&keywords=")
user1123 = driver.find_element_by_id('dynamic-table').text
d1124=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1124&keywords=")
user1124 = driver.find_element_by_id('dynamic-table').text
d1125=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1125&keywords=")
user1125 = driver.find_element_by_id('dynamic-table').text
d1126=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1126&keywords=")
user1126 = driver.find_element_by_id('dynamic-table').text
d1127=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1127&keywords=")
user1127 = driver.find_element_by_id('dynamic-table').text
d1128=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1128&keywords=")
user1128 = driver.find_element_by_id('dynamic-table').text
d1129=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1129&keywords=")
user1129 = driver.find_element_by_id('dynamic-table').text
d1130=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1130&keywords=")
user1130 = driver.find_element_by_id('dynamic-table').text
d1131=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1131&keywords=")
user1131 = driver.find_element_by_id('dynamic-table').text
d1132=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1132&keywords=")
user1132 = driver.find_element_by_id('dynamic-table').text
d1133=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1133&keywords=")
user1133 = driver.find_element_by_id('dynamic-table').text
d1134=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1134&keywords=")
user1134 = driver.find_element_by_id('dynamic-table').text
d1135=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1135&keywords=")
user1135 = driver.find_element_by_id('dynamic-table').text
d1136=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1136&keywords=")
user1136 = driver.find_element_by_id('dynamic-table').text
d1137=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1137&keywords=")
user1137 = driver.find_element_by_id('dynamic-table').text
d1138=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1138&keywords=")
user1138 = driver.find_element_by_id('dynamic-table').text
d1139=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1139&keywords=")
user1139 = driver.find_element_by_id('dynamic-table').text
d1140=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1140&keywords=")
user1140 = driver.find_element_by_id('dynamic-table').text
d1141=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1141&keywords=")
user1141 = driver.find_element_by_id('dynamic-table').text
d1142=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1142&keywords=")
user1142 = driver.find_element_by_id('dynamic-table').text
d1143=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1143&keywords=")
user1143 = driver.find_element_by_id('dynamic-table').text
d1144=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1144&keywords=")
user1144 = driver.find_element_by_id('dynamic-table').text
d1145=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1145&keywords=")
user1145 = driver.find_element_by_id('dynamic-table').text
d1146=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1146&keywords=")
user1146 = driver.find_element_by_id('dynamic-table').text
d1147=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1147&keywords=")
user1147 = driver.find_element_by_id('dynamic-table').text
d1148=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1148&keywords=")
user1148 = driver.find_element_by_id('dynamic-table').text
d1149=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1149&keywords=")
user1149 = driver.find_element_by_id('dynamic-table').text
d1150=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1150&keywords=")
user1150 = driver.find_element_by_id('dynamic-table').text
d1151=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1151&keywords=")
user1151 = driver.find_element_by_id('dynamic-table').text
d1152=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1152&keywords=")
user1152 = driver.find_element_by_id('dynamic-table').text
d1153=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1153&keywords=")
user1153 = driver.find_element_by_id('dynamic-table').text
d1154=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1154&keywords=")
user1154 = driver.find_element_by_id('dynamic-table').text
d1155=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1155&keywords=")
user1155 = driver.find_element_by_id('dynamic-table').text
d1156=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1156&keywords=")
user1156 = driver.find_element_by_id('dynamic-table').text
d1157=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1157&keywords=")
user1157 = driver.find_element_by_id('dynamic-table').text
d1158=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1158&keywords=")
user1158 = driver.find_element_by_id('dynamic-table').text
d1159=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1159&keywords=")
user1159 = driver.find_element_by_id('dynamic-table').text
d1160=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1160&keywords=")
user1160 = driver.find_element_by_id('dynamic-table').text
d1161=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1161&keywords=")
user1161 = driver.find_element_by_id('dynamic-table').text
d1162=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1162&keywords=")
user1162 = driver.find_element_by_id('dynamic-table').text
d1163=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1163&keywords=")
user1163 = driver.find_element_by_id('dynamic-table').text
d1164=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1164&keywords=")
user1164 = driver.find_element_by_id('dynamic-table').text
d1165=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1165&keywords=")
user1165 = driver.find_element_by_id('dynamic-table').text
d1166=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1166&keywords=")
user1166 = driver.find_element_by_id('dynamic-table').text
d1167=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1167&keywords=")
user1167 = driver.find_element_by_id('dynamic-table').text
d1168=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1168&keywords=")
user1168 = driver.find_element_by_id('dynamic-table').text
d1169=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1169&keywords=")
user1169 = driver.find_element_by_id('dynamic-table').text
d1170=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1170&keywords=")
user1170 = driver.find_element_by_id('dynamic-table').text
d1171=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1171&keywords=")
user1171 = driver.find_element_by_id('dynamic-table').text
d1172=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1172&keywords=")
user1172 = driver.find_element_by_id('dynamic-table').text
d1173=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1173&keywords=")
user1173 = driver.find_element_by_id('dynamic-table').text
d1174=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1174&keywords=")
user1174 = driver.find_element_by_id('dynamic-table').text
d1175=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1175&keywords=")
user1175 = driver.find_element_by_id('dynamic-table').text
d1176=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1176&keywords=")
user1176 = driver.find_element_by_id('dynamic-table').text
d1177=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1177&keywords=")
user1177 = driver.find_element_by_id('dynamic-table').text
d1178=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1178&keywords=")
user1178 = driver.find_element_by_id('dynamic-table').text
d1179=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1179&keywords=")
user1179 = driver.find_element_by_id('dynamic-table').text
d1180=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1180&keywords=")
user1180 = driver.find_element_by_id('dynamic-table').text
d1181=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1181&keywords=")
user1181 = driver.find_element_by_id('dynamic-table').text
d1182=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1182&keywords=")
user1182 = driver.find_element_by_id('dynamic-table').text
d1183=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1183&keywords=")
user1183 = driver.find_element_by_id('dynamic-table').text
d1184=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1184&keywords=")
user1184 = driver.find_element_by_id('dynamic-table').text
d1185=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1185&keywords=")
user1185 = driver.find_element_by_id('dynamic-table').text
d1186=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1186&keywords=")
user1186 = driver.find_element_by_id('dynamic-table').text
d1187=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1187&keywords=")
user1187 = driver.find_element_by_id('dynamic-table').text
d1188=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1188&keywords=")
user1188 = driver.find_element_by_id('dynamic-table').text
d1189=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1189&keywords=")
user1189 = driver.find_element_by_id('dynamic-table').text
d1190=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1190&keywords=")
user1190 = driver.find_element_by_id('dynamic-table').text
d1191=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1191&keywords=")
user1191 = driver.find_element_by_id('dynamic-table').text
d1192=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1192&keywords=")
user1192 = driver.find_element_by_id('dynamic-table').text
d1193=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1193&keywords=")
user1193 = driver.find_element_by_id('dynamic-table').text
d1194=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1194&keywords=")
user1194 = driver.find_element_by_id('dynamic-table').text
d1195=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1195&keywords=")
user1195 = driver.find_element_by_id('dynamic-table').text
d1196=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1196&keywords=")
user1196 = driver.find_element_by_id('dynamic-table').text
d1197=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1197&keywords=")
user1197 = driver.find_element_by_id('dynamic-table').text
d1198=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1198&keywords=")
user1198 = driver.find_element_by_id('dynamic-table').text
d1199=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1199&keywords=")
user1199 = driver.find_element_by_id('dynamic-table').text
d1200=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1200&keywords=")
user1200 = driver.find_element_by_id('dynamic-table').text
d1201=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1201&keywords=")
user1201 = driver.find_element_by_id('dynamic-table').text
d1202=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1202&keywords=")
user1202 = driver.find_element_by_id('dynamic-table').text
d1203=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1203&keywords=")
user1203 = driver.find_element_by_id('dynamic-table').text
d1204=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1204&keywords=")
user1204 = driver.find_element_by_id('dynamic-table').text
d1205=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1205&keywords=")
user1205 = driver.find_element_by_id('dynamic-table').text
d1206=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1206&keywords=")
user1206 = driver.find_element_by_id('dynamic-table').text
d1207=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1207&keywords=")
user1207 = driver.find_element_by_id('dynamic-table').text
d1208=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1208&keywords=")
user1208 = driver.find_element_by_id('dynamic-table').text
d1209=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1209&keywords=")
user1209 = driver.find_element_by_id('dynamic-table').text
d1210=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1210&keywords=")
user1210 = driver.find_element_by_id('dynamic-table').text
d1211=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1211&keywords=")
user1211 = driver.find_element_by_id('dynamic-table').text
d1212=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1212&keywords=")
user1212 = driver.find_element_by_id('dynamic-table').text
d1213=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1213&keywords=")
user1213 = driver.find_element_by_id('dynamic-table').text
d1214=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1214&keywords=")
user1214 = driver.find_element_by_id('dynamic-table').text
d1215=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1215&keywords=")
user1215 = driver.find_element_by_id('dynamic-table').text
d1216=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1216&keywords=")
user1216 = driver.find_element_by_id('dynamic-table').text
d1217=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1217&keywords=")
user1217 = driver.find_element_by_id('dynamic-table').text
d1218=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1218&keywords=")
user1218 = driver.find_element_by_id('dynamic-table').text
d1219=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1219&keywords=")
user1219 = driver.find_element_by_id('dynamic-table').text
d1220=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1220&keywords=")
user1220 = driver.find_element_by_id('dynamic-table').text
d1221=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1221&keywords=")
user1221 = driver.find_element_by_id('dynamic-table').text
d1222=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1222&keywords=")
user1222 = driver.find_element_by_id('dynamic-table').text
d1223=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1223&keywords=")
user1223 = driver.find_element_by_id('dynamic-table').text
d1224=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1224&keywords=")
user1224 = driver.find_element_by_id('dynamic-table').text
d1225=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1225&keywords=")
user1225 = driver.find_element_by_id('dynamic-table').text
d1226=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1226&keywords=")
user1226 = driver.find_element_by_id('dynamic-table').text
d1227=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1227&keywords=")
user1227 = driver.find_element_by_id('dynamic-table').text
d1228=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1228&keywords=")
user1228 = driver.find_element_by_id('dynamic-table').text
d1229=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1229&keywords=")
user1229 = driver.find_element_by_id('dynamic-table').text
d1230=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1230&keywords=")
user1230 = driver.find_element_by_id('dynamic-table').text
d1231=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1231&keywords=")
user1231 = driver.find_element_by_id('dynamic-table').text
d1232=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1232&keywords=")
user1232 = driver.find_element_by_id('dynamic-table').text
d1233=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1233&keywords=")
user1233 = driver.find_element_by_id('dynamic-table').text
d1234=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1234&keywords=")
user1234 = driver.find_element_by_id('dynamic-table').text
d1235=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1235&keywords=")
user1235 = driver.find_element_by_id('dynamic-table').text
d1236=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1236&keywords=")
user1236 = driver.find_element_by_id('dynamic-table').text
d1237=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1237&keywords=")
user1237 = driver.find_element_by_id('dynamic-table').text
d1238=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1238&keywords=")
user1238 = driver.find_element_by_id('dynamic-table').text
d1239=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1239&keywords=")
user1239 = driver.find_element_by_id('dynamic-table').text
d1240=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1240&keywords=")
user1240 = driver.find_element_by_id('dynamic-table').text
d1241=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1241&keywords=")
user1241 = driver.find_element_by_id('dynamic-table').text
d1242=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1242&keywords=")
user1242 = driver.find_element_by_id('dynamic-table').text
d1243=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1243&keywords=")
user1243 = driver.find_element_by_id('dynamic-table').text
d1244=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1244&keywords=")
user1244 = driver.find_element_by_id('dynamic-table').text
d1245=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1245&keywords=")
user1245 = driver.find_element_by_id('dynamic-table').text
d1246=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1246&keywords=")
user1246 = driver.find_element_by_id('dynamic-table').text
d1247=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1247&keywords=")
user1247 = driver.find_element_by_id('dynamic-table').text
d1248=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1248&keywords=")
user1248 = driver.find_element_by_id('dynamic-table').text
d1249=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1249&keywords=")
user1249 = driver.find_element_by_id('dynamic-table').text
d1250=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1250&keywords=")
user1250 = driver.find_element_by_id('dynamic-table').text
d1251=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1251&keywords=")
user1251 = driver.find_element_by_id('dynamic-table').text
d1252=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1252&keywords=")
user1252 = driver.find_element_by_id('dynamic-table').text
d1253=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1253&keywords=")
user1253 = driver.find_element_by_id('dynamic-table').text
d1254=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1254&keywords=")
user1254 = driver.find_element_by_id('dynamic-table').text
d1255=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1255&keywords=")
user1255 = driver.find_element_by_id('dynamic-table').text
d1256=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1256&keywords=")
user1256 = driver.find_element_by_id('dynamic-table').text
d1257=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1257&keywords=")
user1257 = driver.find_element_by_id('dynamic-table').text
d1258=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1258&keywords=")
user1258 = driver.find_element_by_id('dynamic-table').text
d1259=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1259&keywords=")
user1259 = driver.find_element_by_id('dynamic-table').text
d1260=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1260&keywords=")
user1260 = driver.find_element_by_id('dynamic-table').text
d1261=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1261&keywords=")
user1261 = driver.find_element_by_id('dynamic-table').text
d1262=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1262&keywords=")
user1262 = driver.find_element_by_id('dynamic-table').text
d1263=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1263&keywords=")
user1263 = driver.find_element_by_id('dynamic-table').text
d1264=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1264&keywords=")
user1264 = driver.find_element_by_id('dynamic-table').text
d1265=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1265&keywords=")
user1265 = driver.find_element_by_id('dynamic-table').text
d1266=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1266&keywords=")
user1266 = driver.find_element_by_id('dynamic-table').text
d1267=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1267&keywords=")
user1267 = driver.find_element_by_id('dynamic-table').text
d1268=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1268&keywords=")
user1268 = driver.find_element_by_id('dynamic-table').text
d1269=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1269&keywords=")
user1269 = driver.find_element_by_id('dynamic-table').text
d1270=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1270&keywords=")
user1270 = driver.find_element_by_id('dynamic-table').text
d1271=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1271&keywords=")
user1271 = driver.find_element_by_id('dynamic-table').text
d1272=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1272&keywords=")
user1272 = driver.find_element_by_id('dynamic-table').text
d1273=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1273&keywords=")
user1273 = driver.find_element_by_id('dynamic-table').text
d1274=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1274&keywords=")
user1274 = driver.find_element_by_id('dynamic-table').text
d1275=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1275&keywords=")
user1275 = driver.find_element_by_id('dynamic-table').text
d1276=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1276&keywords=")
user1276 = driver.find_element_by_id('dynamic-table').text
d1277=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1277&keywords=")
user1277 = driver.find_element_by_id('dynamic-table').text
d1278=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1278&keywords=")
user1278 = driver.find_element_by_id('dynamic-table').text
d1279=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1279&keywords=")
user1279 = driver.find_element_by_id('dynamic-table').text
d1280=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1280&keywords=")
user1280 = driver.find_element_by_id('dynamic-table').text
d1281=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1281&keywords=")
user1281 = driver.find_element_by_id('dynamic-table').text
d1282=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1282&keywords=")
user1282 = driver.find_element_by_id('dynamic-table').text
d1283=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1283&keywords=")
user1283 = driver.find_element_by_id('dynamic-table').text
d1284=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1284&keywords=")
user1284 = driver.find_element_by_id('dynamic-table').text
d1285=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1285&keywords=")
user1285 = driver.find_element_by_id('dynamic-table').text
d1286=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1286&keywords=")
user1286 = driver.find_element_by_id('dynamic-table').text
d1287=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1287&keywords=")
user1287 = driver.find_element_by_id('dynamic-table').text
d1288=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1288&keywords=")
user1288 = driver.find_element_by_id('dynamic-table').text
d1289=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1289&keywords=")
user1289 = driver.find_element_by_id('dynamic-table').text
d1290=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1290&keywords=")
user1290 = driver.find_element_by_id('dynamic-table').text
d1291=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1291&keywords=")
user1291 = driver.find_element_by_id('dynamic-table').text
d1292=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1292&keywords=")
user1292 = driver.find_element_by_id('dynamic-table').text
d1293=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1293&keywords=")
user1293 = driver.find_element_by_id('dynamic-table').text
d1294=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1294&keywords=")
user1294 = driver.find_element_by_id('dynamic-table').text
d1295=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1295&keywords=")
user1295 = driver.find_element_by_id('dynamic-table').text
d1296=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1296&keywords=")
user1296 = driver.find_element_by_id('dynamic-table').text
d1297=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1297&keywords=")
user1297 = driver.find_element_by_id('dynamic-table').text
d1298=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1298&keywords=")
user1298 = driver.find_element_by_id('dynamic-table').text
d1299=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1299&keywords=")
user1299 = driver.find_element_by_id('dynamic-table').text
d1300=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1300&keywords=")
user1300 = driver.find_element_by_id('dynamic-table').text
d1301=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1301&keywords=")
user1301 = driver.find_element_by_id('dynamic-table').text
d1302=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1302&keywords=")
user1302 = driver.find_element_by_id('dynamic-table').text
d1303=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1303&keywords=")
user1303 = driver.find_element_by_id('dynamic-table').text
d1304=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1304&keywords=")
user1304 = driver.find_element_by_id('dynamic-table').text
d1305=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1305&keywords=")
user1305 = driver.find_element_by_id('dynamic-table').text
d1306=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1306&keywords=")
user1306 = driver.find_element_by_id('dynamic-table').text
d1307=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1307&keywords=")
user1307 = driver.find_element_by_id('dynamic-table').text
d1308=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1308&keywords=")
user1308 = driver.find_element_by_id('dynamic-table').text
d1309=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1309&keywords=")
user1309 = driver.find_element_by_id('dynamic-table').text
d1310=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1310&keywords=")
user1310 = driver.find_element_by_id('dynamic-table').text
d1311=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1311&keywords=")
user1311 = driver.find_element_by_id('dynamic-table').text
d1312=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1312&keywords=")
user1312 = driver.find_element_by_id('dynamic-table').text
d1313=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1313&keywords=")
user1313 = driver.find_element_by_id('dynamic-table').text
d1314=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1314&keywords=")
user1314 = driver.find_element_by_id('dynamic-table').text
d1315=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1315&keywords=")
user1315 = driver.find_element_by_id('dynamic-table').text
d1316=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1316&keywords=")
user1316 = driver.find_element_by_id('dynamic-table').text
d1317=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1317&keywords=")
user1317 = driver.find_element_by_id('dynamic-table').text
d1318=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1318&keywords=")
user1318 = driver.find_element_by_id('dynamic-table').text
d1319=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1319&keywords=")
user1319 = driver.find_element_by_id('dynamic-table').text
d1320=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1320&keywords=")
user1320 = driver.find_element_by_id('dynamic-table').text
d1321=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1321&keywords=")
user1321 = driver.find_element_by_id('dynamic-table').text
d1322=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1322&keywords=")
user1322 = driver.find_element_by_id('dynamic-table').text
d1323=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1323&keywords=")
user1323 = driver.find_element_by_id('dynamic-table').text
d1324=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1324&keywords=")
user1324 = driver.find_element_by_id('dynamic-table').text
d1325=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1325&keywords=")
user1325 = driver.find_element_by_id('dynamic-table').text
d1326=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1326&keywords=")
user1326 = driver.find_element_by_id('dynamic-table').text
d1327=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1327&keywords=")
user1327 = driver.find_element_by_id('dynamic-table').text
d1328=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1328&keywords=")
user1328 = driver.find_element_by_id('dynamic-table').text
d1329=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1329&keywords=")
user1329 = driver.find_element_by_id('dynamic-table').text
d1330=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1330&keywords=")
user1330 = driver.find_element_by_id('dynamic-table').text
d1331=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1331&keywords=")
user1331 = driver.find_element_by_id('dynamic-table').text
d1332=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1332&keywords=")
user1332 = driver.find_element_by_id('dynamic-table').text
d1333=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1333&keywords=")
user1333 = driver.find_element_by_id('dynamic-table').text
d1334=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1334&keywords=")
user1334 = driver.find_element_by_id('dynamic-table').text
d1335=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1335&keywords=")
user1335 = driver.find_element_by_id('dynamic-table').text
d1336=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1336&keywords=")
user1336 = driver.find_element_by_id('dynamic-table').text
d1337=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1337&keywords=")
user1337 = driver.find_element_by_id('dynamic-table').text
d1338=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1338&keywords=")
user1338 = driver.find_element_by_id('dynamic-table').text
d1339=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1339&keywords=")
user1339 = driver.find_element_by_id('dynamic-table').text
d1340=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1340&keywords=")
user1340 = driver.find_element_by_id('dynamic-table').text
d1341=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1341&keywords=")
user1341 = driver.find_element_by_id('dynamic-table').text
d1342=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1342&keywords=")
user1342 = driver.find_element_by_id('dynamic-table').text
d1343=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1343&keywords=")
user1343 = driver.find_element_by_id('dynamic-table').text
d1344=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1344&keywords=")
user1344 = driver.find_element_by_id('dynamic-table').text
d1345=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1345&keywords=")
user1345 = driver.find_element_by_id('dynamic-table').text
d1346=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1346&keywords=")
user1346 = driver.find_element_by_id('dynamic-table').text
d1347=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1347&keywords=")
user1347 = driver.find_element_by_id('dynamic-table').text
d1348=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1348&keywords=")
user1348 = driver.find_element_by_id('dynamic-table').text
d1349=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1349&keywords=")
user1349 = driver.find_element_by_id('dynamic-table').text
d1350=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1350&keywords=")
user1350 = driver.find_element_by_id('dynamic-table').text
d1351=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1351&keywords=")
user1351 = driver.find_element_by_id('dynamic-table').text
d1352=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1352&keywords=")
user1352 = driver.find_element_by_id('dynamic-table').text
d1353=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1353&keywords=")
user1353 = driver.find_element_by_id('dynamic-table').text
d1354=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1354&keywords=")
user1354 = driver.find_element_by_id('dynamic-table').text
d1355=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1355&keywords=")
user1355 = driver.find_element_by_id('dynamic-table').text
d1356=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1356&keywords=")
user1356 = driver.find_element_by_id('dynamic-table').text
d1357=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1357&keywords=")
user1357 = driver.find_element_by_id('dynamic-table').text
d1358=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1358&keywords=")
user1358 = driver.find_element_by_id('dynamic-table').text
d1359=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1359&keywords=")
user1359 = driver.find_element_by_id('dynamic-table').text
d1360=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1360&keywords=")
user1360 = driver.find_element_by_id('dynamic-table').text
d1361=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1361&keywords=")
user1361 = driver.find_element_by_id('dynamic-table').text
d1362=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1362&keywords=")
user1362 = driver.find_element_by_id('dynamic-table').text
d1363=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1363&keywords=")
user1363 = driver.find_element_by_id('dynamic-table').text
d1364=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1364&keywords=")
user1364 = driver.find_element_by_id('dynamic-table').text
d1365=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1365&keywords=")
user1365 = driver.find_element_by_id('dynamic-table').text
d1366=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1366&keywords=")
user1366 = driver.find_element_by_id('dynamic-table').text
d1367=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1367&keywords=")
user1367 = driver.find_element_by_id('dynamic-table').text
d1368=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1368&keywords=")
user1368 = driver.find_element_by_id('dynamic-table').text
d1369=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1369&keywords=")
user1369 = driver.find_element_by_id('dynamic-table').text
d1370=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1370&keywords=")
user1370 = driver.find_element_by_id('dynamic-table').text
d1371=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1371&keywords=")
user1371 = driver.find_element_by_id('dynamic-table').text
d1372=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1372&keywords=")
user1372 = driver.find_element_by_id('dynamic-table').text
d1373=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1373&keywords=")
user1373 = driver.find_element_by_id('dynamic-table').text
d1374=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1374&keywords=")
user1374 = driver.find_element_by_id('dynamic-table').text
d1375=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1375&keywords=")
user1375 = driver.find_element_by_id('dynamic-table').text
d1376=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1376&keywords=")
user1376 = driver.find_element_by_id('dynamic-table').text
d1377=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1377&keywords=")
user1377 = driver.find_element_by_id('dynamic-table').text
d1378=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1378&keywords=")
user1378 = driver.find_element_by_id('dynamic-table').text
d1379=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1379&keywords=")
user1379 = driver.find_element_by_id('dynamic-table').text
d1380=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1380&keywords=")
user1380 = driver.find_element_by_id('dynamic-table').text
d1381=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1381&keywords=")
user1381 = driver.find_element_by_id('dynamic-table').text
d1382=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1382&keywords=")
user1382 = driver.find_element_by_id('dynamic-table').text
d1383=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1383&keywords=")
user1383 = driver.find_element_by_id('dynamic-table').text
d1384=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1384&keywords=")
user1384 = driver.find_element_by_id('dynamic-table').text
d1385=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1385&keywords=")
user1385 = driver.find_element_by_id('dynamic-table').text
d1386=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1386&keywords=")
user1386 = driver.find_element_by_id('dynamic-table').text
d1387=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1387&keywords=")
user1387 = driver.find_element_by_id('dynamic-table').text
d1388=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1388&keywords=")
user1388 = driver.find_element_by_id('dynamic-table').text
d1389=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1389&keywords=")
user1389 = driver.find_element_by_id('dynamic-table').text
d1390=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1390&keywords=")
user1390 = driver.find_element_by_id('dynamic-table').text
d1391=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1391&keywords=")
user1391 = driver.find_element_by_id('dynamic-table').text
d1392=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1392&keywords=")
user1392 = driver.find_element_by_id('dynamic-table').text
d1393=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1393&keywords=")
user1393 = driver.find_element_by_id('dynamic-table').text
d1394=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1394&keywords=")
user1394 = driver.find_element_by_id('dynamic-table').text
d1395=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1395&keywords=")
user1395 = driver.find_element_by_id('dynamic-table').text
d1396=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1396&keywords=")
user1396 = driver.find_element_by_id('dynamic-table').text
d1397=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1397&keywords=")
user1397 = driver.find_element_by_id('dynamic-table').text
d1398=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1398&keywords=")
user1398 = driver.find_element_by_id('dynamic-table').text
d1399=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1399&keywords=")
user1399 = driver.find_element_by_id('dynamic-table').text
d1400=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1400&keywords=")
user1400 = driver.find_element_by_id('dynamic-table').text
d1401=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1401&keywords=")
user1401 = driver.find_element_by_id('dynamic-table').text
d1402=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1402&keywords=")
user1402 = driver.find_element_by_id('dynamic-table').text
d1403=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1403&keywords=")
user1403 = driver.find_element_by_id('dynamic-table').text
d1404=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1404&keywords=")
user1404 = driver.find_element_by_id('dynamic-table').text
d1405=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1405&keywords=")
user1405 = driver.find_element_by_id('dynamic-table').text
d1406=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1406&keywords=")
user1406 = driver.find_element_by_id('dynamic-table').text
d1407=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1407&keywords=")
user1407 = driver.find_element_by_id('dynamic-table').text
d1408=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1408&keywords=")
user1408 = driver.find_element_by_id('dynamic-table').text
d1409=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1409&keywords=")
user1409 = driver.find_element_by_id('dynamic-table').text
d1410=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1410&keywords=")
user1410 = driver.find_element_by_id('dynamic-table').text
d1411=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1411&keywords=")
user1411 = driver.find_element_by_id('dynamic-table').text
d1412=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1412&keywords=")
user1412 = driver.find_element_by_id('dynamic-table').text
d1413=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1413&keywords=")
user1413 = driver.find_element_by_id('dynamic-table').text
d1414=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1414&keywords=")
user1414 = driver.find_element_by_id('dynamic-table').text
d1415=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1415&keywords=")
user1415 = driver.find_element_by_id('dynamic-table').text
d1416=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1416&keywords=")
user1416 = driver.find_element_by_id('dynamic-table').text
d1417=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1417&keywords=")
user1417 = driver.find_element_by_id('dynamic-table').text
d1418=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1418&keywords=")
user1418 = driver.find_element_by_id('dynamic-table').text
d1419=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1419&keywords=")
user1419 = driver.find_element_by_id('dynamic-table').text
d1420=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1420&keywords=")
user1420 = driver.find_element_by_id('dynamic-table').text
d1421=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1421&keywords=")
user1421 = driver.find_element_by_id('dynamic-table').text
d1422=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1422&keywords=")
user1422 = driver.find_element_by_id('dynamic-table').text
d1423=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1423&keywords=")
user1423 = driver.find_element_by_id('dynamic-table').text
d1424=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1424&keywords=")
user1424 = driver.find_element_by_id('dynamic-table').text
d1425=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1425&keywords=")
user1425 = driver.find_element_by_id('dynamic-table').text
d1426=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1426&keywords=")
user1426 = driver.find_element_by_id('dynamic-table').text
d1427=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1427&keywords=")
user1427 = driver.find_element_by_id('dynamic-table').text
d1428=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1428&keywords=")
user1428 = driver.find_element_by_id('dynamic-table').text
d1429=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1429&keywords=")
user1429 = driver.find_element_by_id('dynamic-table').text
d1430=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1430&keywords=")
user1430 = driver.find_element_by_id('dynamic-table').text
d1431=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1431&keywords=")
user1431 = driver.find_element_by_id('dynamic-table').text
d1432=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1432&keywords=")
user1432 = driver.find_element_by_id('dynamic-table').text
d1433=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1433&keywords=")
user1433 = driver.find_element_by_id('dynamic-table').text
d1434=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1434&keywords=")
user1434 = driver.find_element_by_id('dynamic-table').text
d1435=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1435&keywords=")
user1435 = driver.find_element_by_id('dynamic-table').text
d1436=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1436&keywords=")
user1436 = driver.find_element_by_id('dynamic-table').text
d1437=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1437&keywords=")
user1437 = driver.find_element_by_id('dynamic-table').text
d1438=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1438&keywords=")
user1438 = driver.find_element_by_id('dynamic-table').text
d1439=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1439&keywords=")
user1439 = driver.find_element_by_id('dynamic-table').text
d1440=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1440&keywords=")
user1440 = driver.find_element_by_id('dynamic-table').text
d1441=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1441&keywords=")
user1441 = driver.find_element_by_id('dynamic-table').text
d1442=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1442&keywords=")
user1442 = driver.find_element_by_id('dynamic-table').text
d1443=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1443&keywords=")
user1443 = driver.find_element_by_id('dynamic-table').text
d1444=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1444&keywords=")
user1444 = driver.find_element_by_id('dynamic-table').text
d1445=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1445&keywords=")
user1445 = driver.find_element_by_id('dynamic-table').text
d1446=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1446&keywords=")
user1446 = driver.find_element_by_id('dynamic-table').text
d1447=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1447&keywords=")
user1447 = driver.find_element_by_id('dynamic-table').text
d1448=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1448&keywords=")
user1448 = driver.find_element_by_id('dynamic-table').text
d1449=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1449&keywords=")
user1449 = driver.find_element_by_id('dynamic-table').text
d1450=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1450&keywords=")
user1450 = driver.find_element_by_id('dynamic-table').text
d1451=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1451&keywords=")
user1451 = driver.find_element_by_id('dynamic-table').text
d1452=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1452&keywords=")
user1452 = driver.find_element_by_id('dynamic-table').text
d1453=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1453&keywords=")
user1453 = driver.find_element_by_id('dynamic-table').text
d1454=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1454&keywords=")
user1454 = driver.find_element_by_id('dynamic-table').text
d1455=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1455&keywords=")
user1455 = driver.find_element_by_id('dynamic-table').text
d1456=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1456&keywords=")
user1456 = driver.find_element_by_id('dynamic-table').text
d1457=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1457&keywords=")
user1457 = driver.find_element_by_id('dynamic-table').text
d1458=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1458&keywords=")
user1458 = driver.find_element_by_id('dynamic-table').text
d1459=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1459&keywords=")
user1459 = driver.find_element_by_id('dynamic-table').text
d1460=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1460&keywords=")
user1460 = driver.find_element_by_id('dynamic-table').text
d1461=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1461&keywords=")
user1461 = driver.find_element_by_id('dynamic-table').text
d1462=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1462&keywords=")
user1462 = driver.find_element_by_id('dynamic-table').text
d1463=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1463&keywords=")
user1463 = driver.find_element_by_id('dynamic-table').text
d1464=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1464&keywords=")
user1464 = driver.find_element_by_id('dynamic-table').text
d1465=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1465&keywords=")
user1465 = driver.find_element_by_id('dynamic-table').text
d1466=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1466&keywords=")
user1466 = driver.find_element_by_id('dynamic-table').text
d1467=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1467&keywords=")
user1467 = driver.find_element_by_id('dynamic-table').text
d1468=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1468&keywords=")
user1468 = driver.find_element_by_id('dynamic-table').text
d1469=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1469&keywords=")
user1469 = driver.find_element_by_id('dynamic-table').text
d1470=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1470&keywords=")
user1470 = driver.find_element_by_id('dynamic-table').text
d1471=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1471&keywords=")
user1471 = driver.find_element_by_id('dynamic-table').text
d1472=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1472&keywords=")
user1472 = driver.find_element_by_id('dynamic-table').text
d1473=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1473&keywords=")
user1473 = driver.find_element_by_id('dynamic-table').text
d1474=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1474&keywords=")
user1474 = driver.find_element_by_id('dynamic-table').text
d1475=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1475&keywords=")
user1475 = driver.find_element_by_id('dynamic-table').text
d1476=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1476&keywords=")
user1476 = driver.find_element_by_id('dynamic-table').text
d1477=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1477&keywords=")
user1477 = driver.find_element_by_id('dynamic-table').text
d1478=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1478&keywords=")
user1478 = driver.find_element_by_id('dynamic-table').text
d1479=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1479&keywords=")
user1479 = driver.find_element_by_id('dynamic-table').text
d1480=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1480&keywords=")
user1480 = driver.find_element_by_id('dynamic-table').text
d1481=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1481&keywords=")
user1481 = driver.find_element_by_id('dynamic-table').text
d1482=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1482&keywords=")
user1482 = driver.find_element_by_id('dynamic-table').text
d1483=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1483&keywords=")
user1483 = driver.find_element_by_id('dynamic-table').text
d1484=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1484&keywords=")
user1484 = driver.find_element_by_id('dynamic-table').text
d1485=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1485&keywords=")
user1485 = driver.find_element_by_id('dynamic-table').text
d1486=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1486&keywords=")
user1486 = driver.find_element_by_id('dynamic-table').text
d1487=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1487&keywords=")
user1487 = driver.find_element_by_id('dynamic-table').text
d1488=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1488&keywords=")
user1488 = driver.find_element_by_id('dynamic-table').text
d1489=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1489&keywords=")
user1489 = driver.find_element_by_id('dynamic-table').text
d1490=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1490&keywords=")
user1490 = driver.find_element_by_id('dynamic-table').text
d1491=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1491&keywords=")
user1491 = driver.find_element_by_id('dynamic-table').text
d1492=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1492&keywords=")
user1492 = driver.find_element_by_id('dynamic-table').text
d1493=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1493&keywords=")
user1493 = driver.find_element_by_id('dynamic-table').text
d1494=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1494&keywords=")
user1494 = driver.find_element_by_id('dynamic-table').text
d1495=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1495&keywords=")
user1495 = driver.find_element_by_id('dynamic-table').text
d1496=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1496&keywords=")
user1496 = driver.find_element_by_id('dynamic-table').text
d1497=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1497&keywords=")
user1497 = driver.find_element_by_id('dynamic-table').text
d1498=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1498&keywords=")
user1498 = driver.find_element_by_id('dynamic-table').text
d1499=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1499&keywords=")
user1499 = driver.find_element_by_id('dynamic-table').text
d1500=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1500&keywords=")
user1500 = driver.find_element_by_id('dynamic-table').text
d1501=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1501&keywords=")
user1501 = driver.find_element_by_id('dynamic-table').text
d1502=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1502&keywords=")
user1502 = driver.find_element_by_id('dynamic-table').text
d1503=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1503&keywords=")
user1503 = driver.find_element_by_id('dynamic-table').text
d1504=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1504&keywords=")
user1504 = driver.find_element_by_id('dynamic-table').text
d1505=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1505&keywords=")
user1505 = driver.find_element_by_id('dynamic-table').text
d1506=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1506&keywords=")
user1506 = driver.find_element_by_id('dynamic-table').text
d1507=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1507&keywords=")
user1507 = driver.find_element_by_id('dynamic-table').text
d1508=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1508&keywords=")
user1508 = driver.find_element_by_id('dynamic-table').text
d1509=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1509&keywords=")
user1509 = driver.find_element_by_id('dynamic-table').text
d1510=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1510&keywords=")
user1510 = driver.find_element_by_id('dynamic-table').text
d1511=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1511&keywords=")
user1511 = driver.find_element_by_id('dynamic-table').text
d1512=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1512&keywords=")
user1512 = driver.find_element_by_id('dynamic-table').text
d1513=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1513&keywords=")
user1513 = driver.find_element_by_id('dynamic-table').text
d1514=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1514&keywords=")
user1514 = driver.find_element_by_id('dynamic-table').text
d1515=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1515&keywords=")
user1515 = driver.find_element_by_id('dynamic-table').text
d1516=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1516&keywords=")
user1516 = driver.find_element_by_id('dynamic-table').text
d1517=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1517&keywords=")
user1517 = driver.find_element_by_id('dynamic-table').text
d1518=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1518&keywords=")
user1518 = driver.find_element_by_id('dynamic-table').text
d1519=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1519&keywords=")
user1519 = driver.find_element_by_id('dynamic-table').text
d1520=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1520&keywords=")
user1520 = driver.find_element_by_id('dynamic-table').text
d1521=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1521&keywords=")
user1521 = driver.find_element_by_id('dynamic-table').text
d1522=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1522&keywords=")
user1522 = driver.find_element_by_id('dynamic-table').text
d1523=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1523&keywords=")
user1523 = driver.find_element_by_id('dynamic-table').text
d1524=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1524&keywords=")
user1524 = driver.find_element_by_id('dynamic-table').text
d1525=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1525&keywords=")
user1525 = driver.find_element_by_id('dynamic-table').text
d1526=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1526&keywords=")
user1526 = driver.find_element_by_id('dynamic-table').text
d1527=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1527&keywords=")
user1527 = driver.find_element_by_id('dynamic-table').text
d1528=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1528&keywords=")
user1528 = driver.find_element_by_id('dynamic-table').text
d1529=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1529&keywords=")
user1529 = driver.find_element_by_id('dynamic-table').text
d1530=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1530&keywords=")
user1530 = driver.find_element_by_id('dynamic-table').text
d1531=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1531&keywords=")
user1531 = driver.find_element_by_id('dynamic-table').text
d1532=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1532&keywords=")
user1532 = driver.find_element_by_id('dynamic-table').text
d1533=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1533&keywords=")
user1533 = driver.find_element_by_id('dynamic-table').text
d1534=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1534&keywords=")
user1534 = driver.find_element_by_id('dynamic-table').text
d1535=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1535&keywords=")
user1535 = driver.find_element_by_id('dynamic-table').text
d1536=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1536&keywords=")
user1536 = driver.find_element_by_id('dynamic-table').text
d1537=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1537&keywords=")
user1537 = driver.find_element_by_id('dynamic-table').text
d1538=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1538&keywords=")
user1538 = driver.find_element_by_id('dynamic-table').text
d1539=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1539&keywords=")
user1539 = driver.find_element_by_id('dynamic-table').text
d1540=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1540&keywords=")
user1540 = driver.find_element_by_id('dynamic-table').text
d1541=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1541&keywords=")
user1541 = driver.find_element_by_id('dynamic-table').text
d1542=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1542&keywords=")
user1542 = driver.find_element_by_id('dynamic-table').text
d1543=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1543&keywords=")
user1543 = driver.find_element_by_id('dynamic-table').text
d1544=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1544&keywords=")
user1544 = driver.find_element_by_id('dynamic-table').text
d1545=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1545&keywords=")
user1545 = driver.find_element_by_id('dynamic-table').text
d1546=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1546&keywords=")
user1546 = driver.find_element_by_id('dynamic-table').text
d1547=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1547&keywords=")
user1547 = driver.find_element_by_id('dynamic-table').text
d1548=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1548&keywords=")
user1548 = driver.find_element_by_id('dynamic-table').text
d1549=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1549&keywords=")
user1549 = driver.find_element_by_id('dynamic-table').text
d1550=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1550&keywords=")
user1550 = driver.find_element_by_id('dynamic-table').text
d1551=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1551&keywords=")
user1551 = driver.find_element_by_id('dynamic-table').text
d1552=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1552&keywords=")
user1552 = driver.find_element_by_id('dynamic-table').text
d1553=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1553&keywords=")
user1553 = driver.find_element_by_id('dynamic-table').text
d1554=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1554&keywords=")
user1554 = driver.find_element_by_id('dynamic-table').text
d1555=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1555&keywords=")
user1555 = driver.find_element_by_id('dynamic-table').text
d1556=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1556&keywords=")
user1556 = driver.find_element_by_id('dynamic-table').text
d1557=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1557&keywords=")
user1557 = driver.find_element_by_id('dynamic-table').text
d1558=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1558&keywords=")
user1558 = driver.find_element_by_id('dynamic-table').text
d1559=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1559&keywords=")
user1559 = driver.find_element_by_id('dynamic-table').text
d1560=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1560&keywords=")
user1560 = driver.find_element_by_id('dynamic-table').text
d1561=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1561&keywords=")
user1561 = driver.find_element_by_id('dynamic-table').text
d1562=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1562&keywords=")
user1562 = driver.find_element_by_id('dynamic-table').text
d1563=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1563&keywords=")
user1563 = driver.find_element_by_id('dynamic-table').text
d1564=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1564&keywords=")
user1564 = driver.find_element_by_id('dynamic-table').text
d1565=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1565&keywords=")
user1565 = driver.find_element_by_id('dynamic-table').text
d1566=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1566&keywords=")
user1566 = driver.find_element_by_id('dynamic-table').text
d1567=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1567&keywords=")
user1567 = driver.find_element_by_id('dynamic-table').text
d1568=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1568&keywords=")
user1568 = driver.find_element_by_id('dynamic-table').text
d1569=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1569&keywords=")
user1569 = driver.find_element_by_id('dynamic-table').text
d1570=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1570&keywords=")
user1570 = driver.find_element_by_id('dynamic-table').text
d1571=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1571&keywords=")
user1571 = driver.find_element_by_id('dynamic-table').text
d1572=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1572&keywords=")
user1572 = driver.find_element_by_id('dynamic-table').text
d1573=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1573&keywords=")
user1573 = driver.find_element_by_id('dynamic-table').text
d1574=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1574&keywords=")
user1574 = driver.find_element_by_id('dynamic-table').text
d1575=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1575&keywords=")
user1575 = driver.find_element_by_id('dynamic-table').text
d1576=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1576&keywords=")
user1576 = driver.find_element_by_id('dynamic-table').text
d1577=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1577&keywords=")
user1577 = driver.find_element_by_id('dynamic-table').text
d1578=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1578&keywords=")
user1578 = driver.find_element_by_id('dynamic-table').text
d1579=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1579&keywords=")
user1579 = driver.find_element_by_id('dynamic-table').text
d1580=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1580&keywords=")
user1580 = driver.find_element_by_id('dynamic-table').text
d1581=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1581&keywords=")
user1581 = driver.find_element_by_id('dynamic-table').text
d1582=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1582&keywords=")
user1582 = driver.find_element_by_id('dynamic-table').text
d1583=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1583&keywords=")
user1583 = driver.find_element_by_id('dynamic-table').text
d1584=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1584&keywords=")
user1584 = driver.find_element_by_id('dynamic-table').text
d1585=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1585&keywords=")
user1585 = driver.find_element_by_id('dynamic-table').text
d1586=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1586&keywords=")
user1586 = driver.find_element_by_id('dynamic-table').text
d1587=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1587&keywords=")
user1587 = driver.find_element_by_id('dynamic-table').text
d1588=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1588&keywords=")
user1588 = driver.find_element_by_id('dynamic-table').text
d1589=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1589&keywords=")
user1589 = driver.find_element_by_id('dynamic-table').text
d1590=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1590&keywords=")
user1590 = driver.find_element_by_id('dynamic-table').text
d1591=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1591&keywords=")
user1591 = driver.find_element_by_id('dynamic-table').text
d1592=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1592&keywords=")
user1592 = driver.find_element_by_id('dynamic-table').text
d1593=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1593&keywords=")
user1593 = driver.find_element_by_id('dynamic-table').text
d1594=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1594&keywords=")
user1594 = driver.find_element_by_id('dynamic-table').text
d1595=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1595&keywords=")
user1595 = driver.find_element_by_id('dynamic-table').text
d1596=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1596&keywords=")
user1596 = driver.find_element_by_id('dynamic-table').text
d1597=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1597&keywords=")
user1597 = driver.find_element_by_id('dynamic-table').text
d1598=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1598&keywords=")
user1598 = driver.find_element_by_id('dynamic-table').text
d1599=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1599&keywords=")
user1599 = driver.find_element_by_id('dynamic-table').text
d1600=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1600&keywords=")
user1600 = driver.find_element_by_id('dynamic-table').text
d1601=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1601&keywords=")
user1601 = driver.find_element_by_id('dynamic-table').text
d1602=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1602&keywords=")
user1602 = driver.find_element_by_id('dynamic-table').text
d1603=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1603&keywords=")
user1603 = driver.find_element_by_id('dynamic-table').text
d1604=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1604&keywords=")
user1604 = driver.find_element_by_id('dynamic-table').text
d1605=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1605&keywords=")
user1605 = driver.find_element_by_id('dynamic-table').text
d1606=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1606&keywords=")
user1606 = driver.find_element_by_id('dynamic-table').text
d1607=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1607&keywords=")
user1607 = driver.find_element_by_id('dynamic-table').text
d1608=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1608&keywords=")
user1608 = driver.find_element_by_id('dynamic-table').text
d1609=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1609&keywords=")
user1609 = driver.find_element_by_id('dynamic-table').text
d1610=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1610&keywords=")
user1610 = driver.find_element_by_id('dynamic-table').text
d1611=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1611&keywords=")
user1611 = driver.find_element_by_id('dynamic-table').text
d1612=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1612&keywords=")
user1612 = driver.find_element_by_id('dynamic-table').text
d1613=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1613&keywords=")
user1613 = driver.find_element_by_id('dynamic-table').text
d1614=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1614&keywords=")
user1614 = driver.find_element_by_id('dynamic-table').text
d1615=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1615&keywords=")
user1615 = driver.find_element_by_id('dynamic-table').text
d1616=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1616&keywords=")
user1616 = driver.find_element_by_id('dynamic-table').text
d1617=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1617&keywords=")
user1617 = driver.find_element_by_id('dynamic-table').text
d1618=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1618&keywords=")
user1618 = driver.find_element_by_id('dynamic-table').text
d1619=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1619&keywords=")
user1619 = driver.find_element_by_id('dynamic-table').text
d1620=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1620&keywords=")
user1620 = driver.find_element_by_id('dynamic-table').text
d1621=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1621&keywords=")
user1621 = driver.find_element_by_id('dynamic-table').text
d1622=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1622&keywords=")
user1622 = driver.find_element_by_id('dynamic-table').text
d1623=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1623&keywords=")
user1623 = driver.find_element_by_id('dynamic-table').text
d1624=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1624&keywords=")
user1624 = driver.find_element_by_id('dynamic-table').text
d1625=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1625&keywords=")
user1625 = driver.find_element_by_id('dynamic-table').text
d1626=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1626&keywords=")
user1626 = driver.find_element_by_id('dynamic-table').text
d1627=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1627&keywords=")
user1627 = driver.find_element_by_id('dynamic-table').text
d1628=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1628&keywords=")
user1628 = driver.find_element_by_id('dynamic-table').text
d1629=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1629&keywords=")
user1629 = driver.find_element_by_id('dynamic-table').text
d1630=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1630&keywords=")
user1630 = driver.find_element_by_id('dynamic-table').text
d1631=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1631&keywords=")
user1631 = driver.find_element_by_id('dynamic-table').text
d1632=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1632&keywords=")
user1632 = driver.find_element_by_id('dynamic-table').text
d1633=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1633&keywords=")
user1633 = driver.find_element_by_id('dynamic-table').text
d1634=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1634&keywords=")
user1634 = driver.find_element_by_id('dynamic-table').text
d1635=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1635&keywords=")
user1635 = driver.find_element_by_id('dynamic-table').text
d1636=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1636&keywords=")
user1636 = driver.find_element_by_id('dynamic-table').text
d1637=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1637&keywords=")
user1637 = driver.find_element_by_id('dynamic-table').text
d1638=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1638&keywords=")
user1638 = driver.find_element_by_id('dynamic-table').text
d1639=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1639&keywords=")
user1639 = driver.find_element_by_id('dynamic-table').text
d1640=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1640&keywords=")
user1640 = driver.find_element_by_id('dynamic-table').text
d1641=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1641&keywords=")
user1641 = driver.find_element_by_id('dynamic-table').text
d1642=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1642&keywords=")
user1642 = driver.find_element_by_id('dynamic-table').text
d1643=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1643&keywords=")
user1643 = driver.find_element_by_id('dynamic-table').text
d1644=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1644&keywords=")
user1644 = driver.find_element_by_id('dynamic-table').text
d1645=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1645&keywords=")
user1645 = driver.find_element_by_id('dynamic-table').text
d1646=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1646&keywords=")
user1646 = driver.find_element_by_id('dynamic-table').text
d1647=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1647&keywords=")
user1647 = driver.find_element_by_id('dynamic-table').text
d1648=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1648&keywords=")
user1648 = driver.find_element_by_id('dynamic-table').text
d1649=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1649&keywords=")
user1649 = driver.find_element_by_id('dynamic-table').text
d1650=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1650&keywords=")
user1650 = driver.find_element_by_id('dynamic-table').text
d1651=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1651&keywords=")
user1651 = driver.find_element_by_id('dynamic-table').text
d1652=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1652&keywords=")
user1652 = driver.find_element_by_id('dynamic-table').text
d1653=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1653&keywords=")
user1653 = driver.find_element_by_id('dynamic-table').text
d1654=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1654&keywords=")
user1654 = driver.find_element_by_id('dynamic-table').text
d1655=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1655&keywords=")
user1655 = driver.find_element_by_id('dynamic-table').text
d1656=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1656&keywords=")
user1656 = driver.find_element_by_id('dynamic-table').text
d1657=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1657&keywords=")
user1657 = driver.find_element_by_id('dynamic-table').text
d1658=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1658&keywords=")
user1658 = driver.find_element_by_id('dynamic-table').text
d1659=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1659&keywords=")
user1659 = driver.find_element_by_id('dynamic-table').text
d1660=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1660&keywords=")
user1660 = driver.find_element_by_id('dynamic-table').text
d1661=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1661&keywords=")
user1661 = driver.find_element_by_id('dynamic-table').text
d1662=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1662&keywords=")
user1662 = driver.find_element_by_id('dynamic-table').text
d1663=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1663&keywords=")
user1663 = driver.find_element_by_id('dynamic-table').text
d1664=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1664&keywords=")
user1664 = driver.find_element_by_id('dynamic-table').text
d1665=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1665&keywords=")
user1665 = driver.find_element_by_id('dynamic-table').text
d1666=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1666&keywords=")
user1666 = driver.find_element_by_id('dynamic-table').text
d1667=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1667&keywords=")
user1667 = driver.find_element_by_id('dynamic-table').text
d1668=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1668&keywords=")
user1668 = driver.find_element_by_id('dynamic-table').text
d1669=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1669&keywords=")
user1669 = driver.find_element_by_id('dynamic-table').text
d1670=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1670&keywords=")
user1670 = driver.find_element_by_id('dynamic-table').text
d1671=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1671&keywords=")
user1671 = driver.find_element_by_id('dynamic-table').text
d1672=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1672&keywords=")
user1672 = driver.find_element_by_id('dynamic-table').text
d1673=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1673&keywords=")
user1673 = driver.find_element_by_id('dynamic-table').text
d1674=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1674&keywords=")
user1674 = driver.find_element_by_id('dynamic-table').text
d1675=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1675&keywords=")
user1675 = driver.find_element_by_id('dynamic-table').text
d1676=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1676&keywords=")
user1676 = driver.find_element_by_id('dynamic-table').text
d1677=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1677&keywords=")
user1677 = driver.find_element_by_id('dynamic-table').text
d1678=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1678&keywords=")
user1678 = driver.find_element_by_id('dynamic-table').text
d1679=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1679&keywords=")
user1679 = driver.find_element_by_id('dynamic-table').text
d1680=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1680&keywords=")
user1680 = driver.find_element_by_id('dynamic-table').text
d1681=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1681&keywords=")
user1681 = driver.find_element_by_id('dynamic-table').text
d1682=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1682&keywords=")
user1682 = driver.find_element_by_id('dynamic-table').text
d1683=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1683&keywords=")
user1683 = driver.find_element_by_id('dynamic-table').text
d1684=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1684&keywords=")
user1684 = driver.find_element_by_id('dynamic-table').text
d1685=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1685&keywords=")
user1685 = driver.find_element_by_id('dynamic-table').text
d1686=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1686&keywords=")
user1686 = driver.find_element_by_id('dynamic-table').text
d1687=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1687&keywords=")
user1687 = driver.find_element_by_id('dynamic-table').text
d1688=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1688&keywords=")
user1688 = driver.find_element_by_id('dynamic-table').text
d1689=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1689&keywords=")
user1689 = driver.find_element_by_id('dynamic-table').text
d1690=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1690&keywords=")
user1690 = driver.find_element_by_id('dynamic-table').text
d1691=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1691&keywords=")
user1691 = driver.find_element_by_id('dynamic-table').text
d1692=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1692&keywords=")
user1692 = driver.find_element_by_id('dynamic-table').text
d1693=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1693&keywords=")
user1693 = driver.find_element_by_id('dynamic-table').text
d1694=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1694&keywords=")
user1694 = driver.find_element_by_id('dynamic-table').text
d1695=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1695&keywords=")
user1695 = driver.find_element_by_id('dynamic-table').text
d1696=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1696&keywords=")
user1696 = driver.find_element_by_id('dynamic-table').text
d1697=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1697&keywords=")
user1697 = driver.find_element_by_id('dynamic-table').text
d1698=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1698&keywords=")
user1698 = driver.find_element_by_id('dynamic-table').text
d1699=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1699&keywords=")
user1699 = driver.find_element_by_id('dynamic-table').text
d1700=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1700&keywords=")
user1700 = driver.find_element_by_id('dynamic-table').text
d1701=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1701&keywords=")
user1701 = driver.find_element_by_id('dynamic-table').text
d1702=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1702&keywords=")
user1702 = driver.find_element_by_id('dynamic-table').text
d1703=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1703&keywords=")
user1703 = driver.find_element_by_id('dynamic-table').text
d1704=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1704&keywords=")
user1704 = driver.find_element_by_id('dynamic-table').text
d1705=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1705&keywords=")
user1705 = driver.find_element_by_id('dynamic-table').text
d1706=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1706&keywords=")
user1706 = driver.find_element_by_id('dynamic-table').text
d1707=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1707&keywords=")
user1707 = driver.find_element_by_id('dynamic-table').text
d1708=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1708&keywords=")
user1708 = driver.find_element_by_id('dynamic-table').text
d1709=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1709&keywords=")
user1709 = driver.find_element_by_id('dynamic-table').text
d1710=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1710&keywords=")
user1710 = driver.find_element_by_id('dynamic-table').text
d1711=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1711&keywords=")
user1711 = driver.find_element_by_id('dynamic-table').text
d1712=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1712&keywords=")
user1712 = driver.find_element_by_id('dynamic-table').text
d1713=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1713&keywords=")
user1713 = driver.find_element_by_id('dynamic-table').text
d1714=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1714&keywords=")
user1714 = driver.find_element_by_id('dynamic-table').text
d1715=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1715&keywords=")
user1715 = driver.find_element_by_id('dynamic-table').text
d1716=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1716&keywords=")
user1716 = driver.find_element_by_id('dynamic-table').text
d1717=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1717&keywords=")
user1717 = driver.find_element_by_id('dynamic-table').text
d1718=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1718&keywords=")
user1718 = driver.find_element_by_id('dynamic-table').text
d1719=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1719&keywords=")
user1719 = driver.find_element_by_id('dynamic-table').text
d1720=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1720&keywords=")
user1720 = driver.find_element_by_id('dynamic-table').text
d1721=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1721&keywords=")
user1721 = driver.find_element_by_id('dynamic-table').text
d1722=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1722&keywords=")
user1722 = driver.find_element_by_id('dynamic-table').text
d1723=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1723&keywords=")
user1723 = driver.find_element_by_id('dynamic-table').text
d1724=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1724&keywords=")
user1724 = driver.find_element_by_id('dynamic-table').text
d1725=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1725&keywords=")
user1725 = driver.find_element_by_id('dynamic-table').text
d1726=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1726&keywords=")
user1726 = driver.find_element_by_id('dynamic-table').text
d1727=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1727&keywords=")
user1727 = driver.find_element_by_id('dynamic-table').text
d1728=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1728&keywords=")
user1728 = driver.find_element_by_id('dynamic-table').text
d1729=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1729&keywords=")
user1729 = driver.find_element_by_id('dynamic-table').text
d1730=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1730&keywords=")
user1730 = driver.find_element_by_id('dynamic-table').text
d1731=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1731&keywords=")
user1731 = driver.find_element_by_id('dynamic-table').text
d1732=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1732&keywords=")
user1732 = driver.find_element_by_id('dynamic-table').text
d1733=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1733&keywords=")
user1733 = driver.find_element_by_id('dynamic-table').text
d1734=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1734&keywords=")
user1734 = driver.find_element_by_id('dynamic-table').text
d1735=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1735&keywords=")
user1735 = driver.find_element_by_id('dynamic-table').text
d1736=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1736&keywords=")
user1736 = driver.find_element_by_id('dynamic-table').text
d1737=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1737&keywords=")
user1737 = driver.find_element_by_id('dynamic-table').text
d1738=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1738&keywords=")
user1738 = driver.find_element_by_id('dynamic-table').text
d1739=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1739&keywords=")
user1739 = driver.find_element_by_id('dynamic-table').text
d1740=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1740&keywords=")
user1740 = driver.find_element_by_id('dynamic-table').text
d1741=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1741&keywords=")
user1741 = driver.find_element_by_id('dynamic-table').text
d1742=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1742&keywords=")
user1742 = driver.find_element_by_id('dynamic-table').text
d1743=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1743&keywords=")
user1743 = driver.find_element_by_id('dynamic-table').text
d1744=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1744&keywords=")
user1744 = driver.find_element_by_id('dynamic-table').text
d1745=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1745&keywords=")
user1745 = driver.find_element_by_id('dynamic-table').text
d1746=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1746&keywords=")
user1746 = driver.find_element_by_id('dynamic-table').text
d1747=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1747&keywords=")
user1747 = driver.find_element_by_id('dynamic-table').text
d1748=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1748&keywords=")
user1748 = driver.find_element_by_id('dynamic-table').text
d1749=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1749&keywords=")
user1749 = driver.find_element_by_id('dynamic-table').text
d1750=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1750&keywords=")
user1750 = driver.find_element_by_id('dynamic-table').text
d1751=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1751&keywords=")
user1751 = driver.find_element_by_id('dynamic-table').text
d1752=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1752&keywords=")
user1752 = driver.find_element_by_id('dynamic-table').text
d1753=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1753&keywords=")
user1753 = driver.find_element_by_id('dynamic-table').text
d1754=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1754&keywords=")
user1754 = driver.find_element_by_id('dynamic-table').text
d1755=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1755&keywords=")
user1755 = driver.find_element_by_id('dynamic-table').text
d1756=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1756&keywords=")
user1756 = driver.find_element_by_id('dynamic-table').text
d1757=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1757&keywords=")
user1757 = driver.find_element_by_id('dynamic-table').text
d1758=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1758&keywords=")
user1758 = driver.find_element_by_id('dynamic-table').text
d1759=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1759&keywords=")
user1759 = driver.find_element_by_id('dynamic-table').text
d1760=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1760&keywords=")
user1760 = driver.find_element_by_id('dynamic-table').text
d1761=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1761&keywords=")
user1761 = driver.find_element_by_id('dynamic-table').text
d1762=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1762&keywords=")
user1762 = driver.find_element_by_id('dynamic-table').text
d1763=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1763&keywords=")
user1763 = driver.find_element_by_id('dynamic-table').text
d1764=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1764&keywords=")
user1764 = driver.find_element_by_id('dynamic-table').text
d1765=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1765&keywords=")
user1765 = driver.find_element_by_id('dynamic-table').text
d1766=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1766&keywords=")
user1766 = driver.find_element_by_id('dynamic-table').text
d1767=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1767&keywords=")
user1767 = driver.find_element_by_id('dynamic-table').text
d1768=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1768&keywords=")
user1768 = driver.find_element_by_id('dynamic-table').text
d1769=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1769&keywords=")
user1769 = driver.find_element_by_id('dynamic-table').text
d1770=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1770&keywords=")
user1770 = driver.find_element_by_id('dynamic-table').text
d1771=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1771&keywords=")
user1771 = driver.find_element_by_id('dynamic-table').text
d1772=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1772&keywords=")
user1772 = driver.find_element_by_id('dynamic-table').text
d1773=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1773&keywords=")
user1773 = driver.find_element_by_id('dynamic-table').text
d1774=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1774&keywords=")
user1774 = driver.find_element_by_id('dynamic-table').text
d1775=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1775&keywords=")
user1775 = driver.find_element_by_id('dynamic-table').text
d1776=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1776&keywords=")
user1776 = driver.find_element_by_id('dynamic-table').text
d1777=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1777&keywords=")
user1777 = driver.find_element_by_id('dynamic-table').text
d1778=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1778&keywords=")
user1778 = driver.find_element_by_id('dynamic-table').text
d1779=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1779&keywords=")
user1779 = driver.find_element_by_id('dynamic-table').text
d1780=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1780&keywords=")
user1780 = driver.find_element_by_id('dynamic-table').text
d1781=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1781&keywords=")
user1781 = driver.find_element_by_id('dynamic-table').text
d1782=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1782&keywords=")
user1782 = driver.find_element_by_id('dynamic-table').text
d1783=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1783&keywords=")
user1783 = driver.find_element_by_id('dynamic-table').text
d1784=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1784&keywords=")
user1784 = driver.find_element_by_id('dynamic-table').text
d1785=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1785&keywords=")
user1785 = driver.find_element_by_id('dynamic-table').text
d1786=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1786&keywords=")
user1786 = driver.find_element_by_id('dynamic-table').text
d1787=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1787&keywords=")
user1787 = driver.find_element_by_id('dynamic-table').text
d1788=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1788&keywords=")
user1788 = driver.find_element_by_id('dynamic-table').text
d1789=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1789&keywords=")
user1789 = driver.find_element_by_id('dynamic-table').text
d1790=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1790&keywords=")
user1790 = driver.find_element_by_id('dynamic-table').text
d1791=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1791&keywords=")
user1791 = driver.find_element_by_id('dynamic-table').text
d1792=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1792&keywords=")
user1792 = driver.find_element_by_id('dynamic-table').text
d1793=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1793&keywords=")
user1793 = driver.find_element_by_id('dynamic-table').text
d1794=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1794&keywords=")
user1794 = driver.find_element_by_id('dynamic-table').text
d1795=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1795&keywords=")
user1795 = driver.find_element_by_id('dynamic-table').text
d1796=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1796&keywords=")
user1796 = driver.find_element_by_id('dynamic-table').text
d1797=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1797&keywords=")
user1797 = driver.find_element_by_id('dynamic-table').text
d1798=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1798&keywords=")
user1798 = driver.find_element_by_id('dynamic-table').text
d1799=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1799&keywords=")
user1799 = driver.find_element_by_id('dynamic-table').text
d1800=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1800&keywords=")
user1800 = driver.find_element_by_id('dynamic-table').text
d1801=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1801&keywords=")
user1801 = driver.find_element_by_id('dynamic-table').text
d1802=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1802&keywords=")
user1802 = driver.find_element_by_id('dynamic-table').text
d1803=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1803&keywords=")
user1803 = driver.find_element_by_id('dynamic-table').text
d1804=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1804&keywords=")
user1804 = driver.find_element_by_id('dynamic-table').text
d1805=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1805&keywords=")
user1805 = driver.find_element_by_id('dynamic-table').text
d1806=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1806&keywords=")
user1806 = driver.find_element_by_id('dynamic-table').text
d1807=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1807&keywords=")
user1807 = driver.find_element_by_id('dynamic-table').text
d1808=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1808&keywords=")
user1808 = driver.find_element_by_id('dynamic-table').text
d1809=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1809&keywords=")
user1809 = driver.find_element_by_id('dynamic-table').text
d1810=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1810&keywords=")
user1810 = driver.find_element_by_id('dynamic-table').text
d1811=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1811&keywords=")
user1811 = driver.find_element_by_id('dynamic-table').text
d1812=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1812&keywords=")
user1812 = driver.find_element_by_id('dynamic-table').text
d1813=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1813&keywords=")
user1813 = driver.find_element_by_id('dynamic-table').text
d1814=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1814&keywords=")
user1814 = driver.find_element_by_id('dynamic-table').text
d1815=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1815&keywords=")
user1815 = driver.find_element_by_id('dynamic-table').text
d1816=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1816&keywords=")
user1816 = driver.find_element_by_id('dynamic-table').text
d1817=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1817&keywords=")
user1817 = driver.find_element_by_id('dynamic-table').text
d1818=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1818&keywords=")
user1818 = driver.find_element_by_id('dynamic-table').text
d1819=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1819&keywords=")
user1819 = driver.find_element_by_id('dynamic-table').text
d1820=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1820&keywords=")
user1820 = driver.find_element_by_id('dynamic-table').text
d1821=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1821&keywords=")
user1821 = driver.find_element_by_id('dynamic-table').text
d1822=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1822&keywords=")
user1822 = driver.find_element_by_id('dynamic-table').text
d1823=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1823&keywords=")
user1823 = driver.find_element_by_id('dynamic-table').text
d1824=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1824&keywords=")
user1824 = driver.find_element_by_id('dynamic-table').text
d1825=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1825&keywords=")
user1825 = driver.find_element_by_id('dynamic-table').text
d1826=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1826&keywords=")
user1826 = driver.find_element_by_id('dynamic-table').text
d1827=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1827&keywords=")
user1827 = driver.find_element_by_id('dynamic-table').text
d1828=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1828&keywords=")
user1828 = driver.find_element_by_id('dynamic-table').text
d1829=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1829&keywords=")
user1829 = driver.find_element_by_id('dynamic-table').text
d1830=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1830&keywords=")
user1830 = driver.find_element_by_id('dynamic-table').text
d1831=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1831&keywords=")
user1831 = driver.find_element_by_id('dynamic-table').text
d1832=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1832&keywords=")
user1832 = driver.find_element_by_id('dynamic-table').text
d1833=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1833&keywords=")
user1833 = driver.find_element_by_id('dynamic-table').text
d1834=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1834&keywords=")
user1834 = driver.find_element_by_id('dynamic-table').text
d1835=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1835&keywords=")
user1835 = driver.find_element_by_id('dynamic-table').text
d1836=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1836&keywords=")
user1836 = driver.find_element_by_id('dynamic-table').text
d1837=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1837&keywords=")
user1837 = driver.find_element_by_id('dynamic-table').text
d1838=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1838&keywords=")
user1838 = driver.find_element_by_id('dynamic-table').text
d1839=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1839&keywords=")
user1839 = driver.find_element_by_id('dynamic-table').text
d1840=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1840&keywords=")
user1840 = driver.find_element_by_id('dynamic-table').text
d1841=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1841&keywords=")
user1841 = driver.find_element_by_id('dynamic-table').text
d1842=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1842&keywords=")
user1842 = driver.find_element_by_id('dynamic-table').text
d1843=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1843&keywords=")
user1843 = driver.find_element_by_id('dynamic-table').text
d1844=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1844&keywords=")
user1844 = driver.find_element_by_id('dynamic-table').text
d1845=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1845&keywords=")
user1845 = driver.find_element_by_id('dynamic-table').text
d1846=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1846&keywords=")
user1846 = driver.find_element_by_id('dynamic-table').text
d1847=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1847&keywords=")
user1847 = driver.find_element_by_id('dynamic-table').text
d1848=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1848&keywords=")
user1848 = driver.find_element_by_id('dynamic-table').text
d1849=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1849&keywords=")
user1849 = driver.find_element_by_id('dynamic-table').text
d1850=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1850&keywords=")
user1850 = driver.find_element_by_id('dynamic-table').text
d1851=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1851&keywords=")
user1851 = driver.find_element_by_id('dynamic-table').text
d1852=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1852&keywords=")
user1852 = driver.find_element_by_id('dynamic-table').text
d1853=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1853&keywords=")
user1853 = driver.find_element_by_id('dynamic-table').text
d1854=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1854&keywords=")
user1854 = driver.find_element_by_id('dynamic-table').text
d1855=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1855&keywords=")
user1855 = driver.find_element_by_id('dynamic-table').text
d1856=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1856&keywords=")
user1856 = driver.find_element_by_id('dynamic-table').text
d1857=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1857&keywords=")
user1857 = driver.find_element_by_id('dynamic-table').text
d1858=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1858&keywords=")
user1858 = driver.find_element_by_id('dynamic-table').text
d1859=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1859&keywords=")
user1859 = driver.find_element_by_id('dynamic-table').text
d1860=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1860&keywords=")
user1860 = driver.find_element_by_id('dynamic-table').text
d1861=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1861&keywords=")
user1861 = driver.find_element_by_id('dynamic-table').text
d1862=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1862&keywords=")
user1862 = driver.find_element_by_id('dynamic-table').text
d1863=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1863&keywords=")
user1863 = driver.find_element_by_id('dynamic-table').text
d1864=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1864&keywords=")
user1864 = driver.find_element_by_id('dynamic-table').text
d1865=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1865&keywords=")
user1865 = driver.find_element_by_id('dynamic-table').text
d1866=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1866&keywords=")
user1866 = driver.find_element_by_id('dynamic-table').text
d1867=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1867&keywords=")
user1867 = driver.find_element_by_id('dynamic-table').text
d1868=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1868&keywords=")
user1868 = driver.find_element_by_id('dynamic-table').text
d1869=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1869&keywords=")
user1869 = driver.find_element_by_id('dynamic-table').text
d1870=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1870&keywords=")
user1870 = driver.find_element_by_id('dynamic-table').text
d1871=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1871&keywords=")
user1871 = driver.find_element_by_id('dynamic-table').text
d1872=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1872&keywords=")
user1872 = driver.find_element_by_id('dynamic-table').text
d1873=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1873&keywords=")
user1873 = driver.find_element_by_id('dynamic-table').text
d1874=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1874&keywords=")
user1874 = driver.find_element_by_id('dynamic-table').text
d1875=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1875&keywords=")
user1875 = driver.find_element_by_id('dynamic-table').text
d1876=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1876&keywords=")
user1876 = driver.find_element_by_id('dynamic-table').text
d1877=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1877&keywords=")
user1877 = driver.find_element_by_id('dynamic-table').text
d1878=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1878&keywords=")
user1878 = driver.find_element_by_id('dynamic-table').text
d1879=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1879&keywords=")
user1879 = driver.find_element_by_id('dynamic-table').text
d1880=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1880&keywords=")
user1880 = driver.find_element_by_id('dynamic-table').text
d1881=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1881&keywords=")
user1881 = driver.find_element_by_id('dynamic-table').text
d1882=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1882&keywords=")
user1882 = driver.find_element_by_id('dynamic-table').text
d1883=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1883&keywords=")
user1883 = driver.find_element_by_id('dynamic-table').text
d1884=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1884&keywords=")
user1884 = driver.find_element_by_id('dynamic-table').text
d1885=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1885&keywords=")
user1885 = driver.find_element_by_id('dynamic-table').text
d1886=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1886&keywords=")
user1886 = driver.find_element_by_id('dynamic-table').text
d1887=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1887&keywords=")
user1887 = driver.find_element_by_id('dynamic-table').text
d1888=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1888&keywords=")
user1888 = driver.find_element_by_id('dynamic-table').text
d1889=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1889&keywords=")
user1889 = driver.find_element_by_id('dynamic-table').text
d1890=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1890&keywords=")
user1890 = driver.find_element_by_id('dynamic-table').text
d1891=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1891&keywords=")
user1891 = driver.find_element_by_id('dynamic-table').text
d1892=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1892&keywords=")
user1892 = driver.find_element_by_id('dynamic-table').text
d1893=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1893&keywords=")
user1893 = driver.find_element_by_id('dynamic-table').text
d1894=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1894&keywords=")
user1894 = driver.find_element_by_id('dynamic-table').text
d1895=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1895&keywords=")
user1895 = driver.find_element_by_id('dynamic-table').text
d1896=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1896&keywords=")
user1896 = driver.find_element_by_id('dynamic-table').text
d1897=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1897&keywords=")
user1897 = driver.find_element_by_id('dynamic-table').text
d1898=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1898&keywords=")
user1898 = driver.find_element_by_id('dynamic-table').text
d1899=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1899&keywords=")
user1899 = driver.find_element_by_id('dynamic-table').text
d1900=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1900&keywords=")
user1900 = driver.find_element_by_id('dynamic-table').text
d1901=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1901&keywords=")
user1901 = driver.find_element_by_id('dynamic-table').text
d1902=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1902&keywords=")
user1902 = driver.find_element_by_id('dynamic-table').text
d1903=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1903&keywords=")
user1903 = driver.find_element_by_id('dynamic-table').text
d1904=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1904&keywords=")
user1904 = driver.find_element_by_id('dynamic-table').text
d1905=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1905&keywords=")
user1905 = driver.find_element_by_id('dynamic-table').text
d1906=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1906&keywords=")
user1906 = driver.find_element_by_id('dynamic-table').text
d1907=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1907&keywords=")
user1907 = driver.find_element_by_id('dynamic-table').text
d1908=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1908&keywords=")
user1908 = driver.find_element_by_id('dynamic-table').text
d1909=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1909&keywords=")
user1909 = driver.find_element_by_id('dynamic-table').text
d1910=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1910&keywords=")
user1910 = driver.find_element_by_id('dynamic-table').text
d1911=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1911&keywords=")
user1911 = driver.find_element_by_id('dynamic-table').text
d1912=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1912&keywords=")
user1912 = driver.find_element_by_id('dynamic-table').text
d1913=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1913&keywords=")
user1913 = driver.find_element_by_id('dynamic-table').text
d1914=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1914&keywords=")
user1914 = driver.find_element_by_id('dynamic-table').text
d1915=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1915&keywords=")
user1915 = driver.find_element_by_id('dynamic-table').text
d1916=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1916&keywords=")
user1916 = driver.find_element_by_id('dynamic-table').text
d1917=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1917&keywords=")
user1917 = driver.find_element_by_id('dynamic-table').text
d1918=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1918&keywords=")
user1918 = driver.find_element_by_id('dynamic-table').text
d1919=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1919&keywords=")
user1919 = driver.find_element_by_id('dynamic-table').text
d1920=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1920&keywords=")
user1920 = driver.find_element_by_id('dynamic-table').text
d1921=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1921&keywords=")
user1921 = driver.find_element_by_id('dynamic-table').text
d1922=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1922&keywords=")
user1922 = driver.find_element_by_id('dynamic-table').text
d1923=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1923&keywords=")
user1923 = driver.find_element_by_id('dynamic-table').text
d1924=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1924&keywords=")
user1924 = driver.find_element_by_id('dynamic-table').text
d1925=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1925&keywords=")
user1925 = driver.find_element_by_id('dynamic-table').text
d1926=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1926&keywords=")
user1926 = driver.find_element_by_id('dynamic-table').text
d1927=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1927&keywords=")
user1927 = driver.find_element_by_id('dynamic-table').text
d1928=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1928&keywords=")
user1928 = driver.find_element_by_id('dynamic-table').text
d1929=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1929&keywords=")
user1929 = driver.find_element_by_id('dynamic-table').text
d1930=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1930&keywords=")
user1930 = driver.find_element_by_id('dynamic-table').text
d1931=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1931&keywords=")
user1931 = driver.find_element_by_id('dynamic-table').text
d1932=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1932&keywords=")
user1932 = driver.find_element_by_id('dynamic-table').text
d1933=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1933&keywords=")
user1933 = driver.find_element_by_id('dynamic-table').text
d1934=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1934&keywords=")
user1934 = driver.find_element_by_id('dynamic-table').text
d1935=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1935&keywords=")
user1935 = driver.find_element_by_id('dynamic-table').text
d1936=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1936&keywords=")
user1936 = driver.find_element_by_id('dynamic-table').text
d1937=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1937&keywords=")
user1937 = driver.find_element_by_id('dynamic-table').text
d1938=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1938&keywords=")
user1938 = driver.find_element_by_id('dynamic-table').text
d1939=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1939&keywords=")
user1939 = driver.find_element_by_id('dynamic-table').text
d1940=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1940&keywords=")
user1940 = driver.find_element_by_id('dynamic-table').text
d1941=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1941&keywords=")
user1941 = driver.find_element_by_id('dynamic-table').text
d1942=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1942&keywords=")
user1942 = driver.find_element_by_id('dynamic-table').text
d1943=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1943&keywords=")
user1943 = driver.find_element_by_id('dynamic-table').text
d1944=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1944&keywords=")
user1944 = driver.find_element_by_id('dynamic-table').text
d1945=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1945&keywords=")
user1945 = driver.find_element_by_id('dynamic-table').text
d1946=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1946&keywords=")
user1946 = driver.find_element_by_id('dynamic-table').text
d1947=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1947&keywords=")
user1947 = driver.find_element_by_id('dynamic-table').text
d1948=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1948&keywords=")
user1948 = driver.find_element_by_id('dynamic-table').text
d1949=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1949&keywords=")
user1949 = driver.find_element_by_id('dynamic-table').text
d1950=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1950&keywords=")
user1950 = driver.find_element_by_id('dynamic-table').text
d1951=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1951&keywords=")
user1951 = driver.find_element_by_id('dynamic-table').text
d1952=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1952&keywords=")
user1952 = driver.find_element_by_id('dynamic-table').text
d1953=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1953&keywords=")
user1953 = driver.find_element_by_id('dynamic-table').text
d1954=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1954&keywords=")
user1954 = driver.find_element_by_id('dynamic-table').text
d1955=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1955&keywords=")
user1955 = driver.find_element_by_id('dynamic-table').text
d1956=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1956&keywords=")
user1956 = driver.find_element_by_id('dynamic-table').text
d1957=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1957&keywords=")
user1957 = driver.find_element_by_id('dynamic-table').text
d1958=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1958&keywords=")
user1958 = driver.find_element_by_id('dynamic-table').text
d1959=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1959&keywords=")
user1959 = driver.find_element_by_id('dynamic-table').text
d1960=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1960&keywords=")
user1960 = driver.find_element_by_id('dynamic-table').text
d1961=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1961&keywords=")
user1961 = driver.find_element_by_id('dynamic-table').text
d1962=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1962&keywords=")
user1962 = driver.find_element_by_id('dynamic-table').text
d1963=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1963&keywords=")
user1963 = driver.find_element_by_id('dynamic-table').text
d1964=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1964&keywords=")
user1964 = driver.find_element_by_id('dynamic-table').text
d1965=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1965&keywords=")
user1965 = driver.find_element_by_id('dynamic-table').text
d1966=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1966&keywords=")
user1966 = driver.find_element_by_id('dynamic-table').text
d1967=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1967&keywords=")
user1967 = driver.find_element_by_id('dynamic-table').text
d1968=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1968&keywords=")
user1968 = driver.find_element_by_id('dynamic-table').text
d1969=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1969&keywords=")
user1969 = driver.find_element_by_id('dynamic-table').text
d1970=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1970&keywords=")
user1970 = driver.find_element_by_id('dynamic-table').text
d1971=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1971&keywords=")
user1971 = driver.find_element_by_id('dynamic-table').text
d1972=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1972&keywords=")
user1972 = driver.find_element_by_id('dynamic-table').text
d1973=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1973&keywords=")
user1973 = driver.find_element_by_id('dynamic-table').text
d1974=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1974&keywords=")
user1974 = driver.find_element_by_id('dynamic-table').text
d1975=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1975&keywords=")
user1975 = driver.find_element_by_id('dynamic-table').text
d1976=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1976&keywords=")
user1976 = driver.find_element_by_id('dynamic-table').text
d1977=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1977&keywords=")
user1977 = driver.find_element_by_id('dynamic-table').text
d1978=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1978&keywords=")
user1978 = driver.find_element_by_id('dynamic-table').text
d1979=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1979&keywords=")
user1979 = driver.find_element_by_id('dynamic-table').text
d1980=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1980&keywords=")
user1980 = driver.find_element_by_id('dynamic-table').text
d1981=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1981&keywords=")
user1981 = driver.find_element_by_id('dynamic-table').text
d1982=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1982&keywords=")
user1982 = driver.find_element_by_id('dynamic-table').text
d1983=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1983&keywords=")
user1983 = driver.find_element_by_id('dynamic-table').text
d1984=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1984&keywords=")
user1984 = driver.find_element_by_id('dynamic-table').text
d1985=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1985&keywords=")
user1985 = driver.find_element_by_id('dynamic-table').text
d1986=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1986&keywords=")
user1986 = driver.find_element_by_id('dynamic-table').text
d1987=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1987&keywords=")
user1987 = driver.find_element_by_id('dynamic-table').text
d1988=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1988&keywords=")
user1988 = driver.find_element_by_id('dynamic-table').text
d1989=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1989&keywords=")
user1989 = driver.find_element_by_id('dynamic-table').text
d1990=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1990&keywords=")
user1990 = driver.find_element_by_id('dynamic-table').text
d1991=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1991&keywords=")
user1991 = driver.find_element_by_id('dynamic-table').text
d1992=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1992&keywords=")
user1992 = driver.find_element_by_id('dynamic-table').text
d1993=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1993&keywords=")
user1993 = driver.find_element_by_id('dynamic-table').text
d1994=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1994&keywords=")
user1994 = driver.find_element_by_id('dynamic-table').text
d1995=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1995&keywords=")
user1995 = driver.find_element_by_id('dynamic-table').text
d1996=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1996&keywords=")
user1996 = driver.find_element_by_id('dynamic-table').text
d1997=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1997&keywords=")
user1997 = driver.find_element_by_id('dynamic-table').text
d1998=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1998&keywords=")
user1998 = driver.find_element_by_id('dynamic-table').text
d1999=driver.get("http://db-service.guazi-corp.com/dataQuery/allTables/?pageNo=1999&keywords=")
user1999 = driver.find_element_by_id('dynamic-table').text

# %%
f = open(r'd:\catalogs.txt', "a",encoding='utf-8')

# %%
print(user1,user2,user3,user4,user5,user6,user7,user8,user9,user10,user11,user12,user13,user14,user15,user16,user17,user18,user19,user20,user21,user22,user23,user24,user25,user26,user27,user28,user29,user30,user31,user32,user33,user34,user35,user36,user37,user38,user39,user40,user41,user42,user43,user44,user45,user46,user47,user48,user49,user50,user51,user52,user53,user54,user55,user56,user57,user58,user59,user60,user61,user62,user63,user64,user65,user66,user67,user68,user69,user70,user71,user72,user73,user74,user75,user76,user77,user78,user79,user80,user81,user82,user83,user84,user85,user86,user87,user88,user89,user90,user91,user92,user93,user94,user95,user96,user97,user98,user99,user100,user101,user102,user103,user104,user105,user106,user107,user108,user109,user110,user111,user112,user113,user114,user115,user116,user117,user118,user119,user120,user121,user122,user123,user124,user125,user126,user127,user128,user129,user130,user131,user132,user133,user134,user135,user136,user137,user138,user139,user140,user141,user142,user143,user144,user145,user146,user147,user148,user149,user150,user151,user152,user153,user154,user155,user156,user157,user158,user159,user160,user161,user162,user163,user164,user165,user166,user167,user168,user169,user170,user171,user172,user173,user174,user175,user176,user177,user178,user179,user180,user181,user182,user183,user184,user185,user186,user187,user188,user189,user190,user191,user192,user193,user194,user195,user196,user197,user198,user199,user200,user201,user202,user203,user204,user205,user206,user207,user208,user209,user210,user211,user212,user213,user214,user215,user216,user217,user218,user219,user220,user221,user222,user223,user224,user225,user226,user227,user228,user229,user230,user231,user232,user233,user234,user235,user236,user237,user238,user239,user240,user241,user242,user243,user244,user245,user246,user247,user248,user249,user250,user251,user252,user253,user254,user255,user256,user257,user258,user259,user260,user261,user262,user263,user264,user265,user266,user267,user268,user269,user270,user271,user272,user273,user274,user275,user276,user277,user278,user279,user280,user281,user282,user283,user284,user285,user286,user287,user288,user289,user290,user291,user292,user293,user294,user295,user296,user297,user298,user299,user300,user301,user302,user303,user304,user305,user306,user307,user308,user309,user310,user311,user312,user313,user314,user315,user316,user317,user318,user319,user320,user321,user322,user323,user324,user325,user326,user327,user328,user329,user330,user331,user332,user333,user334,user335,user336,user337,user338,user339,user340,user341,user342,user343,user344,user345,user346,user347,user348,user349,user350,user351,user352,user353,user354,user355,user356,user357,user358,user359,user360,user361,user362,user363,user364,user365,user366,user367,user368,user369,user370,user371,user372,user373,user374,user375,user376,user377,user378,user379,user380,user381,user382,user383,user384,user385,user386,user387,user388,user389,user390,user391,user392,user393,user394,user395,user396,user397,user398,user399,user400,user401,user402,user403,user404,user405,user406,user407,user408,user409,user410,user411,user412,user413,user414,user415,user416,user417,user418,user419,user420,user421,user422,user423,user424,user425,user426,user427,user428,user429,user430,user431,user432,user433,user434,user435,user436,user437,user438,user439,user440,user441,user442,user443,user444,user445,user446,user447,user448,user449,user450,user451,user452,user453,user454,user455,user456,user457,user458,user459,user460,user461,user462,user463,user464,user465,user466,user467,user468,user469,user470,user471,user472,user473,user474,user475,user476,user477,user478,user479,user480,user481,user482,user483,user484,user485,user486,user487,user488,user489,user490,user491,user492,user493,user494,user495,user496,user497,user498,user499,user500,user501,user502,user503,user504,user505,user506,user507,user508,user509,user510,user511,user512,user513,user514,user515,user516,user517,user518,user519,user520,user521,user522,user523,user524,user525,user526,user527,user528,user529,user530,user531,user532,user533,user534,user535,user536,user537,user538,user539,user540,user541,user542,user543,user544,user545,user546,user547,user548,user549,user550,user551,user552,user553,user554,user555,user556,user557,user558,user559,user560,user561,user562,user563,user564,user565,user566,user567,user568,user569,user570,user571,user572,user573,user574,user575,user576,user577,user578,user579,user580,user581,user582,user583,user584,user585,user586,user587,user588,user589,user590,user591,user592,user593,user594,user595,user596,user597,user598,user599,user600,user601,user602,user603,user604,user605,user606,user607,user608,user609,user610,user611,user612,user613,user614,user615,user616,user617,user618,user619,user620,user621,user622,user623,user624,user625,user626,user627,user628,user629,user630,user631,user632,user633,user634,user635,user636,user637,user638,user639,user640,user641,user642,user643,user644,user645,user646,user647,user648,user649,user650,user651,user652,user653,user654,user655,user656,user657,user658,user659,user660,user661,user662,user663,user664,user665,user666,user667,user668,user669,user670,user671,user672,user673,user674,user675,user676,user677,user678,user679,user680,user681,user682,user683,user684,user685,user686,user687,user688,user689,user690,user691,user692,user693,user694,user695,user696,user697,user698,user699,user700,user701,user702,user703,user704,user705,user706,user707,user708,user709,user710,user711,user712,user713,user714,user715,user716,user717,user718,user719,user720,user721,user722,user723,user724,user725,user726,user727,user728,user729,user730,user731,user732,user733,user734,user735,user736,user737,user738,user739,user740,user741,user742,user743,user744,user745,user746,user747,user748,user749,user750,user751,user752,user753,user754,user755,user756,user757,user758,user759,user760,user761,user762,user763,user764,user765,user766,user767,user768,user769,user770,user771,user772,user773,user774,user775,user776,user777,user778,user779,user780,user781,user782,user783,user784,user785,user786,user787,user788,user789,user790,user791,user792,user793,user794,user795,user796,user797,user798,user799,user800,user801,user802,user803,user804,user805,user806,user807,user808,user809,user810,user811,user812,user813,user814,user815,user816,user817,user818,user819,user820,user821,user822,user823,user824,user825,user826,user827,user828,user829,user830,user831,user832,user833,user834,user835,user836,user837,user838,user839,user840,user841,user842,user843,user844,user845,user846,user847,user848,user849,user850,user851,user852,user853,user854,user855,user856,user857,user858,user859,user860,user861,user862,user863,user864,user865,user866,user867,user868,user869,user870,user871,user872,user873,user874,user875,user876,user877,user878,user879,user880,user881,user882,user883,user884,user885,user886,user887,user888,user889,user890,user891,user892,user893,user894,user895,user896,user897,user898,user899,user900,user901,user902,user903,user904,user905,user906,user907,user908,user909,user910,user911,user912,user913,user914,user915,user916,user917,user918,user919,user920,user921,user922,user923,user924,user925,user926,user927,user928,user929,user930,user931,user932,user933,user934,user935,user936,user937,user938,user939,user940,user941,user942,user943,user944,user945,user946,user947,user948,user949,user950,user951,user952,user953,user954,user955,user956,user957,user958,user959,user960,user961,user962,user963,user964,user965,user966,user967,user968,user969,user970,user971,user972,user973,user974,user975,user976,user977,user978,user979,user980,user981,user982,user983,user984,user985,user986,user987,user988,user989,user990,user991,user992,user993,user994,user995,user996,user997,user998,user999,user1000,user1001,user1002,user1003,user1004,user1005,user1006,user1007,user1008,user1009,user1010,user1011,user1012,user1013,user1014,user1015,user1016,user1017,user1018,user1019,user1020,user1021,user1022,user1023,user1024,user1025,user1026,user1027,user1028,user1029,user1030,user1031,user1032,user1033,user1034,user1035,user1036,user1037,user1038,user1039,user1040,user1041,user1042,user1043,user1044,user1045,user1046,user1047,user1048,user1049,user1050,user1051,user1052,user1053,user1054,user1055,user1056,user1057,user1058,user1059,user1060,user1061,user1062,user1063,user1064,user1065,user1066,user1067,user1068,user1069,user1070,user1071,user1072,user1073,user1074,user1075,user1076,user1077,user1078,user1079,user1080,user1081,user1082,user1083,user1084,user1085,user1086,user1087,user1088,user1089,user1090,user1091,user1092,user1093,user1094,user1095,user1096,user1097,user1098,user1099,user1100,user1101,user1102,user1103,user1104,user1105,user1106,user1107,user1108,user1109,user1110,user1111,user1112,user1113,user1114,user1115,user1116,user1117,user1118,user1119,user1120,user1121,user1122,user1123,user1124,user1125,user1126,user1127,user1128,user1129,user1130,user1131,user1132,user1133,user1134,user1135,user1136,user1137,user1138,user1139,user1140,user1141,user1142,user1143,user1144,user1145,user1146,user1147,user1148,user1149,user1150,user1151,user1152,user1153,user1154,user1155,user1156,user1157,user1158,user1159,user1160,user1161,user1162,user1163,user1164,user1165,user1166,user1167,user1168,user1169,user1170,user1171,user1172,user1173,user1174,user1175,user1176,user1177,user1178,user1179,user1180,user1181,user1182,user1183,user1184,user1185,user1186,user1187,user1188,user1189,user1190,user1191,user1192,user1193,user1194,user1195,user1196,user1197,user1198,user1199,user1200,user1201,user1202,user1203,user1204,user1205,user1206,user1207,user1208,user1209,user1210,user1211,user1212,user1213,user1214,user1215,user1216,user1217,user1218,user1219,user1220,user1221,user1222,user1223,user1224,user1225,user1226,user1227,user1228,user1229,user1230,user1231,user1232,user1233,user1234,user1235,user1236,user1237,user1238,user1239,user1240,user1241,user1242,user1243,user1244,user1245,user1246,user1247,user1248,user1249,user1250,user1251,user1252,user1253,user1254,user1255,user1256,user1257,user1258,user1259,user1260,user1261,user1262,user1263,user1264,user1265,user1266,user1267,user1268,user1269,user1270,user1271,user1272,user1273,user1274,user1275,user1276,user1277,user1278,user1279,user1280,user1281,user1282,user1283,user1284,user1285,user1286,user1287,user1288,user1289,user1290,user1291,user1292,user1293,user1294,user1295,user1296,user1297,user1298,user1299,user1300,user1301,user1302,user1303,user1304,user1305,user1306,user1307,user1308,user1309,user1310,user1311,user1312,user1313,user1314,user1315,user1316,user1317,user1318,user1319,user1320,user1321,user1322,user1323,user1324,user1325,user1326,user1327,user1328,user1329,user1330,user1331,user1332,user1333,user1334,user1335,user1336,user1337,user1338,user1339,user1340,user1341,user1342,user1343,user1344,user1345,user1346,user1347,user1348,user1349,user1350,user1351,user1352,user1353,user1354,user1355,user1356,user1357,user1358,user1359,user1360,user1361,user1362,user1363,user1364,user1365,user1366,user1367,user1368,user1369,user1370,user1371,user1372,user1373,user1374,user1375,user1376,user1377,user1378,user1379,user1380,user1381,user1382,user1383,user1384,user1385,user1386,user1387,user1388,user1389,user1390,user1391,user1392,user1393,user1394,user1395,user1396,user1397,user1398,user1399,user1400,user1401,user1402,user1403,user1404,user1405,user1406,user1407,user1408,user1409,user1410,user1411,user1412,user1413,user1414,user1415,user1416,user1417,user1418,user1419,user1420,user1421,user1422,user1423,user1424,user1425,user1426,user1427,user1428,user1429,user1430,user1431,user1432,user1433,user1434,user1435,user1436,user1437,user1438,user1439,user1440,user1441,user1442,user1443,user1444,user1445,user1446,user1447,user1448,user1449,user1450,user1451,user1452,user1453,user1454,user1455,user1456,user1457,user1458,user1459,user1460,user1461,user1462,user1463,user1464,user1465,user1466,user1467,user1468,user1469,user1470,user1471,user1472,user1473,user1474,user1475,user1476,user1477,user1478,user1479,user1480,user1481,user1482,user1483,user1484,user1485,user1486,user1487,user1488,user1489,user1490,user1491,user1492,user1493,user1494,user1495,user1496,user1497,user1498,user1499,user1500,user1501,user1502,user1503,user1504,user1505,user1506,user1507,user1508,user1509,user1510,user1511,user1512,user1513,user1514,user1515,user1516,user1517,user1518,user1519,user1520,user1521,user1522,user1523,user1524,user1525,user1526,user1527,user1528,user1529,user1530,user1531,user1532,user1533,user1534,user1535,user1536,user1537,user1538,user1539,user1540,user1541,user1542,user1543,user1544,user1545,user1546,user1547,user1548,user1549,user1550,user1551,user1552,user1553,user1554,user1555,user1556,user1557,user1558,user1559,user1560,user1561,user1562,user1563,user1564,user1565,user1566,user1567,user1568,user1569,user1570,user1571,user1572,user1573,user1574,user1575,user1576,user1577,user1578,user1579,user1580,user1581,user1582,user1583,user1584,user1585,user1586,user1587,user1588,user1589,user1590,user1591,user1592,user1593,user1594,user1595,user1596,user1597,user1598,user1599,user1600,user1601,user1602,user1603,user1604,user1605,user1606,user1607,user1608,user1609,user1610,user1611,user1612,user1613,user1614,user1615,user1616,user1617,user1618,user1619,user1620,user1621,user1622,user1623,user1624,user1625,user1626,user1627,user1628,user1629,user1630,user1631,user1632,user1633,user1634,user1635,user1636,user1637,user1638,user1639,user1640,user1641,user1642,user1643,user1644,user1645,user1646,user1647,user1648,user1649,user1650,user1651,user1652,user1653,user1654,user1655,user1656,user1657,user1658,user1659,user1660,user1661,user1662,user1663,user1664,user1665,user1666,user1667,user1668,user1669,user1670,user1671,user1672,user1673,user1674,user1675,user1676,user1677,user1678,user1679,user1680,user1681,user1682,user1683,user1684,user1685,user1686,user1687,user1688,user1689,user1690,user1691,user1692,user1693,user1694,user1695,user1696,user1697,user1698,user1699,user1700,user1701,user1702,user1703,user1704,user1705,user1706,user1707,user1708,user1709,user1710,user1711,user1712,user1713,user1714,user1715,user1716,user1717,user1718,user1719,user1720,user1721,user1722,user1723,user1724,user1725,user1726,user1727,user1728,user1729,user1730,user1731,user1732,user1733,user1734,user1735,user1736,user1737,user1738,user1739,user1740,user1741,user1742,user1743,user1744,user1745,user1746,user1747,user1748,user1749,user1750,user1751,user1752,user1753,user1754,user1755,user1756,user1757,user1758,user1759,user1760,user1761,user1762,user1763,user1764,user1765,user1766,user1767,user1768,user1769,user1770,user1771,user1772,user1773,user1774,user1775,user1776,user1777,user1778,user1779,user1780,user1781,user1782,user1783,user1784,user1785,user1786,user1787,user1788,user1789,user1790,user1791,user1792,user1793,user1794,user1795,user1796,user1797,user1798,user1799,user1800,user1801,user1802,user1803,user1804,user1805,user1806,user1807,user1808,user1809,user1810,user1811,user1812,user1813,user1814,user1815,user1816,user1817,user1818,user1819,user1820,user1821,user1822,user1823,user1824,user1825,user1826,user1827,user1828,user1829,user1830,user1831,user1832,user1833,user1834,user1835,user1836,user1837,user1838,user1839,user1840,user1841,user1842,user1843,user1844,user1845,user1846,user1847,user1848,user1849,user1850,user1851,user1852,user1853,user1854,user1855,user1856,user1857,user1858,user1859,user1860,user1861,user1862,user1863,user1864,user1865,user1866,user1867,user1868,user1869,user1870,user1871,user1872,user1873,user1874,user1875,user1876,user1877,user1878,user1879,user1880,user1881,user1882,user1883,user1884,user1885,user1886,user1887,user1888,user1889,user1890,user1891,user1892,user1893,user1894,user1895,user1896,user1897,user1898,user1899,user1900,user1901,user1902,user1903,user1904,user1905,user1906,user1907,user1908,user1909,user1910,user1911,user1912,user1913,user1914,user1915,user1916,user1917,user1918,user1919,user1920,user1921,user1922,user1923,user1924,user1925,user1926,user1927,user1928,user1929,user1930,user1931,user1932,user1933,user1934,user1935,user1936,user1937,user1938,user1939,user1940,user1941,user1942,user1943,user1944,user1945,user1946,user1947,user1948,user1949,user1950,user1951,user1952,user1953,user1954,user1955,user1956,user1957,user1958,user1959,user1960,user1961,user1962,user1963,user1964,user1965,user1966,user1967,user1968,user1969,user1970,user1971,user1972,user1973,user1974,user1975,user1976,user1977,user1978,user1979,user1980,user1981,user1982,user1983,user1984,user1985,user1986,user1987,user1988,user1989,user1990,user1991,user1992,user1993,user1994,user1995,user1996,user1997,user1998,user1999,file=f)

# %%
# 记录一下  取得阶段性胜利  
# 后面还需要 1. 将复杂语句转化成 循环结构
# 2. 现在的方式 每次页面刷新之后 信息重新排列  会导致重复信息 以及遗漏信息  每次点击页面之后在获取元素
# 按钮之后的内容怎么复制
# 乱码问题  是为啥

# %%
print(user1100)
# Out:
# 业务线 Owner 端口 数据库 表名 DDL 行数 存储空间(M) 创建时间 表注释 昨日增长 统计时间
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic deduct_score_log 查看DDL 3 0 2019-08-13 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic evaluate_project_operate_log 查看DDL 2 0 2020-01-06 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic evaluate_scan_log 查看DDL 1 0 2019-04-22 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic evaluator_job 查看DDL 3 0 2019-12-17 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic evaluator_punishment_log 查看DDL 1 0 2019-08-14 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic evaluator_work_status_log 查看DDL 1 0 2019-07-22 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic fixed_point_operator_log 查看DDL 1 0 2019-12-08 0 2020-04-28
# dbsys liuqiang44 3401 10_16_208_153_3335_evaluate_statistic g3_call_diff_detail 查看DDL 1 0 2019-04-24 0 2020-04-28
# ...

# %%
element = driver.find_element_by_id('reqDetail')

# %%
print(element)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="68bc949e93d4ffbddf35caa6a36a3fcb", element="2e542b22-3d96-4388-867c-7723e4cad67c")>

# %%
element = driver.find_element_by_id('tableDDL')

# %%
print(element.text)
# Out:
# CREATE TABLE `task_execution_pod_record` (
#   `id` int(10) unsigned NOT NULL AUTO_INCREMENT COMMENT '编号',
#   `cluster` varchar(20) NOT NULL DEFAULT '' COMMENT '运行集群',
#   `namespace` varchar(20) NOT NULL DEFAULT '' COMMENT 'namespace',
#   `owner_ref_name` varchar(50) NOT NULL DEFAULT '' COMMENT '父级资源名',
#   `pod_name` varchar(50) NOT NULL DEFAULT '' COMMENT '任务每次执行的JOB名',
#   `states` varchar(200) NOT NULL DEFAULT '' COMMENT 'pod运行状态',
#   `ip` varchar(100) NOT NULL DEFAULT '' COMMENT 'IP',
#   `yaml` text COMMENT 'job的执行信息的yaml描述',
#   `restart_counts` int(5) NOT NULL DEFAULT '0' COMMENT '重启总次数',
#   `resource_version` int(15) NOT NULL DEFAULT '0' COMMENT '版号',
#   `created_at` timestamp NOT NULL DEFAULT CURRENT_TIMESTAMP COMMENT '创建时间',
#   `updated_at` timestamp NOT NULL DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP COMMENT '修改时间',
#   PRIMARY KEY (`id`),
#   UNIQUE KEY `uniq_version` (`resource_version`),
#   KEY `idx_ip` (`ip`),
# ...

# %%
element = driver.find_element_by_css_selector('tbody > tr > td > button')

# %%
print(element.get_attribute('outerHTML'))
# Out:
# <button type="button" id="reqDetail" class="btn btn-mini btn-success" onclick="getTableInfo(11004154)"> 查看DDL</button>
